# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from dotenv import load_dotenv
import os
import requests
from pprint import pprint
import psycopg2
import json

# %% [markdown]
# ### Data Extraction

# %%
# Load environment variables from the .env file
load_dotenv()

# Retrieve environment variables
rapidapi_key = os.getenv('RAPIDAPI_KEY')
rapidapi_host = os.getenv('RAPIDAPI_HOST')

# Define the headers using the variables
headers = {
    'x-rapidapi-key': rapidapi_key,
    'x-rapidapi-host': rapidapi_host,
}

# API request details
url = "https://realty-mole-property-api.p.rapidapi.com/randomProperties"
querystring = {"limit": "500"}

# Make the API request
response = requests.get(url, headers=headers, params=querystring)

# Print the response
pprint(response.json())
# Out:
# [{'addressLine1': '1042 Riverside Dr',
#   'assessorID': '264-54-019',
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'city': 'San Jose',
#   'county': 'Santa Clara',
#   'features': {'fireplace': True,
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Garage',
#                'roomCount': 5,
#                'unitCount': 1},
#   'formattedAddress': '1042 Riverside Dr, San Jose, CA 95125',
#   'id': '1042-Riverside-Dr,-San-Jose,-CA-95125',
#   'lastSaleDate': '2021-04-02T00:00:00.000Z',
#   'lastSalePrice': 999000,
#   'latitude': 37.312376,
#   'legalDescription': 'TR 29 LOT 10',
#   'longitude': -121.900219,
#   'lotSize': 4945,
#   'owner': {'mailingAddress': {'addressLine1': '1042 Riverside Dr',
#                                'city': 'San Jose',
#                                'formattedAddress': '1042 Riverside Dr, San '
#                                                    'Jose, CA 95125',
#                                'id': '1042-Riverside-Dr,-San-Jose,-CA-95125',
#                                'state': 'CA',
#                                'zipCode': '95125'},
#             'names': ['Allison J Brooks', 'WILLIAM PETERMAN']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 13416}},
#   'propertyType': 'Single Family',
#   'squareFootage': 930,
#   'state': 'CA',
#   'subdivision': 'INDIANA COURT',
#   'taxAssessment': {'2023': {'improvements': 102999,
#                              'land': 936360,
#                              'value': 1039359}},
#   'yearBuilt': 1939,
#   'zipCode': '95125',
#   'zoning': 'R1'},
#  {'addressLine1': '6909 Windmere Ln',
#   'assessorID': '055E0-03-00-01700',
#   'bathrooms': 5,
#   'bedrooms': 6,
#   'city': 'Crozet',
#   'county': 'Albemarle',
#   'features': {'architectureType': 'Traditional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Composition',
#                'fireplace': True,
#                'fireplaceType': 'Gas Log',
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Heat Pump',
#                'roofType': 'Wood',
#                'roomCount': 9},
#   'formattedAddress': '6909 Windmere Ln, Crozet, VA 22932',
#   'id': '6909-Windmere-Ln,-Crozet,-VA-22932',
#   'lastSaleDate': '2016-06-03T00:00:00.000Z',
#   'lastSalePrice': 675000,
#   'latitude': 38.067079,
#   'legalDescription': 'OLD TRAIL 17 PH 1 CREEKSIDE',
#   'longitude': -78.716506,
#   'lotSize': 20081,
#   'owner': {'mailingAddress': {'addressLine1': '6909 Windmere Ln',
#                                'city': 'Crozet',
#                                'formattedAddress': '6909 Windmere Ln, Crozet, '
#                                                    'VA 22932',
#                                'id': '6909-Windmere-Ln,-Crozet,-VA-22932',
#                                'state': 'VA',
#                                'zipCode': '22932'},
#             'names': ['Patrick R Latimer', 'KATHERINE A LATIMER']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 5801}, '2024': {'total': 8323}},
#   'propertyType': 'Single Family',
#   'squareFootage': 3318,
#   'state': 'VA',
#   'subdivision': 'OLD TRAIL',
#   'taxAssessment': {'2021': {'improvements': 448400,
#                              'land': 225700,
#                              'value': 674100},
#                     '2024': {'improvements': 741400,
#                              'land': 233200,
#                              'value': 974600}},
#   'yearBuilt': 2011,
#   'zipCode': '22932',
#   'zoning': 'R1 RESIDENTIAL'},
#  {'addressLine1': '38320 N Chicago Ave',
#   'assessorID': '03-34-400-006',
#   'bathrooms': 1.5,
#   'bedrooms': 3,
#   'city': 'Wadsworth',
#   'county': 'Lake',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'OTHER',
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '38320 N Chicago Ave, Wadsworth, IL 60083',
#   'id': '38320-N-Chicago-Ave,-Wadsworth,-IL-60083',
#   'latitude': 42.418909,
#   'legalDescription': 'E 225 FT N 60 FT S 229.5 FT OF S 10 ACSOF N 35 ACS PT '
#                       'NE1/4 SE1/4 SECTION 34 TOWNSHIP 46 RANGE 11',
#   'longitude': -87.924063,
#   'lotSize': 13504,
#   'owner': {'mailingAddress': {'addressLine1': '38320 N Chicago Ave',
#                                'city': 'Wadsworth',
#                                'id': '38320-N-Chicago-Ave,-Wadsworth,-IL-60083',
#                                'state': 'IL',
#                                'zipCode': '60083'},
#             'names': ['TRUST 38320']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 2127}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1452,
#   'state': 'IL',
#   'subdivision': 'PT NE1/4 SE1/4',
#   'taxAssessment': {'2022': {'improvements': 43674,
#                              'land': 5739,
#                              'value': 49413}},
#   'yearBuilt': 1949,
#   'zipCode': '60083'},
#  {'addressLine1': '2050 Sw 122nd Ave',
#   'addressLine2': 'Apt 22',
#   'assessorID': '30-4912-069-0060',
#   'bathrooms': 3,
#   'bedrooms': 3,
#   'city': 'Miami',
#   'county': 'Miami-Dade',
#   'features': {'architectureType': 'Condo / Apartment'},
#   'formattedAddress': '2050 Sw 122nd Ave, Apt 22, Miami, FL 33175',
#   'id': '2050-Sw-122nd-Ave,-Apt-22,-Miami,-FL-33175',
#   'lastSaleDate': '2022-01-14T00:00:00.000Z',
#   'lastSalePrice': 310000,
#   'latitude': 25.74855,
#   'legalDescription': 'BRISAS DEL LAGO CONDO UNIT 22 UNDIV 1/15 INT IN COMMON '
#                       'ELEMENTS OFF REC 13692-3120 OR 14500-1923 1289 1',
#   'longitude': -80.391202,
#   'owner': {'mailingAddress': {'addressLine1': '2050 Sw 122nd Ave',
#                                'addressLine2': 'APT 22',
#                                'city': 'Miami',
#                                'formattedAddress': '2050 Sw 122nd Ave, APT 22, '
#                                                    'Miami, FL 33175',
#                                'id': '2050-Sw-122nd-Ave,-APT-22,-Miami,-FL-33175',
#                                'state': 'FL',
#                                'zipCode': '33175'},
#             'names': ['Carlos Cortes Bayardo', 'Cecilia Cortes']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 3467},
#                     '2022': {'total': 4345},
#                     '2023': {'total': 4780}},
#   'propertyType': 'Condo',
#   'squareFootage': 1518,
#   'state': 'FL',
#   'subdivision': 'BRISAS DEL LAGO',
#   'taxAssessment': {'2020': {'value': 195000},
#                     '2021': {'value': 195000},
#                     '2022': {'value': 253500},
#                     '2023': {'value': 278850}},
#   'yearBuilt': 1988,
#   'zipCode': '33175',
#   'zoning': '3900:MULTI-FAM,38-62 U/A'},
#  {'addressLine1': '3008 Crestline Rd',
#   'assessorID': '136-060-16-00-5',
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'city': 'Bakersfield',
#   'county': 'Kern',
#   'features': {'cooling': True,
#                'coolingType': 'Evaporative',
#                'fireplace': True,
#                'fireplaceType': 'Single',
#                'floorCount': 1,
#                'heating': True,
#                'heatingType': 'Electric',
#                'pool': True,
#                'unitCount': 1},
#   'formattedAddress': '3008 Crestline Rd, Bakersfield, CA 93306',
#   'id': '3008-Crestline-Rd,-Bakersfield,-CA-93306',
#   'latitude': 35.378973,
#   'legalDescription': 'TRACT 1360, BLOCK, LOT 25',
#   'longitude': -118.951116,
#   'lotSize': 7405,
#   'owner': {'mailingAddress': {'addressLine1': '3008 Crestline Rd',
#                                'city': 'Bakersfield',
#                                'id': '3008-Crestline-Rd,-Bakersfield,-CA-93306',
#                                'state': 'CA',
#                                'zipCode': '93306'},
#             'names': ['PATRICIA TOPPING']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 1126}, '2023': {'total': 1378}},
#   'propertyType': 'Land',
#   'squareFootage': 1117,
#   'state': 'CA',
#   'taxAssessment': {'2019': {'improvements': 26610,
#                              'land': 9640,
#                              'value': 36250},
#                     '2023': {'improvements': 27970,
#                              'land': 10131,
#                              'value': 38101}},
#   'yearBuilt': 1950,
#   'zipCode': '93306',
#   'zoning': 'R-1'},
#  {'addressLine1': '1508 Yardley Rd',
#   'assessorID': '20-043-079',
#   'bathrooms': 1.5,
#   'bedrooms': 3,
#   'city': 'Yardley',
#   'county': 'Bucks',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Wood',
#                'fireplace': True,
#                'floorCount': 2,
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 6},
#   'formattedAddress': '1508 Yardley Rd, Yardley, PA 19067',
#   'id': '1508-Yardley-Rd,-Yardley,-PA-19067',
#   'lastSaleDate': '2020-12-14T00:00:00.000Z',
#   'lastSalePrice': 535000,
#   'latitude': 40.220329,
#   'legalDescription': 'WESTOVER TRACT BLK G LOT #1 80X200',
#   'longitude': -74.810774,
#   'lotSize': 16000,
#   'owner': {'mailingAddress': {'addressLine1': '1508 Yardley Rd',
#                                'city': 'Yardley',
#                                'id': '1508-Yardley-Rd,-Yardley,-PA-19067',
#                                'state': 'PA',
#                                'zipCode': '19067'},
#             'names': ["JULIANNE MARIE O'CONNELL", "SEAN MICHAEL O'CONNELL"]},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 7197}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1458,
#   'state': 'PA',
#   'subdivision': 'WESTOVER',
#   'taxAssessment': {'2023': {'improvements': 22240,
#                              'land': 9760,
#                              'value': 32000}},
#   'yearBuilt': 1953,
#   'zipCode': '19067',
#   'zoning': 'R2'},
#  {'addressLine1': '1763 E 228th St',
#   'assessorID': '650-04-016',
#   'bathrooms': 1.5,
#   'bedrooms': 3,
#   'city': 'Euclid',
#   'county': 'Cuyahoga',
#   'features': {'architectureType': 'Ranch',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 5,
#                'unitCount': 1},
#   'formattedAddress': '1763 E 228th St, Euclid, OH 44117',
#   'id': '1763-E-228th-St,-Euclid,-OH-44117',
#   'latitude': 41.571139,
#   'legalDescription': 'AT TR CHARHT#2 0022 ALL MB650 PG04 MB12354 PG0023 MB PG',
#   'longitude': -81.522157,
#   'lotSize': 8100,
#   'owner': {'mailingAddress': {'addressLine1': '1763 E 228th St',
#                                'city': 'Euclid',
#                                'formattedAddress': '1763 E 228th St, Euclid, '
#                                                    'OH 44117',
#                                'id': '1763-E-228th-St,-Euclid,-OH-44117',
#                                'state': 'OH',
#                                'zipCode': '44117'},
#             'names': ['BERNICE JACOBSON', 'JAMES JACOBSON'],
#             'type': 'Organization'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 2862}, '2023': {'total': 2894}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1544,
#   'state': 'OH',
#   'subdivision': 'AT TR CHARHT#2',
#   'taxAssessment': {'2022': {'improvements': 34160,
#                              'land': 8300,
#                              'value': 42460},
#                     '2023': {'improvements': 34160,
#                              'land': 8300,
#                              'value': 42460}},
#   'yearBuilt': 1957,
#   'zipCode': '44117',
#   'zoning': 'U1'},
#  {'addressLine1': '17423 Brookview Dr',
#   'assessorID': '46 044 05 0010 000',
#   'bathrooms': 2.5,
#   'bedrooms': 3,
#   'city': 'Livonia',
#   'county': 'Wayne',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Adobe',
#                'fireplace': True,
#                'fireplaceType': 'Single',
#                'floorCount': 2,
#                'foundationType': 'OTHER',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 7,
#                'unitCount': 1},
#   'formattedAddress': '17423 Brookview Dr, Livonia, MI 48152',
#   'id': '17423-Brookview-Dr,-Livonia,-MI-48152',
#   'lastSaleDate': '2019-07-03T00:00:00.000Z',
#   'lastSalePrice': 289000,
#   'latitude': 42.416115,
#   'legalDescription': 'LOT #10 SUNSET PARK ESTATES T1S R9E; L102 P33 & 34 WCR',
#   'longitude': -83.338793,
#   'lotSize': 8276,
#   'owner': {'mailingAddress': {'addressLine1': '17423 Brookview Dr',
#                                'city': 'Livonia',
#                                'id': '17423-Brookview-Dr,-Livonia,-MI-48152',
#                                'state': 'MI',
#                                'zipCode': '48152'},
#             'names': ['DAVID PATTON',
#                       'BETHANY A PATTON',
#                       'PATTON FAMILY TRUST']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 5075}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1863,
#   'state': 'MI',
#   'subdivision': 'SUNSET PARK ESTATES',
#   'taxAssessment': {'2022': {'value': 147200}},
#   'yearBuilt': 1989,
#   'zipCode': '48152'},
#  {'addressLine1': '605 E Moore St',
#   'assessorID': '10-08-34-04-013-02000',
#   'bedrooms': 2,
#   'city': 'Hayti',
#   'county': 'Pemiscot',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Stucco',
#                'floorCount': 1,
#                'foundationType': 'Block',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'roomCount': 5},
#   'formattedAddress': '605 E Moore St, Hayti, MO 63851',
#   'id': '605-E-Moore-St,-Hayti,-MO-63851',
#   'lastSaleDate': '2022-12-19T00:00:00.000Z',
#   'latitude': 36.235673,
#   'legalDescription': 'E 150 OF LOT 5 PLUS ADDED FOOTAGE BLK 27 OATES REED '
#                       'MOORE REPLAT HAYTI',
#   'longitude': -89.744765,
#   'owner': {'mailingAddress': {'addressLine1': '71 County Hwy',
#                                'addressLine2': '411',
#                                'city': 'Bragg City',
#                                'id': '71-County-Hwy,-411,-Bragg-City,-MO-63827',
#                                'state': 'MO',
#                                'zipCode': '63827'},
#             'names': ['MICHAEL BLANKENSHIP', 'DARLENE BLANKENSHIP']},
#   'ownerOccupied': True,
#   'propertyType': 'Single Family',
#   'squareFootage': 1267,
#   'state': 'MO',
#   'taxAssessment': {'2020': {'value': 7570}, '2023': {'value': 8690}},
#   'yearBuilt': 1950,
#   'zipCode': '63851'},
#  {'addressLine1': '1515 W Arrow Hwy',
#   'addressLine2': 'Spc 45',
#   'assessorID': '1007-231-10-6045',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'Upland',
#   'county': 'San Bernardino',
#   'features': {'architectureType': 'Mobile Home',
#                'cooling': True,
#                'coolingType': 'Central',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Carport',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'roomCount': 5},
#   'formattedAddress': '1515 W Arrow Hwy, Spc 45, Upland, CA 91786',
#   'id': '1515-W-Arrow-Hwy,-Spc-45,-Upland,-CA-91786',
#   'latitude': 34.10231,
#   'legalDescription': '14 SKYLINE AMBER COVE SN#67710382GB/67710382GA',
#   'longitude': -117.678541,
#   'owner': {'mailingAddress': {'addressLine1': '1515 W Arrow Hwy',
#                                'addressLine2': 'SPC 45',
#                                'city': 'Upland',
#                                'formattedAddress': '1515 W Arrow Hwy, SPC 45, '
#                                                    'Upland, CA 91786',
#                                'id': '1515-W-Arrow-Hwy,-SPC-45,-Upland,-CA-91786',
#                                'state': 'CA',
#                                'zipCode': '91786'},
#             'names': ['An Tran']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 670},
#                     '2022': {'total': 657},
#                     '2023': {'total': 658}},
#   'propertyType': 'Manufactured',
#   'squareFootage': 1040,
#   'state': 'CA',
#   'taxAssessment': {'2019': {'improvements': 62000, 'value': 62000},
#                     '2022': {'improvements': 62000, 'value': 62000},
#                     '2023': {'improvements': 62000, 'value': 62000}},
#   'yearBuilt': 2014,
#   'zipCode': '91786'},
#  {'addressLine1': '5 W Hill Dr',
#   'assessorID': 'WHAR M:H8 B:5993 L:5',
#   'bathrooms': 6,
#   'bedrooms': 6,
#   'city': 'West Hartford',
#   'county': 'Hartford',
#   'features': {'architectureType': 'Colonial',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Wood Siding',
#                'fireplace': True,
#                'floorCount': 3,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Underground / Basement',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 12,
#                'unitCount': 1},
#   'formattedAddress': '5 W Hill Dr, West Hartford, CT 06119',
#   'id': '5-W-Hill-Dr,-West-Hartford,-CT-06119',
#   'lastSaleDate': '1996-12-18T00:00:00.000Z',
#   'lastSalePrice': 212000,
#   'latitude': 41.765418,
#   'legalDescription': '059931 - 000005 - 000001  -  000000',
#   'longitude': -72.7231,
#   'lotSize': 21780,
#   'owner': {'mailingAddress': {'addressLine1': '5 W Hill Dr',
#                                'city': 'West Hartford',
#                                'id': '5-W-Hill-Dr,-West-Hartford,-CT-06119',
#                                'state': 'CT',
#                                'zipCode': '06119'},
#             'names': ['CHARLES P COLLITON']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 18548}},
#   'propertyType': 'Single Family',
#   'squareFootage': 4972,
#   'state': 'CT',
#   'taxAssessment': {'2020': {'improvements': 321130,
#                              'land': 122600,
#                              'value': 443730}},
#   'yearBuilt': 1921,
#   'zipCode': '06119',
#   'zoning': 'R-10'},
#  {'addressLine1': '831 Geronimo Trl',
#   'assessorID': '219-06-810-019',
#   'city': 'Jean',
#   'county': 'Clark',
#   'features': {},
#   'formattedAddress': '831 Geronimo Trl, Jean, NV 89019',
#   'id': '831-Geronimo-Trl,-Jean,-NV-89019',
#   'lastSaleDate': '2022-06-10T00:00:00.000Z',
#   'lastSalePrice': 67500,
#   'latitude': 35.796778,
#   'legalDescription': 'SKY RANCH EST 1 PLAT BOOK 22 PAGE 89 LOT 19 BLOCK 1',
#   'longitude': -115.627502,
#   'lotSize': 31799,
#   'owner': {'mailingAddress': {'addressLine1': '900 Eagle Ave',
#                                'city': 'Sandy Valley',
#                                'id': '900-Eagle-Ave,-Sandy-Valley,-NV-89019',
#                                'state': 'NV',
#                                'zipCode': '89019'},
#             'names': ['MARC FOURNIER']},
#   'propertyTaxes': {'2022': {'total': 244}},
#   'propertyType': 'Land',
#   'state': 'NV',
#   'subdivision': 'SKY RANCH EST 1',
#   'taxAssessment': {'2023': {'improvements': 181,
#                              'land': 11813,
#                              'value': 11994}},
#   'zipCode': '89019'},
#  {'addressLine1': '12402 Biloxi Dr',
#   'assessorID': 'R-3453-0LL-0350-1',
#   'bathrooms': 2,
#   'bedrooms': 4,
#   'city': 'Frisco',
#   'county': 'Collin',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'fireplace': True,
#                'floorCount': 1,
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'roomCount': 7,
#                'unitCount': 1},
#   'formattedAddress': '12402 Biloxi Dr, Frisco, TX 75035',
#   'id': '12402-Biloxi-Dr,-Frisco,-TX-75035',
#   'lastSaleDate': '2000-04-03T00:00:00.000Z',
#   'latitude': 33.129315,
#   'legalDescription': 'PLANTATION RESORT PHASE IIIC, THE (CFR), BLK LL, LOT 35',
#   'longitude': -96.76956,
#   'owner': {'mailingAddress': {'addressLine1': '12402 Biloxi Dr',
#                                'city': 'Frisco',
#                                'formattedAddress': '12402 Biloxi Dr, Frisco, '
#                                                    'TX 75035',
#                                'id': '12402-Biloxi-Dr,-Frisco,-TX-75035',
#                                'state': 'TX',
#                                'zipCode': '75035'},
#             'names': ['Daniel Spencer', 'Michelle Spencer'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 6378}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1952,
#   'state': 'TX',
#   'subdivision': 'PLANTATION RESORT PHASE IIIC THE (CFR)',
#   'taxAssessment': {'2022': {'improvements': 330377,
#                              'land': 110000,
#                              'value': 440377},
#                     '2023': {'improvements': 374000,
#                              'land': 130000,
#                              'value': 504000}},
#   'yearBuilt': 1997,
#   'zipCode': '75035',
#   'zoning': 'SFR'},
#  {'addressLine1': '740 E Vernon Rd',
#   'addressLine2': 'Apt 307',
#   'city': 'Philadelphia',
#   'county': 'Philadelphia',
#   'features': {},
#   'formattedAddress': '740 E Vernon Rd, Apt 307, Philadelphia, PA 19119',
#   'id': '740-E-Vernon-Rd,-Apt-307,-Philadelphia,-PA-19119',
#   'latitude': 40.063615,
#   'longitude': -75.17618,
#   'state': 'PA',
#   'zipCode': '19119'},
#  {'addressLine1': '8526 Mansfield Ave',
#   'assessorID': '10-20-219-009',
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'city': 'Morton Grove',
#   'county': 'Cook',
#   'features': {'architectureType': 'Bungalow',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Brick / Stone',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Garage',
#                'roofType': 'Shingle',
#                'unitCount': 1},
#   'formattedAddress': '8526 Mansfield Ave, Morton Grove, IL 60053',
#   'id': '8526-Mansfield-Ave,-Morton-Grove,-IL-60053',
#   'lastSaleDate': '1992-10-02T00:00:00.000Z',
#   'lastSalePrice': 135000,
#   'latitude': 42.036598,
#   'legalDescription': '(NORTHWESTERN)(REALTY) COS (DEMPSTER) TERMINAL SUB OF '
#                       'PT OF WH NE SEC 20-41-13',
#   'longitude': -87.77316,
#   'lotSize': 3720,
#   'owner': {'mailingAddress': {'addressLine1': '8526 Mansfield Ave',
#                                'city': 'Morton Grove',
#                                'formattedAddress': '8526 Mansfield Ave, Morton '
#                                                    'Grove, IL 60053',
#                                'id': '8526-Mansfield-Ave,-Morton-Grove,-IL-60053',
#                                'state': 'IL',
#                                'zipCode': '60053'},
#             'names': ['Albert L Shafer']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 8203}, '2022': {'total': 7981}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1182,
#   'state': 'IL',
#   'subdivision': 'NORTHWESTERN REALTY COS DEMPSTER',
#   'taxAssessment': {'2021': {'improvements': 22599,
#                              'land': 2976,
#                              'value': 25575},
#                     '2022': {'improvements': 24164,
#                              'land': 4836,
#                              'value': 29000}},
#   'yearBuilt': 1930,
#   'zipCode': '60053'},
#  {'addressLine1': '3650 W Diversey Ave',
#   'assessorID': '13261300260000',
#   'bathrooms': 3,
#   'bedrooms': 4,
#   'city': 'Chicago',
#   'county': 'Cook',
#   'features': {'architectureType': 'Two Family',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Brick / Stone',
#                'floorCount': 2,
#                'roofType': 'Roll Tar & Gravel',
#                'unitCount': 3},
#   'formattedAddress': '3650 W Diversey Ave, Chicago, IL 60647',
#   'id': '3650-W-Diversey-Ave,-Chicago,-IL-60647',
#   'lastSaleDate': '2014-12-03T00:00:00.000Z',
#   'lastSalePrice': 300000,
#   'latitude': 41.932102,
#   'legalDescription': 'DIST:71 CITY/MUNI/TWP:JEFFERSON SEC/TWN/RNG/MER:SEC 26 '
#                       'TWN 40N RNG 13E',
#   'longitude': -87.719231,
#   'lotSize': 3175,
#   'owner': {'mailingAddress': {'addressLine1': '5328 W Leland Ave',
#                                'city': 'Chicago',
#                                'formattedAddress': '5328 W Leland Ave, '
#                                                    'Chicago, IL 60630',
#                                'id': '5328-W-Leland-Ave,-Chicago,-IL-60630',
#                                'state': 'IL',
#                                'zipCode': '60630'},
#             'names': ['Darek Wrzosek']},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2016': {'total': 6910},
#                     '2018': {'total': 5876},
#                     '2021': {'total': 10290},
#                     '2022': {'total': 10526}},
#   'propertyType': 'Apartment',
#   'squareFootage': 4532,
#   'state': 'IL',
#   'subdivision': 'BLANCHARDS SUB',
#   'taxAssessment': {'2018': {'improvements': 24666,
#                              'land': 5080,
#                              'value': 29746},
#                     '2021': {'improvements': 39887,
#                              'land': 11115,
#                              'value': 51002},
#                     '2022': {'improvements': 39887,
#                              'land': 11115,
#                              'value': 51002}},
#   'yearBuilt': 1904,
#   'zipCode': '60647'},
#  {'addressLine1': '2938 S Parnell Ave',
#   'addressLine2': 'Unit 1F',
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'city': 'Chicago',
#   'county': 'Cook',
#   'formattedAddress': '2938 S Parnell Ave, Unit 1F, Chicago, IL 60616',
#   'id': '2938-S-Parnell-Ave,-Unit-1F,-Chicago,-IL-60616',
#   'latitude': 41.840618,
#   'longitude': -87.640541,
#   'lotSize': 3125,
#   'propertyType': 'Apartment',
#   'squareFootage': 1000,
#   'state': 'IL',
#   'zipCode': '60616'},
#  {'addressLine1': '31558 Victoria Point Rd',
#   'assessorID': '4470-017-043',
#   'bathrooms': 4.5,
#   'bedrooms': 4,
#   'city': 'Malibu',
#   'county': 'Los Angeles',
#   'features': {'heating': True, 'heatingType': 'Central', 'unitCount': 1},
#   'formattedAddress': '31558 Victoria Point Rd, Malibu, CA 90265',
#   'id': '31558-Victoria-Point-Rd,-Malibu,-CA-90265',
#   'lastSaleDate': '2021-06-16T00:00:00.000Z',
#   'lastSalePrice': 8000000,
#   'latitude': 34.03582,
#   'legalDescription': 'TRACT NO 25166 LOT 21',
#   'longitude': -118.862013,
#   'lotSize': 8128,
#   'owner': {'mailingAddress': {'addressLine1': '357 Bellino Dr',
#                                'city': 'Pacific Palisades',
#                                'formattedAddress': '357 Bellino Dr, Pacific '
#                                                    'Palisades, CA 90272',
#                                'id': '357-Bellino-Dr,-Pacific-Palisades,-CA-90272',
#                                'state': 'CA',
#                                'zipCode': '90272'},
#             'names': ['Julie J Morley', 'THE JULIE J MORLEY REVOCABLE TRUST'],
#             'type': 'Individual'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2023': {'total': 99629}},
#   'propertyType': 'Single Family',
#   'squareFootage': 4195,
#   'state': 'CA',
#   'subdivision': '25166',
#   'taxAssessment': {'2023': {'improvements': 1664640,
#                              'land': 6658560,
#                              'value': 8323200}},
#   'yearBuilt': 1974,
#   'zipCode': '90265',
#   'zoning': 'LCR1*'},
#  {'addressLine1': '1400 Old Country Rd',
#   'addressLine2': 'Ste 408',
#   'city': 'Westbury',
#   'county': 'Nassau',
#   'features': {},
#   'formattedAddress': '1400 Old Country Rd, Ste 408, Westbury, NY 11590',
#   'id': '1400-Old-Country-Rd,-Ste-408,-Westbury,-NY-11590',
#   'latitude': 40.755038,
#   'longitude': -73.552792,
#   'state': 'NY',
#   'zipCode': '11590'},
#  {'addressLine1': '17537 W 157th Ter',
#   'assessorID': 'DP77140000 0021',
#   'bathrooms': 2.5,
#   'bedrooms': 4,
#   'city': 'Olathe',
#   'county': 'Johnson',
#   'features': {'architectureType': 'Split Level',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Wood',
#                'fireplace': True,
#                'fireplaceType': 'Single',
#                'floorCount': 1,
#                'foundationType': 'OTHER',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Basement',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'roomCount': 7},
#   'formattedAddress': '17537 W 157th Ter, Olathe, KS 66062',
#   'id': '17537-W-157th-Ter,-Olathe,-KS-66062',
#   'latitude': 38.843084,
#   'legalDescription': 'WALNUT CREEK 2ND PLAT LT 21 OLC 677 21',
#   'longitude': -94.790493,
#   'lotSize': 8187,
#   'owner': {'mailingAddress': {'addressLine1': '17537 W 157th Ter',
#                                'city': 'Olathe',
#                                'id': '17537-W-157th-Ter,-Olathe,-KS-66062',
#                                'state': 'KS',
#                                'zipCode': '66062'},
#             'names': ['KELLY J DAHL']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 4471}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1915,
#   'state': 'KS',
#   'subdivision': 'WALNUT CREEK',
#   'taxAssessment': {'2021': {'improvements': 28855,
#                              'land': 6301,
#                              'value': 35156},
#                     '2022': {'improvements': 31626,
#                              'land': 6301,
#                              'value': 37927}},
#   'yearBuilt': 1999,
#   'zipCode': '66062',
#   'zoning': 'R1'},
#  {'addressLine1': '412 Kennedy Taylor Ln',
#   'assessorID': '2-4200-00422',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Inman',
#   'county': 'Spartanburg',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Vinyl',
#                'floorCount': 1,
#                'foundationType': 'Brick',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '412 Kennedy Taylor Ln, Inman, SC 29349',
#   'id': '412-Kennedy-Taylor-Ln,-Inman,-SC-29349',
#   'lastSaleDate': '2004-07-19T00:00:00.000Z',
#   'lastSalePrice': 154000,
#   'latitude': 35.048532,
#   'legalDescription': 'LOT 49 KENNEDYS MEADOW SUB PB 154-871',
#   'longitude': -82.05609,
#   'lotSize': 24829,
#   'owner': {'mailingAddress': {'addressLine1': '412 Kennedy Taylor Ln',
#                                'city': 'Inman',
#                                'formattedAddress': '412 Kennedy Taylor Ln, '
#                                                    'Inman, SC 29349',
#                                'id': '412-Kennedy-Taylor-Ln,-Inman,-SC-29349',
#                                'state': 'SC',
#                                'zipCode': '29349'},
#             'names': ['Robert C Whiteside', 'Vivian A Whiteside']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 1048}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1669,
#   'state': 'SC',
#   'subdivision': 'KENNEDYS MEADOW SUB',
#   'taxAssessment': {'2023': {'improvements': 6898,
#                              'land': 1058,
#                              'value': 7956}},
#   'yearBuilt': 2004,
#   'zipCode': '29349'},
#  {'addressLine1': '55 River Rd',
#   'addressLine2': 'Apt 22',
#   'city': 'Manchester',
#   'county': 'Hillsborough',
#   'features': {},
#   'formattedAddress': '55 River Rd, Apt 22, Manchester, NH 03104',
#   'id': '55-River-Rd,-Apt-22,-Manchester,-NH-03104',
#   'latitude': 43.004356,
#   'longitude': -71.468414,
#   'state': 'NH',
#   'zipCode': '03104'},
#  {'addressLine1': '1566 Benik Rd',
#   'assessorID': '8267-006-020',
#   'bathrooms': 3,
#   'bedrooms': 4,
#   'city': 'La Habra Heights',
#   'county': 'Los Angeles',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'pool': True,
#                'roomCount': 13,
#                'unitCount': 1},
#   'formattedAddress': '1566 Benik Rd, La Habra Heights, CA 90631',
#   'id': '1566-Benik-Rd,-La-Habra-Heights,-CA-90631',
#   'latitude': 33.952166,
#   'legalDescription': 'PARCEL MAP 41-92 EX OF ST LOT 2',
#   'longitude': -117.939409,
#   'lotSize': 36796,
#   'owner': {'mailingAddress': {'addressLine1': '1566 Benik Rd',
#                                'city': 'La Habra Heights',
#                                'id': '1566-Benik-Rd,-La-Habra-Heights,-CA-90631',
#                                'state': 'CA',
#                                'zipCode': '90631'},
#             'names': ['BRIAN S BERGMAN']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 10344}},
#   'propertyType': 'Single Family',
#   'squareFootage': 3641,
#   'state': 'CA',
#   'subdivision': 'LA HABRA HEIGHTS TR',
#   'taxAssessment': {'2019': {'improvements': 600561,
#                              'land': 238709,
#                              'value': 839270}},
#   'yearBuilt': 1977,
#   'zipCode': '90631',
#   'zoning': 'LHRA1*'},
#  {'addressLine1': '10715 38th Ave N',
#   'assessorID': '13-118-22-33-0036',
#   'bathrooms': 2,
#   'bedrooms': 4,
#   'city': 'Minneapolis',
#   'county': 'Hennepin',
#   'features': {'architectureType': 'Split Entry',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Metal',
#                'fireplace': True,
#                'floorCount': 1,
#                'foundationType': 'Block',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 5,
#                'unitCount': 1},
#   'formattedAddress': '10715 38th Ave N, Minneapolis, MN 55441',
#   'id': '10715-38th-Ave-N,-Minneapolis,-MN-55441',
#   'lastSaleDate': '1992-02-01T00:00:00.000Z',
#   'lastSalePrice': 136900,
#   'latitude': 45.024846,
#   'legalDescription': '005 004 WELLINGTON ADDN 105 X 155',
#   'longitude': -93.416757,
#   'lotSize': 16117,
#   'owner': {'mailingAddress': {'addressLine1': '10715 38th Ave N',
#                                'city': 'Plymouth',
#                                'formattedAddress': '10715 38th Ave N, '
#                                                    'Plymouth, MN 55441',
#                                'id': '10715-38th-Ave-N,-Plymouth,-MN-55441',
#                                'state': 'MN',
#                                'zipCode': '55441'},
#             'names': ['Lori M Raabe'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 4835}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1384,
#   'state': 'MN',
#   'subdivision': 'WELLINGTON ADDN',
#   'taxAssessment': {'2023': {'improvements': 290500,
#                              'land': 136000,
#                              'value': 426500}},
#   'yearBuilt': 1979,
#   'zipCode': '55441'},
#  {'addressLine1': '5747 Virginia Ave',
#   'assessorID': '5536-006-004',
#   'bathrooms': 2,
#   'bedrooms': 4,
#   'city': 'Los Angeles',
#   'county': 'Los Angeles',
#   'features': {'architectureType': 'Duplex',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'unitCount': 2},
#   'formattedAddress': '5747 Virginia Ave, Los Angeles, CA 90038',
#   'id': '5747-Virginia-Ave,-Los-Angeles,-CA-90038',
#   'lastSaleDate': '1999-11-24T00:00:00.000Z',
#   'lastSalePrice': 155000,
#   'latitude': 34.092065,
#   'legalDescription': 'MANSFIELDS LINCOLN TRACT LOT 63',
#   'longitude': -118.315232,
#   'lotSize': 7500,
#   'owner': {'mailingAddress': {'addressLine1': '5747 Virginia Ave',
#                                'city': 'Los Angeles',
#                                'formattedAddress': '5747 Virginia Ave, Los '
#                                                    'Angeles, CA 90038',
#                                'id': '5747-Virginia-Ave,-Los-Angeles,-CA-90038',
#                                'state': 'CA',
#                                'zipCode': '90038'},
#             'names': ['Luisa R Valladares']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 3977}, '2023': {'total': 4183}},
#   'propertyType': 'Duplex-Triplex',
#   'squareFootage': 1740,
#   'state': 'CA',
#   'subdivision': 'MANSFIELDS LINCOLN TRACT',
#   'taxAssessment': {'2020': {'improvements': 68086,
#                              'land': 238688,
#                              'value': 306774},
#                     '2023': {'improvements': 71569,
#                              'land': 250902,
#                              'value': 322471}},
#   'yearBuilt': 1912,
#   'zipCode': '90038',
#   'zoning': 'LAR3'},
#  {'addressLine1': '27 Jackson St',
#   'addressLine2': '# 1-109',
#   'bathrooms': 1,
#   'bedrooms': 1,
#   'city': 'Lowell',
#   'county': 'Middlesex',
#   'formattedAddress': '27 Jackson St, # 1-109, Lowell, MA 01852',
#   'id': '27-Jackson-St,---1-109,-Lowell,-MA-01852',
#   'latitude': 42.642839,
#   'longitude': -71.310904,
#   'propertyType': 'Apartment',
#   'squareFootage': 1324,
#   'state': 'MA',
#   'zipCode': '01852'},
#  {'addressLine1': '3101 Sunset Ridge Ct',
#   'assessorID': '218505326001',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'Glenwood Springs',
#   'county': 'Garfield',
#   'features': {'architectureType': 'Condo / Apartment',
#                'exteriorType': 'Brick / Stone',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'OTHER',
#                'roomCount': 4,
#                'unitCount': 1},
#   'formattedAddress': '3101 Sunset Ridge Ct, Glenwood Springs, CO 81601',
#   'id': '3101-Sunset-Ridge-Ct,-Glenwood-Springs,-CO-81601',
#   'latitude': 39.562227,
#   'legalDescription': 'SECTION: 5 TOWNSHIP: 6 RANGE: 89 DESC: BUILDING C. '
#                       'AMENDED PLAT OF LOT 3. SUBDIVISION: SUNSET RIDGE VILLAS '
#                       'UNIT: 3101',
#   'longitude': -107.349832,
#   'owner': {'mailingAddress': {'addressLine1': '14692 Nw Glacier Ln',
#                                'city': 'Beaverton',
#                                'formattedAddress': '14692 Nw Glacier Ln, '
#                                                    'Beaverton, OR 97006',
#                                'id': '14692-Nw-Glacier-Ln,-Beaverton,-OR-97006',
#                                'state': 'OR',
#                                'zipCode': '97006'},
#             'names': ['Ann E S Pleau']},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2023': {'total': 1608}},
#   'propertyType': 'Condo',
#   'squareFootage': 916,
#   'state': 'CO',
#   'subdivision': 'SUNSET RIDGE VILLAS',
#   'taxAssessment': {'2023': {'improvements': 22270, 'value': 22270}},
#   'yearBuilt': 1999,
#   'zipCode': '81601'},
#  {'addressLine1': '455 Eddy St',
#   'addressLine2': 'Apt E602',
#   'city': 'San Francisco',
#   'county': 'San Francisco',
#   'features': {},
#   'formattedAddress': '455 Eddy St, Apt E602, San Francisco, CA 94109',
#   'id': '455-Eddy-St,-Apt-E602,-San-Francisco,-CA-94109',
#   'latitude': 37.782901,
#   'longitude': -122.420747,
#   'state': 'CA',
#   'zipCode': '94109'},
#  {'addressLine1': 'PO Box 317',
#   'city': 'Savage',
#   'county': 'Scott',
#   'features': {},
#   'formattedAddress': 'PO Box 317, Savage, MN 55378',
#   'id': 'PO-Box-317,-Savage,-MN-55378',
#   'latitude': 44.756626,
#   'longitude': -93.3639,
#   'state': 'MN',
#   'zipCode': '55378'},
#  {'addressLine1': '603 Highlands Dr',
#   'assessorID': '218505113002',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Glenwood Springs',
#   'county': 'Garfield',
#   'features': {'exteriorType': 'Stucco',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Hot Water',
#                'roofType': 'Composition Shingle',
#                'roomCount': 8,
#                'unitCount': 1},
#   'formattedAddress': '603 Highlands Dr, Glenwood Springs, CO 81601',
#   'id': '603-Highlands-Dr,-Glenwood-Springs,-CO-81601',
#   'lastSaleDate': '1998-07-20T00:00:00.000Z',
#   'lastSalePrice': 110000,
#   'latitude': 39.565278,
#   'legalDescription': 'SECTION: 5 TOWNSHIP: 6 RANGE: 89 SUBDIVISION: GLENWOOD '
#                       'HIGHLANDS EST AMD LOT: 2',
#   'longitude': -107.338809,
#   'lotSize': 43560,
#   'owner': {'mailingAddress': {'addressLine1': '603 Highlands Dr',
#                                'city': 'Glenwood Springs',
#                                'formattedAddress': '603 Highlands Dr, Glenwood '
#                                                    'Springs, CO 81601',
#                                'id': '603-Highlands-Dr,-Glenwood-Springs,-CO-81601',
#                                'state': 'CO',
#                                'zipCode': '81601'},
#             'names': ['Mccarty Kathleen M', 'Merrill Dale A'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 4417}},
#   'propertyType': 'Single Family',
#   'squareFootage': 3043,
#   'state': 'CO',
#   'subdivision': 'GLENWOOD HIGHLANDS EST AMD',
#   'taxAssessment': {'2023': {'improvements': 51980,
#                              'land': 15890,
#                              'value': 67870}},
#   'yearBuilt': 1998,
#   'zipCode': '81601'},
#  {'addressLine1': '924 Duncan Ave',
#   'assessorID': '48-00-01443-00',
#   'bathrooms': 1,
#   'bedrooms': 3,
#   'city': 'Lansdowne',
#   'county': 'Delaware',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 2,
#                'heating': True,
#                'heatingType': 'Central',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '924 Duncan Ave, Lansdowne, PA 19050',
#   'id': '924-Duncan-Ave,-Lansdowne,-PA-19050',
#   'latitude': 39.928547,
#   'legalDescription': 'DIST:48 CITY/MUNI/TWP:YEADON BORO MAP REF:48-09 '
#                       '-071-010',
#   'longitude': -75.251055,
#   'lotSize': 1960,
#   'owner': {'mailingAddress': {'addressLine1': '924 Duncan Ave',
#                                'city': 'Lansdowne',
#                                'formattedAddress': '924 Duncan Ave, Lansdowne, '
#                                                    'PA 19050',
#                                'id': '924-Duncan-Ave,-Lansdowne,-PA-19050',
#                                'state': 'PA',
#                                'zipCode': '19050'},
#             'names': ['Gordon Decis M', 'Gordon Michael G'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 4026}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1324,
#   'state': 'PA',
#   'taxAssessment': {'2023': {'improvements': 74110,
#                              'land': 31800,
#                              'value': 105910},
#                     '2024': {'improvements': 74110,
#                              'land': 31800,
#                              'value': 105910}},
#   'yearBuilt': 1930,
#   'zipCode': '19050'},
#  {'addressLine1': '119 Beach Cove Dr',
#   'assessorID': '41B  A     2C',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'White Stone',
#   'county': 'Lancaster',
#   'features': {'cooling': True,
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 1,
#                'foundationType': 'Pier',
#                'heating': True,
#                'heatingType': 'Heat Pump',
#                'roofType': 'Composition Shingle',
#                'roomCount': 4},
#   'formattedAddress': '119 Beach Cove Dr, White Stone, VA 22578',
#   'id': '119-Beach-Cove-Dr,-White-Stone,-VA-22578',
#   'lastSaleDate': '2012-07-19T00:00:00.000Z',
#   'lastSalePrice': 225000,
#   'latitude': 37.615262,
#   'legalDescription': 'BEACH COVE VILLAS INT IN 3.86 AC LR12/1578 PB6/44-45',
#   'longitude': -76.287241,
#   'lotSize': 168142,
#   'owner': {'mailingAddress': {'addressLine1': '2163 Gold Mine Rd',
#                                'city': 'Palmyra',
#                                'id': '2163-Gold-Mine-Rd,-Palmyra,-VA-22963',
#                                'state': 'VA',
#                                'zipCode': '22963'},
#             'names': ['DONNA K MURRAY']},
#   'propertyType': 'Condo',
#   'squareFootage': 1086,
#   'state': 'VA',
#   'taxAssessment': {'2019': {'improvements': 123000,
#                              'land': 70000,
#                              'value': 193000}},
#   'yearBuilt': 1999,
#   'zipCode': '22578',
#   'zoning': 'A1'},
#  {'addressLine1': '778 Addis St',
#   'assessorID': '05-046600',
#   'bathrooms': 1.5,
#   'bedrooms': 2,
#   'city': 'New Castle',
#   'county': 'Lawrence',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Wood',
#                'floorCount': 2,
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 4},
#   'formattedAddress': '778 Addis St, New Castle, PA 16101',
#   'id': '778-Addis-St,-New-Castle,-PA-16101',
#   'lastSaleDate': '1998-11-20T00:00:00.000Z',
#   'lastSalePrice': 15000,
#   'latitude': 40.982997,
#   'legalDescription': 'L 328 59 X 123 APT-G 328',
#   'longitude': -80.327636,
#   'lotSize': 7405,
#   'owner': {'mailingAddress': {'addressLine1': '778 Addis St',
#                                'city': 'New Castle',
#                                'formattedAddress': '778 Addis St, New Castle, '
#                                                    'PA 16101',
#                                'id': '778-Addis-St,-New-Castle,-PA-16101',
#                                'state': 'PA',
#                                'zipCode': '16101'},
#             'names': ['William A Forkey'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 2484}, '2023': {'total': 2491}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2376,
#   'state': 'PA',
#   'subdivision': 'GASTON PARK AREA',
#   'taxAssessment': {'2022': {'improvements': 56500,
#                              'land': 7300,
#                              'value': 63800},
#                     '2023': {'improvements': 56500,
#                              'land': 7300,
#                              'value': 63800},
#                     '2024': {'improvements': 56500,
#                              'land': 7300,
#                              'value': 63800}},
#   'yearBuilt': 1950,
#   'zipCode': '16101',
#   'zoning': 'R'},
#  {'addressLine1': '106 Hunter Ridge Ct',
#   'assessorID': '2-5003-01600',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Boiling Springs',
#   'county': 'Spartanburg',
#   'features': {'architectureType': 'Raised Ranch',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Wood',
#                'floorCount': 1,
#                'foundationType': 'Brick',
#                'garage': True,
#                'garageType': 'Garage',
# ...
#                'roofType': 'Tile',
#                'unitCount': 1},
#   'formattedAddress': '43787 W Colby Dr, Maricopa, AZ 85138',
#   'id': '43787-W-Colby-Dr,-Maricopa,-AZ-85138',
#   'lastSaleDate': '2014-05-28T00:00:00.000Z',
#   'lastSalePrice': 108500,
#   'latitude': 33.073537,
#   'legalDescription': 'PARCEL 2A AT RANCHO EL DORADO LOT 134 CAB C SLD 184 SEC '
#                       '15-4S-3E 5035 SQ FT .12 AC',
#   'longitude': -112.038276,
#   'lotSize': 5227,
#   'owner': {'mailingAddress': {'addressLine1': '43787 W Colby Dr',
#                                'city': 'Maricopa',
#                                'formattedAddress': '43787 W Colby Dr, '
#                                                    'Maricopa, AZ 85138',
#                                'id': '43787-W-Colby-Dr,-Maricopa,-AZ-85138',
#                                'state': 'AZ',
#                                'zipCode': '85138'},
#             'names': ['Joanna Cooper Vanderpool']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 1203},
#                     '2021': {'total': 1261},
#                     '2022': {'total': 1320},
#                     '2023': {'total': 1359}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1277,
#   'state': 'AZ',
#   'subdivision': 'PARCEL 2A AT RANCHO EL DORADO',
#   'taxAssessment': {'2022': {'improvements': 9841,
#                              'land': 3136,
#                              'value': 12977},
#                     '2023': {'improvements': 12852,
#                              'land': 6795,
#                              'value': 19647},
#                     '2024': {'improvements': 14448,
#                              'land': 10454,
#                              'value': 24902},
#                     '2025': {'improvements': 12162,
#                              'land': 9409,
#                              'value': 21571}},
#   'yearBuilt': 2002,
#   'zipCode': '85138'},
#  {'addressLine1': '37 Edgebrook Cir',
#   'assessorID': '163627',
#   'bathrooms': 2.5,
#   'bedrooms': 3,
#   'city': 'Durham',
#   'county': 'Durham',
#   'features': {'architectureType': 'Townhouse',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'fireplace': True,
#                'floorCount': 1,
#                'heating': True,
#                'heatingType': 'Package',
#                'unitCount': 1},
#   'formattedAddress': '37 Edgebrook Cir, Durham, NC 27703',
#   'id': '37-Edgebrook-Cir,-Durham,-NC-27703',
#   'lastSaleDate': '2003-11-21T00:00:00.000Z',
#   'lastSalePrice': 131000,
#   'latitude': 35.938961,
#   'legalDescription': 'TAYLOR ESTATES TWNHMS/PH: 01-02/LT#078 MODEL-EVERG '
#                       'PL000156-000083',
#   'longitude': -78.845711,
#   'lotSize': 1307,
#   'owner': {'mailingAddress': {'addressLine1': '3108 Broomsedge Way',
#                                'city': 'Durham',
#                                'formattedAddress': '3108 Broomsedge Way, '
#                                                    'Durham, NC 27712',
#                                'id': '3108-Broomsedge-Way,-Durham,-NC-27712',
#                                'state': 'NC',
#                                'zipCode': '27712'},
#             'names': ['Megan Andrews', 'Robert Andrews', 'Megan E Palm'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 2023}, '2023': {'total': 2131}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1440,
#   'state': 'NC',
#   'subdivision': 'TAYLOR ESTATES',
#   'taxAssessment': {'2020': {'improvements': 122652,
#                              'land': 40000,
#                              'value': 162652},
#                     '2023': {'improvements': 122652,
#                              'land': 40000,
#                              'value': 162652}},
#   'yearBuilt': 2003,
#   'zipCode': '27703',
#   'zoning': 'RS-M(D)'},
#  {'addressLine1': '398 Ralph Still Rd',
#   'bathrooms': 4,
#   'bedrooms': 5,
#   'city': 'Dacula',
#   'county': 'Walton',
#   'formattedAddress': '398 Ralph Still Rd, Dacula, GA 30019',
#   'id': '398-Ralph-Still-Rd,-Dacula,-GA-30019',
#   'latitude': 33.906933,
#   'longitude': -83.814764,
#   'lotSize': 40075,
#   'propertyType': 'Single Family',
#   'squareFootage': 3166,
#   'state': 'GA',
#   'yearBuilt': 2023,
#   'zipCode': '30019'},
#  {'addressLine1': '59 Cedarlyn Dr',
#   'assessorID': '33-000-11-0021.00-00000',
#   'bathrooms': 3.5,
#   'bedrooms': 4,
#   'city': 'York',
#   'county': 'York',
#   'features': {'architectureType': 'Colonial',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Wood Shingle',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 8,
#                'unitCount': 1},
#   'formattedAddress': '59 Cedarlyn Dr, York, PA 17408',
#   'id': '59-Cedarlyn-Dr,-York,-PA-17408',
#   'lastSaleDate': '2010-05-14T00:00:00.000Z',
#   'lastSalePrice': 254900,
#   'latitude': 39.907562,
#   'legalDescription': 'LOT 21; FARM LANE ESTATES; BK/PG 1763-7688',
#   'longitude': -76.840982,
#   'lotSize': 15551,
#   'owner': {'mailingAddress': {'addressLine1': '59 Cedarlyn Dr',
#                                'city': 'York',
#                                'id': '59-Cedarlyn-Dr,-York,-PA-17408',
#                                'state': 'PA',
#                                'zipCode': '17408'},
#             'names': ['JAMES W SHAFFER', 'ANNE M SHAFFER']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 6695},
#                     '2021': {'total': 6695},
#                     '2023': {'total': 6999}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2645,
#   'state': 'PA',
#   'subdivision': 'FARM LANE ESTATES',
#   'taxAssessment': {'2020': {'improvements': 134255,
#                              'land': 79180,
#                              'value': 213435},
#                     '2021': {'improvements': 134255,
#                              'land': 79180,
#                              'value': 213435},
#                     '2023': {'improvements': 134255,
#                              'land': 79180,
#                              'value': 213435}},
#   'yearBuilt': 2007,
#   'zipCode': '17408',
#   'zoning': 'R-3'},
#  {'addressLine1': 'PO Box 350134',
#   'city': 'Grand Island',
#   'county': 'Lake',
#   'features': {},
#   'formattedAddress': 'PO Box 350134, Grand Island, FL 32735',
#   'id': 'PO-Box-350134,-Grand-Island,-FL-32735',
#   'latitude': 28.889142,
#   'longitude': -81.736164,
#   'state': 'FL',
#   'zipCode': '32735'},
#  {'addressLine1': '4 Townview Dr',
#   'assessorID': '0504 05270000',
#   'bathrooms': 1.5,
#   'bedrooms': 3,
#   'city': 'West Grove',
#   'county': 'Chester',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 2,
#                'heating': True,
#                'heatingType': 'Heat Pump',
#                'roomCount': 5},
#   'formattedAddress': '4 Townview Dr, West Grove, PA 19390',
#   'id': '4-Townview-Dr,-West-Grove,-PA-19390',
#   'lastSaleDate': '2015-07-01T00:00:00.000Z',
#   'lastSalePrice': 103000,
#   'latitude': 39.817595,
#   'legalDescription': 'UNIT 4 & DWG',
#   'longitude': -75.824591,
#   'lotSize': 1802,
#   'owner': {'mailingAddress': {'addressLine1': '5 Peter Christopher Dr',
#                                'city': 'Landenberg',
#                                'formattedAddress': '5 Peter Christopher Dr, '
#                                                    'Landenberg, PA 19350',
#                                'id': '5-Peter-Christopher-Dr,-Landenberg,-PA-19350',
#                                'state': 'PA',
#                                'zipCode': '19350'},
#             'names': ['Timothy W Sheehan', 'Kimberly Sheehan'],
#             'type': 'Individual'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2022': {'total': 2931},
#                     '2023': {'total': 3004},
#                     '2024': {'total': 3062}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1440,
#   'state': 'PA',
#   'subdivision': 'HEATHER HEIGHTS BLDG GROUP A',
#   'taxAssessment': {'2022': {'improvements': 50370,
#                              'land': 17680,
#                              'value': 68050},
#                     '2023': {'improvements': 50370,
#                              'land': 17680,
#                              'value': 68050},
#                     '2024': {'improvements': 50370,
#                              'land': 17680,
#                              'value': 68050}},
#   'yearBuilt': 1976,
#   'zipCode': '19390',
#   'zoning': 'R3C'},
#  {'addressLine1': '7130 Wind River Dr',
#   'assessorID': '060-004307',
#   'bathrooms': 1,
#   'bedrooms': 3,
#   'city': 'Reynoldsburg',
#   'county': 'Franklin',
#   'features': {'architectureType': 'Ranch',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick / Stone',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Gas',
#                'roomCount': 7,
#                'unitCount': 1},
#   'formattedAddress': '7130 Wind River Dr, Reynoldsburg, OH 43068',
#   'id': '7130-Wind-River-Dr,-Reynoldsburg,-OH-43068',
#   'lastSaleDate': '2017-01-09T00:00:00.000Z',
#   'lastSalePrice': 64502,
#   'latitude': 39.969305,
#   'legalDescription': 'WIND RIVER DR TREEBOURNE VILLAGE LOT 1',
#   'longitude': -82.809836,
#   'lotSize': 28053,
#   'owner': {'mailingAddress': {'addressLine1': '18117 Biscayne Blvd',
#                                'addressLine2': 'UNIT 2605',
#                                'city': 'Aventura',
#                                'formattedAddress': '18117 Biscayne Blvd, UNIT '
#                                                    '2605, Aventura, FL 33160',
#                                'id': '18117-Biscayne-Blvd,-UNIT-2605,-Aventura,-FL-33160',
#                                'state': 'FL',
#                                'zipCode': '33160'},
#             'names': ['WHITE PICKET PROPERTIES LLC'],
#             'type': 'Organization'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2019': {'total': 1693},
#                     '2020': {'total': 1839},
#                     '2022': {'total': 1795},
#                     '2023': {'total': 3579}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1104,
#   'state': 'OH',
#   'subdivision': 'TREEBOURNE VILLAGE',
#   'taxAssessment': {'2019': {'improvements': 8190,
#                              'land': 14390,
#                              'value': 22580},
#                     '2020': {'improvements': 9840,
#                              'land': 17260,
#                              'value': 27100},
#                     '2022': {'improvements': 9840,
#                              'land': 17260,
#                              'value': 27100},
#                     '2023': {'improvements': 32590,
#                              'land': 38850,
#                              'value': 71440}},
#   'yearBuilt': 1983,
#   'zipCode': '43068'},
#  {'addressLine1': '4353 Fairfax Ave',
#   'assessorID': '60084501340010000',
#   'bathrooms': 7,
#   'bedrooms': 5,
#   'city': 'Dallas',
#   'county': 'Dallas',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick Veneer',
#                'fireplace': True,
#                'floorCount': 2,
#                'foundationType': 'Pier / Post & Beam',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'pool': True,
#                'poolType': 'Pool and Hot Tub / Spa',
#                'roofType': 'Tile',
#                'unitCount': 1},
#   'formattedAddress': '4353 Fairfax Ave, Dallas, TX 75205',
#   'id': '4353-Fairfax-Ave,-Dallas,-TX-75205',
#   'lastSaleDate': '2020-09-01T00:00:00.000Z',
#   'latitude': 32.832864,
#   'legalDescription': 'HIGHLAND PARK BLK 134 LT 1 INT202000237061 DD08312020 '
#                       'CO-DC 0845013400100 16908450134',
#   'longitude': -96.81003,
#   'lotSize': 12060,
#   'owner': {'mailingAddress': {'addressLine1': '4353 Fairfax Ave',
#                                'city': 'Dallas',
#                                'formattedAddress': '4353 Fairfax Ave, Dallas, '
#                                                    'TX 75205',
#                                'id': '4353-Fairfax-Ave,-Dallas,-TX-75205',
#                                'state': 'TX',
#                                'zipCode': '75205'},
#             'names': ['Charles Howard Korrell'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 50573}},
#   'propertyType': 'Single Family',
#   'squareFootage': 6498,
#   'state': 'TX',
#   'subdivision': 'HIGHLAND PARK',
#   'taxAssessment': {'2023': {'improvements': 1708220,
#                              'land': 2170800,
#                              'value': 3879020}},
#   'yearBuilt': 2021,
#   'zipCode': '75205',
#   'zoning': 'Z228'},
#  {'addressLine1': '16510 Espinosa Dr',
#   'assessorID': '5040-01-002-0170-907',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Houston',
#   'county': 'Fort Bend',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick / Stone',
#                'fireplace': True,
#                'fireplaceType': 'Prefab',
#                'floorCount': 1,
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '16510 Espinosa Dr, Houston, TX 77083',
#   'id': '16510-Espinosa-Dr,-Houston,-TX-77083',
#   'lastSaleDate': '2021-09-14T00:00:00.000Z',
#   'latitude': 29.698759,
#   'legalDescription': 'MISSION WEST SEC 1, BLOCK 2, LOT 17',
#   'longitude': -95.678233,
#   'lotSize': 6107,
#   'owner': {'mailingAddress': {'addressLine1': '16510 Espinosa Dr',
#                                'city': 'Houston',
#                                'formattedAddress': '16510 Espinosa Dr, '
#                                                    'Houston, TX 77083',
#                                'id': '16510-Espinosa-Dr,-Houston,-TX-77083',
#                                'state': 'TX',
#                                'zipCode': '77083'},
#             'names': ['Granillo Payes Adanilson'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2018': {'total': 2125},
#                     '2021': {'total': 2506},
#                     '2023': {'total': 3220}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1078,
#   'state': 'TX',
#   'subdivision': 'MISSION WEST SEC 1',
#   'taxAssessment': {'2022': {'improvements': 165430,
#                              'land': 23750,
#                              'value': 189180},
#                     '2023': {'improvements': 158578,
#                              'land': 54150,
#                              'value': 212728}},
#   'yearBuilt': 1982,
#   'zipCode': '77083'},
#  {'addressLine1': 'W 51st St',
#   'city': 'Sand Springs',
#   'county': 'Tulsa',
#   'formattedAddress': 'W 51st St, Sand Springs, OK 74063',
#   'id': 'W-51st-St,-Sand-Springs,-OK-74063',
#   'lastSaleDate': '2022-04-07T00:00:00.000Z',
#   'lastSalePrice': 437500,
#   'latitude': 36.089584,
#   'longitude': -96.115933,
#   'lotSize': 290589,
#   'propertyType': 'Land',
#   'state': 'OK',
#   'zipCode': '74063'},
#  {'addressLine1': '12424 Steeple Way Blvd',
#   'addressLine2': 'Apt 736',
#   'city': 'Houston',
#   'county': 'Harris',
#   'features': {},
#   'formattedAddress': '12424 Steeple Way Blvd, Apt 736, Houston, TX 77065',
#   'id': '12424-Steeple-Way-Blvd,-Apt-736,-Houston,-TX-77065',
#   'latitude': 29.905398,
#   'longitude': -95.589331,
#   'state': 'TX',
#   'zipCode': '77065'}]

# %%
data = response.json()

file_name = 'real_estate.json'

with open(file_name, 'w') as file:
    json.dump(data, file, indent=4)


#real_estate_df = pd.DataFrame([data])

real_estate_df = pd.read_json('real_estate.json')
real_estate_df.head()
# Out:
#    bathrooms  bedrooms  squareFootage       county   propertyType  \
# 0        1.0       2.0          930.0  Santa Clara  Single Family
# 1        5.0       6.0         3318.0    Albemarle  Single Family
# 2        1.5       3.0         1452.0         Lake  Single Family
# 3        3.0       3.0         1518.0   Miami-Dade          Condo
# 4        1.0       2.0         1117.0         Kern           Land
#
#           addressLine1         city state  zipCode  \
# 0    1042 Riverside Dr     San Jose    CA    95125
# 1     6909 Windmere Ln       Crozet    VA    22932
# 2  38320 N Chicago Ave    Wadsworth    IL    60083
# 3    2050 Sw 122nd Ave        Miami    FL    33175
# 4    3008 Crestline Rd  Bakersfield    CA    93306
#
#                              formattedAddress  ...  lotSize  \
# 0       1042 Riverside Dr, San Jose, CA 95125  ...   4945.0
# 1          6909 Windmere Ln, Crozet, VA 22932  ...  20081.0
# 2    38320 N Chicago Ave, Wadsworth, IL 60083  ...  13504.0
# 3  2050 Sw 122nd Ave, Apt 22, Miami, FL 33175  ...      NaN
# 4    3008 Crestline Rd, Bakersfield, CA 93306  ...   7405.0
#
#                                        taxAssessment  \
# 0  {'2023': {'value': 1039359, 'land': 936360, 'i...
# 1  {'2021': {'value': 674100, 'land': 225700, 'im...
# 2  {'2022': {'value': 49413, 'land': 5739, 'impro...
# 3  {'2020': {'value': 195000}, '2021': {'value': ...
# 4  {'2019': {'value': 36250, 'land': 9640, 'impro...
#
#                                        propertyTaxes lastSalePrice  \
# 0                         {'2023': {'total': 13416}}      999000.0
# 1  {'2020': {'total': 5801}, '2024': {'total': 83...      675000.0
# 2                          {'2022': {'total': 2127}}           NaN
# 3  {'2020': {'total': 3467}, '2022': {'total': 43...      310000.0
# 4  {'2019': {'total': 1126}, '2023': {'total': 13...           NaN
#
#                lastSaleDate  \
# 0  2021-04-02T00:00:00.000Z
# 1  2016-06-03T00:00:00.000Z
# 2                       NaN
# 3  2022-01-14T00:00:00.000Z
# 4                       NaN
#
#                                                owner  \
# 0  {'names': ['Allison J Brooks', 'WILLIAM PETERM...
# 1  {'names': ['Patrick R Latimer', 'KATHERINE A L...
# 2  {'names': ['TRUST 38320'], 'mailingAddress': {...
# 3  {'names': ['Carlos Cortes Bayardo', 'Cecilia C...
# 4  {'names': ['PATRICIA TOPPING'], 'mailingAddres...
#
#                                            id   longitude   latitude  \
# 0       1042-Riverside-Dr,-San-Jose,-CA-95125 -121.900219  37.312376
# 1          6909-Windmere-Ln,-Crozet,-VA-22932  -78.716506  38.067079
# 2    38320-N-Chicago-Ave,-Wadsworth,-IL-60083  -87.924063  42.418909
# 3  2050-Sw-122nd-Ave,-Apt-22,-Miami,-FL-33175  -80.391202  25.748550
# 4    3008-Crestline-Rd,-Bakersfield,-CA-93306 -118.951116  35.378973
#
#   addressLine2
# 0          NaN
# 1          NaN
# 2          NaN
# 3       Apt 22
# 4          NaN
#
# [5 rows x 27 columns]

# %%
real_estate_df.columns
# Out:
# Index(['bathrooms', 'bedrooms', 'squareFootage', 'county', 'propertyType',
#        'addressLine1', 'city', 'state', 'zipCode', 'formattedAddress',
#        'yearBuilt', 'features', 'assessorID', 'legalDescription',
#        'subdivision', 'zoning', 'ownerOccupied', 'lotSize', 'taxAssessment',
#        'propertyTaxes', 'lastSalePrice', 'lastSaleDate', 'owner', 'id',
#        'longitude', 'latitude', 'addressLine2'],
#       dtype='object')

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bathrooms         375 non-null    float64
#  1   bedrooms          344 non-null    float64
#  2   squareFootage     387 non-null    float64
#  3   county            499 non-null    object
#  4   propertyType      410 non-null    object
#  5   addressLine1      500 non-null    object
#  6   city              500 non-null    object
#  7   state             500 non-null    object
#  8   zipCode           500 non-null    int64
#  9   formattedAddress  500 non-null    object
#  10  yearBuilt         369 non-null    float64
#  11  features          452 non-null    object
#  12  assessorID        354 non-null    object
#  13  legalDescription  347 non-null    object
#  14  subdivision       312 non-null    object
#  15  zoning            180 non-null    object
#  16  ownerOccupied     326 non-null    float64
#  17  lotSize           356 non-null    float64
#  18  taxAssessment     352 non-null    object
#  19  propertyTaxes     339 non-null    object
#  20  lastSalePrice     243 non-null    float64
#  21  lastSaleDate      303 non-null    object
#  22  owner             352 non-null    object
#  23  id                500 non-null    object
#  24  longitude         500 non-null    float64
#  25  latitude          500 non-null    float64
#  26  addressLine2      107 non-null    object
# dtypes: float64(9), int64(1), object(17)
# memory usage: 105.6+ KB

# %% [markdown]
# ### Transformation layer
