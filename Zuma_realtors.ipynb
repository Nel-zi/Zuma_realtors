# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from dotenv import load_dotenv
import os
import requests
from pprint import pprint
import psycopg2
import json

# %% [markdown]
# ### Data Extraction

# %%
# Load environment variables from the .env file
load_dotenv()

# Retrieve environment variables
rapidapi_key = os.getenv('RAPIDAPI_KEY')
rapidapi_host = os.getenv('RAPIDAPI_HOST')

# Define the headers using the variables
headers = {
    'x-rapidapi-key': rapidapi_key,
    'x-rapidapi-host': rapidapi_host,
}

# API request details
url = "https://realty-mole-property-api.p.rapidapi.com/randomProperties"
querystring = {"limit": "500"}

# Make the API request
response = requests.get(url, headers=headers, params=querystring)

# Print the response
pprint(response.json())
# Out:
# [{'addressLine1': '3157 Rosebay Ln',
#   'assessorID': 'B01-56J- -G-00106',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Bartlett',
#   'county': 'Shelby',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick Veneer',
#                'fireplace': True,
#                'fireplaceType': 'Single',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Carport',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'roomCount': 7,
#                'unitCount': 1},
#   'formattedAddress': '3157 Rosebay Ln, Bartlett, TN 38134',
#   'id': '3157-Rosebay-Ln,-Bartlett,-TN-38134',
#   'latitude': 35.21184,
#   'legalDescription': 'WS ROSEBAY LANE',
#   'longitude': -89.866508,
#   'lotSize': 9975,
#   'owner': {'mailingAddress': {'addressLine1': '3548 Skylight Dr E',
#                                'city': 'Bartlett',
#                                'id': '3548-Skylight-Dr-E,-Bartlett,-TN-38135',
#                                'state': 'TN',
#                                'zipCode': '38135'},
#             'names': ['BRANNICK DAISY L TRUST ONE A']},
#   'propertyTaxes': {'2022': {'total': 1429}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1761,
#   'state': 'TN',
#   'subdivision': 'WILDWOOD MANOR REV SEC A',
#   'taxAssessment': {'2023': {'improvements': 34475,
#                              'land': 7675,
#                              'value': 42150}},
#   'yearBuilt': 1973,
#   'zipCode': '38134',
#   'zoning': 'RS-10'},
#  {'addressLine1': '410 Silver Pine Trl',
#   'assessorID': '12 267106760531',
#   'bathrooms': 2.5,
#   'bedrooms': 4,
#   'city': 'Roswell',
#   'county': 'Fulton',
#   'features': {'architectureType': 'Colonial',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Wood',
#                'fireplace': True,
#                'fireplaceType': 'Prefab',
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 9,
#                'unitCount': 1},
#   'formattedAddress': '410 Silver Pine Trl, Roswell, GA 30076',
#   'id': '410-Silver-Pine-Trl,-Roswell,-GA-30076',
#   'latitude': 34.0045,
#   'legalDescription': 'ANNEXATION KITCHEN RENOVATION NVC',
#   'longitude': -84.301676,
#   'lotSize': 11587,
#   'owner': {'mailingAddress': {'addressLine1': '410 Silver Pine Trl',
#                                'city': 'Roswell',
#                                'formattedAddress': '410 Silver Pine Trl, '
#                                                    'Roswell, GA 30076',
#                                'id': '410-Silver-Pine-Trl,-Roswell,-GA-30076',
#                                'state': 'GA',
#                                'zipCode': '30076'},
#             'names': ['GERKER FAMILY TRUST', 'GERKER JANE LOUISE TR'],
#             'type': 'Organization'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 4374}, '2023': {'total': 4828}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2664,
#   'state': 'GA',
#   'subdivision': 'WOODFIELD AT MARTINS LANDING',
#   'taxAssessment': {'2022': {'improvements': 125920,
#                              'land': 29040,
#                              'value': 154960},
#                     '2023': {'improvements': 123320,
#                              'land': 47720,
#                              'value': 171040}},
#   'yearBuilt': 1979,
#   'zipCode': '30076',
#   'zoning': 'R1'},
#  {'addressLine1': '9803 Peddlers Way',
#   'assessorID': '07-22-31-3800-02-520',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Orlando',
#   'county': 'Orange',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Stucco',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '9803 Peddlers Way, Orlando, FL 32817',
#   'id': '9803-Peddlers-Way,-Orlando,-FL-32817',
#   'lastSaleDate': '1986-10-01T00:00:00.000Z',
#   'lastSalePrice': 84500,
#   'latitude': 28.591534,
#   'legalDescription': 'HUNTERS TRACE UNIT 3 14/78 LOT 252',
#   'longitude': -81.249395,
#   'lotSize': 7506,
#   'owner': {'mailingAddress': {'addressLine1': '9803 Peddlers Way',
#                                'city': 'Orlando',
#                                'formattedAddress': '9803 Peddlers Way, '
#                                                    'Orlando, FL 32817',
#                                'id': '9803-Peddlers-Way,-Orlando,-FL-32817',
#                                'state': 'FL',
#                                'zipCode': '32817'},
#             'names': ['RICHARD A SEFICK',
#                       'BERENICE W SEFICK',
#                       'Sefick Family Revocable Trust',
#                       'BERENICE W SEFICK'],
#             'type': 'Organization'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 1406}, '2023': {'total': 1489}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1440,
#   'state': 'FL',
#   'subdivision': 'HUNTERS TRACE UT 3',
#   'taxAssessment': {'2021': {'value': 102525},
#                     '2022': {'value': 105601},
#                     '2023': {'value': 108769}},
#   'yearBuilt': 1986,
#   'zipCode': '32817',
#   'zoning': 'R-1A'},
#  {'addressLine1': '2140 Hammerle St',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'West Linn',
#   'county': 'Clackamas',
#   'features': {},
#   'formattedAddress': '2140 Hammerle St, West Linn, OR 97068',
#   'id': '2140-Hammerle-St,-West-Linn,-OR-97068',
#   'latitude': 45.370764,
#   'longitude': -122.625382,
#   'propertyType': 'Single Family',
#   'squareFootage': 2526,
#   'state': 'OR',
#   'zipCode': '97068'},
#  {'addressLine1': '2124 Landside Dr',
#   'assessorID': 'U1829219S5000001000070',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Valrico',
#   'county': 'Hillsborough',
#   'features': {'architectureType': 'Contemporary',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Stucco',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '2124 Landside Dr, Valrico, FL 33594',
#   'id': '2124-Landside-Dr,-Valrico,-FL-33594',
#   'lastSaleDate': '2014-05-07T00:00:00.000Z',
#   'lastSalePrice': 244900,
#   'latitude': 27.962256,
#   'legalDescription': 'BONVIDA LOT 7 BLOCK 1',
#   'longitude': -82.250749,
#   'lotSize': 8995,
#   'owner': {'mailingAddress': {'addressLine1': '2124 Landside Dr',
#                                'city': 'Valrico',
#                                'formattedAddress': '2124 Landside Dr, Valrico, '
#                                                    'FL 33594',
#                                'id': '2124-Landside-Dr,-Valrico,-FL-33594',
#                                'state': 'FL',
#                                'zipCode': '33594'},
#             'names': ['Giovanni S Solorzano', 'Claudia Solorzano']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 3823}, '2023': {'total': 4006}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2104,
#   'state': 'FL',
#   'subdivision': 'BONVIDA',
#   'taxAssessment': {'2021': {'value': 212818},
#                     '2022': {'value': 219203},
#                     '2023': {'value': 225779}},
#   'yearBuilt': 2014,
#   'zipCode': '33594',
#   'zoning': 'PD'},
#  {'addressLine1': '4076 Day Trl S',
#   'assessorID': '15 029 05 052',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Ellenwood',
#   'county': 'Dekalb',
#   'features': {'architectureType': 'Split Level',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Wood',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'unitCount': 1},
#   'formattedAddress': '4076 Day Trl S, Ellenwood, GA 30294',
#   'id': '4076-Day-Trl-S,-Ellenwood,-GA-30294',
#   'latitude': 33.66164,
#   'legalDescription': 'CITY/MUNI/TWP:UNINCORPORATED',
#   'longitude': -84.229978,
#   'lotSize': 13068,
#   'owner': {'mailingAddress': {'addressLine1': '1508 Brookhollow Dr',
#                                'city': 'Santa Ana',
#                                'formattedAddress': '1508 Brookhollow Dr, Santa '
#                                                    'Ana, CA 92705',
#                                'id': '1508-Brookhollow-Dr,-Santa-Ana,-CA-92705',
#                                'state': 'CA',
#                                'zipCode': '92705'},
#             'names': ['TAH 2018-1 BORROWER LLC'],
#             'type': 'Organization'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2022': {'total': 3337}, '2023': {'total': 4630}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1672,
#   'state': 'GA',
#   'subdivision': 'CHIMNE RIDGE',
#   'taxAssessment': {'2022': {'improvements': 60440,
#                              'land': 7320,
#                              'value': 67760},
#                     '2023': {'improvements': 78360,
#                              'land': 18000,
#                              'value': 96360}},
#   'yearBuilt': 1986,
#   'zipCode': '30294',
#   'zoning': 'R100'},
#  {'addressLine1': '618 Whispering Waters Ave',
#   'assessorID': '020043078',
#   'bathrooms': 2,
#   'bedrooms': 4,
#   'city': 'Gonzales',
#   'county': 'Ascension',
#   'features': {},
#   'formattedAddress': '618 Whispering Waters Ave, Gonzales, LA 70737',
#   'id': '618-Whispering-Waters-Ave,-Gonzales,-LA-70737',
#   'lastSaleDate': '2022-05-09T00:00:00.000Z',
#   'lastSalePrice': 256970,
#   'latitude': 30.228683,
#   'legalDescription': 'LOT 18 WATERS COVE SUBDIVISION',
#   'longitude': -90.926352,
#   'owner': {'mailingAddress': {'addressLine1': '618 Whispering Waters Ave',
#                                'city': 'Gonzales',
#                                'formattedAddress': '618 Whispering Waters Ave, '
#                                                    'Gonzales, LA 70737',
#                                'id': '618-Whispering-Waters-Ave,-Gonzales,-LA-70737',
#                                'state': 'LA',
#                                'zipCode': '70737'},
#             'names': ['J Rodriguez Cruz Zain', 'Yanci L Ellias']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 2767}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1782,
#   'state': 'LA',
#   'subdivision': 'WATERS COVE SUBDIVISION',
#   'taxAssessment': {'2023': {'improvements': 19420,
#                              'land': 4800,
#                              'value': 24220}},
#   'zipCode': '70737'},
#  {'addressLine1': '11852 Tar Heel Trl',
#   'assessorID': '03-25-403-003',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Rockton',
#   'county': 'Winnebago',
#   'features': {'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 2,
#                'heating': True,
#                'heatingType': 'Gas',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '11852 Tar Heel Trl, Rockton, IL 61072',
#   'id': '11852-Tar-Heel-Trl,-Rockton,-IL-61072',
#   'lastSaleDate': '2010-02-24T00:00:00.000Z',
#   'lastSalePrice': 221500,
#   'latitude': 42.43144,
#   'legalDescription': 'OLD RIVER HILLS NO 3 PT SE1/4 SEC 25-46-1 LOT 69',
#   'longitude': -89.066406,
#   'lotSize': 13504,
#   'owner': {'mailingAddress': {'addressLine1': '11852 Tar Heel Trl',
#                                'city': 'Rockton',
#                                'id': '11852-Tar-Heel-Trl,-Rockton,-IL-61072',
#                                'state': 'IL',
#                                'zipCode': '61072'},
#             'names': ['BRANDON M WELLS', 'BRITTANY E WELLS']},
#   'ownerOccupied': True,
#   'propertyType': 'Single Family',
#   'squareFootage': 1118,
#   'state': 'IL',
#   'subdivision': 'OLD RIVER HILLS 03',
#   'taxAssessment': {'2022': {'improvements': 72409,
#                              'land': 17093,
#                              'value': 89502}},
#   'yearBuilt': 2005,
#   'zipCode': '61072',
#   'zoning': 'R1 RESIDENTIAL SING FAM'},
#  {'addressLine1': '2201 E Berry St',
#   'addressLine2': 'Apt 1914',
#   'city': 'Fort Worth',
#   'county': 'Tarrant',
#   'features': {},
#   'formattedAddress': '2201 E Berry St, Apt 1914, Fort Worth, TX 76119',
#   'id': '2201-E-Berry-St,-Apt-1914,-Fort-Worth,-TX-76119',
#   'latitude': 32.707101,
#   'longitude': -97.299095,
#   'state': 'TX',
#   'zipCode': '76119'},
#  {'addressLine1': '3110 Mount Charleston Dr',
#   'city': 'Pahrump',
#   'county': 'Nye',
#   'features': {},
#   'formattedAddress': '3110 Mount Charleston Dr, Pahrump, NV 89048',
#   'id': '3110-Mount-Charleston-Dr,-Pahrump,-NV-89048',
#   'latitude': 36.196073,
#   'longitude': -116.001746,
#   'state': 'NV',
#   'zipCode': '89048'},
#  {'addressLine1': '840 Ivy Point Ln',
#   'assessorID': '144GC019',
#   'bathrooms': 2.5,
#   'bedrooms': 3,
#   'city': 'Knoxville',
#   'county': 'Knox',
#   'features': {'architectureType': 'Contemporary',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Brick',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'roomCount': 9,
#                'unitCount': 1},
#   'formattedAddress': '840 Ivy Point Ln, Knoxville, TN 37922',
#   'id': '840-Ivy-Point-Ln,-Knoxville,-TN-37922',
#   'lastSaleDate': '1996-08-05T00:00:00.000Z',
#   'lastSalePrice': 247500,
#   'latitude': 35.886441,
#   'legalDescription': 'SUBDIVISIONNAME WOODLAND SPRINGS UNIT 3 MAPPLATB M-390 '
#                       'MAPPLATP D DIMENSIONS 100 X 220.52 X IRR',
#   'longitude': -84.089734,
#   'lotSize': 22052,
#   'owner': {'mailingAddress': {'addressLine1': '840 Ivy Point Ln',
#                                'city': 'Knoxville',
#                                'formattedAddress': '840 Ivy Point Ln, '
#                                                    'Knoxville, TN 37922',
#                                'id': '840-Ivy-Point-Ln,-Knoxville,-TN-37922',
#                                'state': 'TN',
#                                'zipCode': '37922'},
#             'names': ['David L Mccord', 'IRIS A MCCORD']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 1794}},
#   'propertyType': 'Single Family',
#   'squareFootage': 3136,
#   'state': 'TN',
#   'subdivision': 'WOODLAND SPRINGS UNIT 3',
#   'taxAssessment': {'2023': {'value': 115425}},
#   'yearBuilt': 1995,
#   'zipCode': '37922'},
#  {'addressLine1': '102 E La Verne Way',
#   'assessorID': '009-605-811',
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'city': 'Palm Springs',
#   'county': 'Riverside',
#   'features': {'architectureType': 'Condo / Apartment',
#                'cooling': True,
#                'coolingType': 'Central',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Tile',
#                'unitCount': 1},
#   'formattedAddress': '102 E La Verne Way, Palm Springs, CA 92264',
#   'id': '102-E-La-Verne-Way,-Palm-Springs,-CA-92264',
#   'lastSaleDate': '2014-08-12T00:00:00.000Z',
#   'lastSalePrice': 240000,
#   'latitude': 33.794402,
#   'legalDescription': 'PI PSL 221',
#   'longitude': -116.545287,
#   'lotSize': 3049,
#   'owner': {'mailingAddress': {'addressLine1': '708 La',
#                                'addressLine2': 'ESTRELLA',
#                                'city': 'Palm Springs',
#                                'formattedAddress': '708 La, ESTRELLA, Palm '
#                                                    'Springs, CA 92264',
#                                'id': '708-La,-ESTRELLA,-Palm-Springs,-CA-92264',
#                                'state': 'CA',
#                                'zipCode': '92264'},
#             'names': ['Andrew Leighton', 'Brian Marki'],
#             'type': 'Individual'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2020': {'total': 4008},
#                     '2021': {'total': 4190},
#                     '2022': {'total': 4274},
#                     '2023': {'total': 4268}},
#   'propertyType': 'Condo',
#   'squareFootage': 1855,
#   'state': 'CA',
#   'taxAssessment': {'2020': {'improvements': 197807,
#                              'land': 104394,
#                              'value': 302201},
#                     '2021': {'improvements': 199856,
#                              'land': 105475,
#                              'value': 305331},
#                     '2022': {'improvements': 203853,
#                              'land': 107584,
#                              'value': 311437},
#                     '2023': {'improvements': 207930,
#                              'land': 109735,
#                              'value': 317665}},
#   'yearBuilt': 1979,
#   'zipCode': '92264',
#   'zoning': 'R2'},
#  {'addressLine1': '4090 E 119th Pl',
#   'addressLine2': 'Apt A',
#   'assessorID': 'R0072545',
#   'bathrooms': 3,
#   'bedrooms': 3,
#   'city': 'Thornton',
#   'county': 'Adams',
#   'features': {'architectureType': 'Townhouse',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'fireplace': True,
#                'fireplaceType': 'Gas Log',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'roomCount': 4,
#                'unitCount': 1},
#   'formattedAddress': '4090 E 119th Pl, Apt A, Thornton, CO 80233',
#   'id': '4090-E-119th-Pl,-Apt-A,-Thornton,-CO-80233',
#   'lastSaleDate': '2019-02-20T00:00:00.000Z',
#   'lastSalePrice': 290000,
#   'latitude': 39.911342,
#   'legalDescription': 'SUB:OAKSHIRE TOWNHOME SUBD BLK:3 LOT:16',
#   'longitude': -104.939076,
#   'lotSize': 2178,
#   'owner': {'mailingAddress': {'addressLine1': '4090 E 119th Pl',
#                                'addressLine2': 'APT A',
#                                'city': 'Thornton',
#                                'formattedAddress': '4090 E 119th Pl, APT A, '
#                                                    'Thornton, CO 80233',
#                                'id': '4090-E-119th-Pl,-APT-A,-Thornton,-CO-80233',
#                                'state': 'CO',
#                                'zipCode': '80233'},
#             'names': ['Jelena Estrada', 'Rudy Estrada'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 3019}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1100,
#   'state': 'CO',
#   'subdivision': 'OAKSHIRE TOWNHOME',
#   'taxAssessment': {'2023': {'improvements': 23810,
#                              'land': 3860,
#                              'value': 27670}},
#   'yearBuilt': 1998,
#   'zipCode': '80233'},
#  {'addressLine1': '714 Market St',
#   'addressLine2': 'Apt B',
#   'city': 'Lexington',
#   'county': 'Davidson',
#   'features': {},
#   'formattedAddress': '714 Market St, Apt B, Lexington, NC 27292',
#   'id': '714-Market-St,-Apt-B,-Lexington,-NC-27292',
#   'latitude': 35.822239,
#   'longitude': -80.268079,
#   'state': 'NC',
#   'zipCode': '27292'},
#  {'addressLine1': '5115 Dover Center Rd',
#   'assessorID': '235-01-083',
#   'bathrooms': 1,
#   'bedrooms': 3,
#   'city': 'North Olmsted',
#   'county': 'Cuyahoga',
#   'features': {'architectureType': 'Ranch',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 1,
#                'foundationType': 'Raised',
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '5115 Dover Center Rd, North Olmsted, OH 44070',
#   'id': '5115-Dover-Center-Rd,-North-Olmsted,-OH-44070',
#   'lastSaleDate': '2023-10-20T00:00:00.000Z',
#   'lastSalePrice': 250000,
#   'latitude': 41.415245,
#   'legalDescription': '21 BUTTERNUTHTS 0001 ALL MB235 PG01 MB PG MB PG',
#   'longitude': -81.922955,
#   'lotSize': 13125,
#   'owner': {'mailingAddress': {'addressLine1': '5115 Dover Center Rd',
#                                'city': 'North Olmsted',
#                                'formattedAddress': '5115 Dover Center Rd, '
#                                                    'North Olmsted, OH 44070',
#                                'id': '5115-Dover-Center-Rd,-North-Olmsted,-OH-44070',
#                                'state': 'OH',
#                                'zipCode': '44070'},
#             'names': ['Denise L Gilroy']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 3753}, '2023': {'total': 3773}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1440,
#   'state': 'OH',
#   'subdivision': 'BUTTERNUTHTS',
#   'taxAssessment': {'2022': {'improvements': 33110,
#                              'land': 13090,
#                              'value': 46200},
#                     '2023': {'improvements': 33110,
#                              'land': 13090,
#                              'value': 46200}},
#   'yearBuilt': 1954,
#   'zipCode': '44070'},
#  {'addressLine1': '6910 Dorothy Louise Dr',
#   'assessorID': '11618-008-1270',
#   'bathrooms': 2.5,
#   'bedrooms': 3,
#   'city': 'San Antonio',
#   'county': 'Bexar',
#   'features': {'architectureType': 'Contemporary',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Asbestos Shingle',
#                'fireplace': True,
#                'floorCount': 1,
#                'foundationType': 'Pier / Post & Beam',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 8,
#                'unitCount': 1},
#   'formattedAddress': '6910 Dorothy Louise Dr, San Antonio, TX 78229',
#   'id': '6910-Dorothy-Louise-Dr,-San-Antonio,-TX-78229',
#   'lastSaleDate': '2017-03-01T00:00:00.000Z',
#   'latitude': 29.498033,
#   'legalDescription': 'NCB 11618 BLK 8 LOT 127',
#   'longitude': -98.583383,
#   'lotSize': 19515,
#   'owner': {'mailingAddress': {'addressLine1': '2046 Babcock Rd',
#                                'city': 'San Antonio',
#                                'id': '2046-Babcock-Rd,-San-Antonio,-TX-78229',
#                                'state': 'TX',
#                                'zipCode': '78229'},
#             'names': ['JESUS M LEIJA', 'MARISOL B LEIJA']},
#   'propertyTaxes': {'2022': {'total': 6637}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2408,
#   'state': 'TX',
#   'subdivision': 'CONV A/S CODE',
#   'taxAssessment': {'2022': {'improvements': 167200,
#                              'land': 100920,
#                              'value': 268120},
#                     '2023': {'improvements': 170440,
#                              'land': 132930,
#                              'value': 303370}},
#   'yearBuilt': 1942,
#   'zipCode': '78229'},
#  {'addressLine1': '6500 Carrington Dr',
#   'assessorID': '0418401501',
#   'bathrooms': 3,
#   'city': 'Austin',
#   'county': 'Travis',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'fireplace': True,
#                'floorCount': 2,
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Detached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '6500 Carrington Dr, Austin, TX 78749',
#   'id': '6500-Carrington-Dr,-Austin,-TX-78749',
#   'lastSaleDate': '2002-02-20T00:00:00.000Z',
#   'latitude': 30.205337,
#   'legalDescription': 'LOT 1 BLK C CIRCLE C RANCH PHS B SEC 20-B',
#   'longitude': -97.885513,
#   'lotSize': 9065,
#   'owner': {'mailingAddress': {'addressLine1': '6500 Carrington Dr',
#                                'city': 'Austin',
#                                'formattedAddress': '6500 Carrington Dr, '
#                                                    'Austin, TX 78749',
#                                'id': '6500-Carrington-Dr,-Austin,-TX-78749',
#                                'state': 'TX',
#                                'zipCode': '78749'},
#             'names': ['Troy Fuller', 'Judy Fuller'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2017': {'total': 10218}, '2022': {'total': 10713}},
#   'propertyType': 'Single Family',
#   'squareFootage': 3588,
#   'state': 'TX',
#   'subdivision': 'CIRCLE C RANCH PHS B SEC 20-B',
#   'taxAssessment': {'2019': {'improvements': 410736,
#                              'land': 100000,
#                              'value': 510736},
#                     '2022': {'improvements': 722010,
#                              'land': 325000,
#                              'value': 1047010},
#                     '2023': {'improvements': 744573,
#                              'land': 325000,
#                              'value': 1069573}},
#   'yearBuilt': 2001,
#   'zipCode': '78749'},
#  {'addressLine1': '78 Blackbird Rd',
#   'city': 'Gillette',
#   'county': 'Campbell',
#   'features': {},
#   'formattedAddress': '78 Blackbird Rd, Gillette, WY 82716',
#   'id': '78-Blackbird-Rd,-Gillette,-WY-82716',
#   'latitude': 44.293112,
#   'longitude': -105.348448,
#   'state': 'WY',
#   'zipCode': '82716'},
#  {'addressLine1': '113 Balance',
#   'assessorID': '580-812-08',
#   'bathrooms': 5,
#   'bedrooms': 4,
#   'city': 'Irvine',
#   'county': 'Orange',
#   'features': {'garage': True, 'garageType': 'Garage'},
#   'formattedAddress': '113 Balance, Irvine, CA 92618',
#   'id': '113-Balance,-Irvine,-CA-92618',
#   'lastSaleDate': '2019-11-26T00:00:00.000Z',
#   'lastSalePrice': 1700000,
#   'latitude': 33.686619,
#   'legalDescription': 'N TR 17888 BLK LOT 30',
#   'longitude': -117.723667,
#   'lotSize': 6303,
#   'owner': {'mailingAddress': {'addressLine1': '113 BALANCE',
#                                'city': 'Irvine',
#                                'formattedAddress': '113 BALANCE, Irvine, CA '
#                                                    '92618',
#                                'id': '113-BALANCE,-Irvine,-CA-92618',
#                                'state': 'CA',
#                                'zipCode': '92618'},
#             'names': ['GARIBI FAMILY TRUST']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 33703}},
#   'propertyType': 'Single Family',
#   'squareFootage': 4501,
#   'state': 'CA',
#   'subdivision': 'ENCORE/CADENCE PARK PH 5',
#   'taxAssessment': {'2023': {'improvements': 1231175,
#                              'land': 579965,
#                              'value': 1811140}},
#   'yearBuilt': 2019,
#   'zipCode': '92618'},
#  {'addressLine1': '7523 Flint Crossing Cir SE',
#   'bathrooms': 4.5,
#   'bedrooms': 5,
#   'city': 'Owens Cross Roads',
#   'county': 'Madison County',
#   'formattedAddress': '7523 Flint Crossing Cir SE, Owens Cross Roads, AL 35763',
#   'id': '7523-Flint-Crossing-Cir-SE,-Owens-Cross-Roads,-AL-35763',
#   'latitude': 34.626859,
#   'longitude': -86.482666,
#   'lotSize': 11761,
#   'propertyType': 'Single Family',
#   'squareFootage': 3686,
#   'state': 'AL',
#   'zipCode': '35763'},
#  {'addressLine1': '6306 Avanti Dr',
#   'assessorID': '37925-16-6',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Arlington',
#   'county': 'Tarrant',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'unitCount': 1},
#   'formattedAddress': '6306 Avanti Dr, Arlington, TX 76001',
#   'id': '6306-Avanti-Dr,-Arlington,-TX-76001',
#   'lastSaleDate': '2021-09-15T00:00:00.000Z',
#   'lastSalePrice': None,
#   'latitude': 32.642545,
#   'legalDescription': 'SEVILLE HILLS SUBDIVISION BLOCK 16 LOT 6',
#   'longitude': -97.127854,
#   'lotSize': 6037,
#   'owner': {'mailingAddress': {'addressLine1': 'PO BOX 4090',
#                                'city': 'Scottsdale',
#                                'formattedAddress': 'PO BOX 4090, Scottsdale, '
#                                                    'AZ 85261',
#                                'id': 'PO-BOX-4090,-Scottsdale,-AZ-85261',
#                                'state': 'AZ',
#                                'zipCode': '85261'},
#             'names': ['YAMASA CO LTD'],
#             'type': 'Organization'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2023': {'total': 6048}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1414,
#   'state': 'TX',
#   'subdivision': 'SEVILLE HILLS SUBDIVISION',
#   'taxAssessment': {'2023': {'improvements': 225000,
#                              'land': 45000,
#                              'value': 270000}},
#   'yearBuilt': 1985,
#   'zipCode': '76001'},
#  {'addressLine1': '1510 14th Ave',
#   'assessorID': '05-35-330-010',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Belvidere',
#   'county': 'Boone',
#   'features': {'architectureType': 'Ranch / Rambler',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Wood Siding',
#                'fireplace': True,
#                'floorCount': 1,
#                'foundationType': 'Concrete',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'roomCount': 6},
#   'formattedAddress': '1510 14th Ave, Belvidere, IL 61008',
#   'id': '1510-14th-Ave,-Belvidere,-IL-61008',
#   'lastSaleDate': '2007-11-30T00:00:00.000Z',
#   'lastSalePrice': 147500,
#   'latitude': 42.245244,
#   'legalDescription': '35-44-3 SHEFFIELD GREEN 6 LT 10 BLK 19 1510 FOURTEENTH '
#                       'AVE',
#   'longitude': -88.856231,
#   'lotSize': 7841,
#   'owner': {'mailingAddress': {'addressLine1': '1510 14th Ave',
#                                'city': 'Belvidere',
#                                'id': '1510-14th-Ave,-Belvidere,-IL-61008',
#                                'state': 'IL',
#                                'zipCode': '61008'},
#             'names': ['WILLIAM L BRAGG']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 3164}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1170,
#   'state': 'IL',
#   'taxAssessment': {'2019': {'improvements': 29919,
#                              'land': 24224,
#                              'value': 54143}},
#   'yearBuilt': 1979,
#   'zipCode': '61008'},
#  {'addressLine1': '10270 E Taron Dr',
#   'addressLine2': 'Apt 377',
#   'city': 'Elk Grove',
#   'county': 'Sacramento',
#   'features': {},
#   'formattedAddress': '10270 E Taron Dr, Apt 377, Elk Grove, CA 95757',
#   'id': '10270-E-Taron-Dr,-Apt-377,-Elk-Grove,-CA-95757',
#   'latitude': 38.402071,
#   'longitude': -121.465259,
#   'state': 'CA',
#   'zipCode': '95757'},
#  {'addressLine1': '132 Charter Oak St',
#   'assessorID': 'MANC M:96 B:1080 L:132',
#   'bathrooms': 3,
#   'bedrooms': 6,
#   'city': 'Manchester',
#   'county': 'Hartford',
#   'features': {'architectureType': 'Duplex Single',
#                'exteriorType': 'Shingle',
#                'floorCount': 3,
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 12,
#                'unitCount': 2},
#   'formattedAddress': '132 Charter Oak St, Manchester, CT 06040',
#   'id': '132-Charter-Oak-St,-Manchester,-CT-06040',
#   'latitude': 41.763954,
#   'legalDescription': 'LOT:132 BLK:1080 CITY/MUNI/TWP:MANCHESTER',
#   'longitude': -72.514556,
#   'lotSize': 9583,
#   'owner': {'mailingAddress': {'addressLine1': 'PO BOX 9173',
#                                'city': 'Bolton',
#                                'formattedAddress': 'PO BOX 9173, Bolton, CT '
#                                                    '06043',
#                                'id': 'PO-BOX-9173,-Bolton,-CT-06043',
#                                'state': 'CT',
#                                'zipCode': '06043'},
#             'names': ['NOT AVAILABLE FROM COUNTY'],
#             'type': 'Organization'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2022': {'total': 6065},
#                     '2023': {'total': 6246},
#                     '2024': {'total': 6494}},
#   'propertyType': 'Duplex-Triplex',
#   'squareFootage': 2804,
#   'state': 'CT',
#   'taxAssessment': {'2022': {'improvements': 137000,
#                              'land': 30900,
#                              'value': 167900},
#                     '2023': {'improvements': 137000,
#                              'land': 30900,
#                              'value': 167900},
#                     '2024': {'improvements': 137000,
#                              'land': 30900,
#                              'value': 167900}},
#   'yearBuilt': 1895,
#   'zipCode': '06040',
#   'zoning': 'RB'},
#  {'addressLine1': '361 Royal Palm Way',
#   'assessorID': 'R31-223-18-3524-0000-0680',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Spring Hill',
#   'county': 'Hernando',
#   'features': {'architectureType': 'Condo / Apartment',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Stucco',
#                'floorCount': 1,
#                'foundationType': 'OTHER',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Package',
#                'roofType': 'Composition Shingle',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '361 Royal Palm Way, Spring Hill, FL 34608',
#   'id': '361-Royal-Palm-Way,-Spring-Hill,-FL-34608',
#   'lastSaleDate': '2023-11-01T00:00:00.000Z',
#   'lastSalePrice': 309000,
#   'latitude': 28.4408,
#   'legalDescription': 'LOT 68 PALMS AT SEVEN HILLS',
#   'longitude': -82.551077,
#   'lotSize': 6930,
#   'owner': {'mailingAddress': {'addressLine1': '361 Royal Palm Way',
#                                'city': 'Spring Hill',
#                                'id': '361-Royal-Palm-Way,-Spring-Hill,-FL-34608',
#                                'state': 'FL',
#                                'zipCode': '34608'},
#             'names': ['JAMES H BELDEN', 'JILL C BELDEN']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 1594}, '2022': {'total': 3407}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1784,
#   'state': 'FL',
#   'subdivision': 'SEVEN HILLS',
#   'taxAssessment': {'2020': {'value': 98519},
#                     '2022': {'improvements': 199336,
#                              'land': 17879,
#                              'value': 217215}},
#   'yearBuilt': 2003,
#   'zipCode': '34608'},
#  {'addressLine1': '1434 Sierra Springs Dr',
#   'addressLine2': 'Unit 535',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'Bedford',
#   'county': 'Tarrant County',
#   'formattedAddress': '1434 Sierra Springs Dr, Unit 535, Bedford, TX 76021',
#   'id': '1434-Sierra-Springs-Dr,-Unit-535,-Bedford,-TX-76021',
#   'latitude': 32.8401754,
#   'longitude': -97.1457615,
#   'propertyType': 'Apartment',
#   'squareFootage': 876,
#   'state': 'TX',
#   'zipCode': '76021'},
#  {'addressLine1': '5399 S Cerulean Ln',
#   'addressLine2': 'Unit 102',
#   'city': 'Saint George',
#   'county': 'Washington',
#   'features': {},
#   'formattedAddress': '5399 S Cerulean Ln, Unit 102, Saint George, UT 84790',
#   'id': '5399-S-Cerulean-Ln,-Unit-102,-Saint-George,-UT-84790',
#   'latitude': 37.016004,
#   'longitude': -113.598367,
#   'state': 'UT',
#   'zipCode': '84790'},
#  {'addressLine1': '3352 Hedrick Ln',
#   'assessorID': 'R-6892-001-199A-1',
#   'city': 'Princeton',
#   'county': 'Collin',
#   'features': {'architectureType': 'Mobile Home',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Carport'},
#   'formattedAddress': '3352 Hedrick Ln, Princeton, TX 75407',
#   'id': '3352-Hedrick-Ln,-Princeton,-TX-75407',
#   'latitude': 33.132072,
#   'legalDescription': 'ABS A0892 W D THOMPSON SURVEY, SHEET 1, TRACT 199 IMP '
#                       'ONLY, SN1: C3033TA, SN2: C3033TB, HUD1: TXS0575165, '
#                       'HUD2: TXS0169028',
#   'longitude': -96.526099,
#   'owner': {'mailingAddress': {'addressLine1': '3352 Hedrick Ln',
#                                'city': 'Princeton',
#                                'id': '3352-Hedrick-Ln,-Princeton,-TX-75407',
#                                'state': 'TX',
#                                'zipCode': '75407'},
#             'names': ['CLAYTON HILL']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 12}},
#   'propertyType': 'Manufactured',
#   'squareFootage': 1344,
#   'state': 'TX',
#   'subdivision': 'W D THOMPSON SURVEY',
#   'taxAssessment': {'2022': {'improvements': 12119, 'value': 12119}},
#   'yearBuilt': 1980,
#   'zipCode': '75407'},
#  {'addressLine1': '18 1/2 Virginia Ave',
#   'city': 'Enfield',
#   'county': 'Hartford',
#   'features': {},
#   'formattedAddress': '18 1/2 Virginia Ave, Enfield, CT 06082',
#   'id': '18-1-2-Virginia-Ave,-Enfield,-CT-06082',
#   'latitude': 42.011316,
#   'longitude': -72.595597,
#   'state': 'CT',
#   'zipCode': '06082'},
#  {'addressLine1': '307 E Black Butte Ave',
#   'assessorID': '151004 CD 06800',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Sisters',
#   'county': 'Deschutes',
#   'features': {'architectureType': 'Split Level',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Mixed'},
#   'formattedAddress': '307 E Black Butte Ave, Sisters, OR 97759',
#   'id': '307-E-Black-Butte-Ave,-Sisters,-OR-97759',
#   'lastSaleDate': '2020-10-16T00:00:00.000Z',
#   'lastSalePrice': 407500,
#   'latitude': 44.294611,
#   'legalDescription': 'KIT',
#   'longitude': -121.547329,
#   'lotSize': 5663,
#   'owner': {'mailingAddress': {'addressLine1': '307 E Black Butte Ave',
#                                'city': 'Sisters',
#                                'formattedAddress': '307 E Black Butte Ave, '
#                                                    'Sisters, OR 97759',
#                                'id': '307-E-Black-Butte-Ave,-Sisters,-OR-97759',
#                                'state': 'OR',
#                                'zipCode': '97759'},
#             'names': ['Janet Anne West'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 3348}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1504,
#   'state': 'OR',
#   'subdivision': 'SISTERS PARK PLACE',
#   'taxAssessment': {'2023': {'value': 202050}},
#   'yearBuilt': 2004,
#   'zipCode': '97759',
#   'zoning': 'GI'},
#  {'addressLine1': '10450 Beulah Lake Rd',
#   'city': 'Cottondale',
#   'county': 'Tuscaloosa',
#   'features': {},
#   'formattedAddress': '10450 Beulah Lake Rd, Cottondale, AL 35453',
#   'id': '10450-Beulah-Lake-Rd,-Cottondale,-AL-35453',
#   'latitude': 33.171278,
#   'longitude': -87.37666,
#   'state': 'AL',
#   'zipCode': '35453'},
#  {'addressLine1': '1000 Daniel Dr',
#   'assessorID': '206631',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Stanley',
#   'county': 'Gaston',
#   'features': {'architectureType': 'Modular',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 1,
#                'foundationType': 'Footing',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'roomCount': 7,
#                'unitCount': 1},
#   'formattedAddress': '1000 Daniel Dr, Stanley, NC 28164',
#   'id': '1000-Daniel-Dr,-Stanley,-NC-28164',
#   'lastSaleDate': '2014-12-16T00:00:00.000Z',
#   'lastSalePrice': 108000,
#   'latitude': 35.334537,
#   'legalDescription': 'SHADOWS OAKS L 17 14 071 014 93 000',
#   'longitude': -81.110179,
#   'lotSize': 20473,
#   'owner': {'mailingAddress': {'addressLine1': '1000 Daniel Dr',
#                                'city': 'Stanley',
#                                'id': '1000-Daniel-Dr,-Stanley,-NC-28164',
#                                'state': 'NC',
#                                'zipCode': '28164'},
#             'names': ['NATHANIEL THEEL']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 1289}},
#   'propertyType': 'Manufactured',
#   'squareFootage': 1316,
#   'state': 'NC',
#   'subdivision': 'SHADOWS OAKS',
#   'taxAssessment': {'2022': {'improvements': 124650,
#                              'land': 15500,
#                              'value': 140150}},
#   'yearBuilt': 2005,
#   'zipCode': '28164',
#   'zoning': 'RMD'},
#  {'addressLine1': '2728 Exposition',
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'city': 'Los Angeles',
#   'county': 'Los Angeles',
#   'formattedAddress': '2728 Exposition, Los Angeles, CA 90018',
#   'id': '2728-Exposition,-Los-Angeles,-CA-90018',
#   'latitude': 34.019939,
#   'longitude': -118.325951,
#   'lotSize': 4477,
#   'propertyType': 'Apartment',
#   'squareFootage': 810,
#   'state': 'CA',
#   'yearBuilt': 1982,
#   'zipCode': '90018'},
#  {'addressLine1': '3811 Carman Rd',
#   'assessorID': '013089 27.19-3-39.2',
#   'bathrooms': 2.5,
#   'bedrooms': 3,
#   'city': 'Schenectady',
#   'county': 'Albany',
#   'features': {'architectureType': 'Colonial',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Mixed',
#                'heating': True,
#                'heatingType': 'Central',
#                'roomCount': 7},
#   'formattedAddress': '3811 Carman Rd, Schenectady, NY 12303',
#   'id': '3811-Carman-Rd,-Schenectady,-NY-12303',
#   'lastSaleDate': '2017-11-13T00:00:00.000Z',
#   'lastSalePrice': 365000,
#   'latitude': 42.722158,
#   'legalDescription': 'LOT:39.002 BLK:3 SEC:27.19 DIST:013089 '
#                       'CITY/MUNI/TWP:GUILDERLAND (TOV)',
#   'longitude': -73.934213,
#   'lotSize': 20000,
#   'owner': {'mailingAddress': {'addressLine1': '108 Southwoods Ct',
#                                'city': 'Schenectady',
#                                'formattedAddress': '108 Southwoods Ct, '
#                                                    'Schenectady, NY 12306',
#                                'id': '108-Southwoods-Ct,-Schenectady,-NY-12306',
#                                'state': 'NY',
#                                'zipCode': '12306'},
#             'names': ['Domenico Albanese']},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2016': {'total': 8819}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1736,
#   'state': 'NY',
#   'subdivision': 'WILSON',
#   'taxAssessment': {'2023': {'improvements': 302000,
#                              'land': 75000,
#                              'value': 377000}},
#   'yearBuilt': 2014,
#   'zipCode': '12303',
#   'zoning': 'R20'},
#  {'addressLine1': '13393 Terraza Playa Cancun',
#   'assessorID': '373-512-23-00',
#   'bathrooms': 2.5,
#   'bedrooms': 4,
#   'city': 'San Diego',
#   'county': 'San Diego',
#   'features': {'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Garage',
#                'unitCount': 1},
#   'formattedAddress': '13393 Terraza Playa Cancun, San Diego, CA 92124',
#   'id': '13393-Terraza-Playa-Cancun,-San-Diego,-CA-92124',
#   'lastSaleDate': '2013-06-24T00:00:00.000Z',
#   'lastSalePrice': 590000,
#   'latitude': 32.838663,
#   'legalDescription': 'TR 12269 LOT 42',
#   'longitude': -117.08385,
#   'lotSize': 6755,
#   'owner': {'mailingAddress': {'addressLine1': '13393 TERRAZA PLAYA CANCUN',
#                                'city': 'San Diego',
#                                'formattedAddress': '13393 TERRAZA PLAYA '
#                                                    'CANCUN, San Diego, CA '
#                                                    '92124',
#                                'id': '13393-TERRAZA-PLAYA-CANCUN,-San-Diego,-CA-92124',
#                                'state': 'CA',
#                                'zipCode': '92124'},
#             'names': ['George W Menzer', 'Wanaporn Menzer'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 9757},
#                     '2022': {'total': 9831},
#                     '2023': {'total': 10105}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2104,
#   'state': 'CA',
#   'subdivision': 'TIERRASANTA NORTE I UNIT #4',
#   'taxAssessment': {'2021': {'improvements': 575317,
#                              'land': 214071,
#                              'value': 789388},
#                     '2022': {'improvements': 586823,
#                              'land': 218352,
#                              'value': 805175},
#                     '2023': {'improvements': 598559,
#                              'land': 222719,
#                              'value': 821278}},
#   'yearBuilt': 1991,
#   'zipCode': '92124',
#   'zoning': 'R-1:SINGLE FAM-RES'},
#  {'addressLine1': '133 Nancy Ct',
#   'assessorID': '161-10-02-056',
#   'bathrooms': 1.5,
#   'bedrooms': 3,
#   'city': 'Radcliff',
#   'county': 'Hardin',
#   'features': {'architectureType': 'Split Level',
#                'exteriorType': 'Frame / Masonry',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central'},
#   'formattedAddress': '133 Nancy Ct, Radcliff, KY 40160',
#   'id': '133-Nancy-Ct,-Radcliff,-KY-40160',
#   'lastSaleDate': '2015-09-09T00:00:00.000Z',
#   'lastSalePrice': 117500,
#   'latitude': 37.823988,
#   'legalDescription': 'PEARMAN MNR LT 56 #1',
#   'longitude': -85.942876,
#   'lotSize': 27443,
#   'owner': {'mailingAddress': {'addressLine1': '133 Nancy Ct',
#                                'city': 'Radcliff',
#                                'id': '133-Nancy-Ct,-Radcliff,-KY-40160',
#                                'state': 'KY',
#                                'zipCode': '40160'},
#             'names': ['REBECCA J ESTES', 'LARRY D ESTES']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 150}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1704,
#   'state': 'KY',
#   'subdivision': 'PEARMAN MNR LT 56 #1',
#   'taxAssessment': {'2022': {'improvements': 126200,
#                              'land': 18700,
#                              'value': 144900}},
#   'yearBuilt': 1974,
#   'zipCode': '40160'},
#  {'addressLine1': '24 Greystone Way',
#   'assessorID': 'NHTN M:21 B:1 L:27',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'North Hampton',
#   'county': 'Rockingham',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 5},
#   'formattedAddress': '24 Greystone Way, North Hampton, NH 03862',
#   'id': '24-Greystone-Way,-North-Hampton,-NH-03862',
#   'lastSaleDate': '2007-10-19T00:00:00.000Z',
#   'lastSalePrice': 224900,
#   'latitude': 42.99865,
#   'legalDescription': 'LOT:27 BLK:1 CITY/MUNI/TWP:NORTH HAMPTON',
#   'longitude': -70.808554,
#   'owner': {'mailingAddress': {'addressLine1': '24 Greystone Way',
#                                'city': 'North Hampton',
# ...
#   'longitude': -81.978485,
#   'owner': {'mailingAddress': {'addressLine1': '2410 Briarwood Dr',
#                                'city': 'North Ridgeville',
#                                'id': '2410-Briarwood-Dr,-North-Ridgeville,-OH-44039',
#                                'state': 'OH',
#                                'zipCode': '44039'},
#             'names': ['DAHN STACEY A YOUNG']},
#   'propertyTaxes': {'2022': {'total': 5192}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2334,
#   'state': 'OH',
#   'subdivision': 'RIDGEFIELD HOMES INC SUBDIVISION #5',
#   'taxAssessment': {'2022': {'improvements': 68850,
#                              'land': 28800,
#                              'value': 97650}},
#   'yearBuilt': 2010,
#   'zipCode': '44039'},
#  {'addressLine1': '311 Weisinger Dr',
#   'assessorID': '9495-03-02300',
#   'bathrooms': 2.5,
#   'bedrooms': 3,
#   'city': 'Magnolia',
#   'county': 'Montgomery',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick',
#                'fireplace': True,
#                'fireplaceType': 'Prefab',
#                'floorCount': 1,
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle'},
#   'formattedAddress': '311 Weisinger Dr, Magnolia, TX 77354',
#   'id': '311-Weisinger-Dr,-Magnolia,-TX-77354',
#   'lastSaleDate': '2021-01-07T00:00:00.000Z',
#   'latitude': 30.224919,
#   'legalDescription': 'WESTWOOD 03, BLOCK 1, LOT 23',
#   'longitude': -95.566186,
#   'lotSize': 20000,
#   'owner': {'mailingAddress': {'addressLine1': '311 Weisinger Dr',
#                                'city': 'Magnolia',
#                                'formattedAddress': '311 Weisinger Dr, '
#                                                    'Magnolia, TX 77354',
#                                'id': '311-Weisinger-Dr,-Magnolia,-TX-77354',
#                                'state': 'TX',
#                                'zipCode': '77354'},
#             'names': ['Timothy E Eason', 'Georgetta L Eason']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 75}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2631,
#   'state': 'TX',
#   'subdivision': 'WESTWOOD 03',
#   'taxAssessment': {'2022': {'improvements': 440110,
#                              'land': 82650,
#                              'value': 425400},
#                     '2023': {'improvements': 453760,
#                              'land': 80000,
#                              'value': 467940}},
#   'yearBuilt': 2015,
#   'zipCode': '77354',
#   'zoning': '2'},
#  {'addressLine1': '2605 Hiland Ave',
#   'assessorID': '740128531',
#   'bathrooms': 3,
#   'bedrooms': 4,
#   'city': 'Falls City',
#   'county': 'Richardson',
#   'features': {'architectureType': 'Ranch',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'OTHER',
#                'fireplace': True,
#                'floorCount': 1,
#                'foundationType': 'OTHER',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'roomCount': 7},
#   'formattedAddress': '2605 Hiland Ave, Falls City, NE 68355',
#   'id': '2605-Hiland-Ave,-Falls-City,-NE-68355',
#   'latitude': 40.071013,
#   'legalDescription': 'FALLS CITY KE MOREHEAD BLK 3 LOTS 25-28 (4L)',
#   'longitude': -95.611179,
#   'lotSize': 12000,
#   'owner': {'mailingAddress': {'addressLine1': '2605 Hiland Ave',
#                                'city': 'Falls City',
#                                'formattedAddress': '2605 Hiland Ave, Falls '
#                                                    'City, NE 68355',
#                                'id': '2605-Hiland-Ave,-Falls-City,-NE-68355',
#                                'state': 'NE',
#                                'zipCode': '68355'},
#             'names': ['Trst Kevin L Malone', 'JANET M MALONE']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 5899}, '2023': {'total': 4987}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1918,
#   'state': 'NE',
#   'taxAssessment': {'2022': {'improvements': 283215,
#                              'land': 24000,
#                              'value': 307215},
#                     '2023': {'improvements': 293518,
#                              'land': 10500,
#                              'value': 304018}},
#   'yearBuilt': 1996,
#   'zipCode': '68355',
#   'zoning': '01-SINGLE FAMILY'},
#  {'addressLine1': '630 N Franklin St',
#   'addressLine2': 'Apt 721',
#   'assessorID': '17-09-222-020-1085',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'Chicago',
#   'county': 'Cook',
#   'features': {'architectureType': 'Condo / Apartment'},
#   'formattedAddress': '630 N Franklin St, Apt 721, Chicago, IL 60654',
#   'id': '630-N-Franklin-St,-Apt-721,-Chicago,-IL-60654',
#   'lastSaleDate': '2005-11-14T00:00:00.000Z',
#   'lastSalePrice': 375000,
#   'latitude': 41.893401,
#   'legalDescription': 'DIST:74 CITY/MUNI/TWP:NORTH CHICAGO',
#   'longitude': -87.636022,
#   'lotSize': 24240,
#   'owner': {'mailingAddress': {'addressLine1': '630 N Franklin St',
#                                'city': 'Wilmette',
#                                'formattedAddress': '630 N Franklin St, '
#                                                    'Wilmette, IL 60091',
#                                'id': '630-N-Franklin-St,-Wilmette,-IL-60091',
#                                'state': 'IL',
#                                'zipCode': '60091'},
#             'names': ['AAKP LLC']},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2018': {'total': 6490}, '2022': {'total': 8721}},
#   'propertyType': 'Condo',
#   'squareFootage': 1200,
#   'state': 'IL',
#   'subdivision': '630 N FRANKLIN CONDOS',
#   'taxAssessment': {'2018': {'improvements': 34050,
#                              'land': 2238,
#                              'value': 36288},
#                     '2022': {'improvements': 39497,
#                              'land': 2902,
#                              'value': 42399}},
#   'yearBuilt': 2005,
#   'zipCode': '60654'},
#  {'addressLine1': '820 E Brinker Dr',
#   'assessorID': '500-22-013',
#   'city': 'Avondale',
#   'county': 'Maricopa',
#   'features': {},
#   'formattedAddress': '820 E Brinker Dr, Avondale, AZ 85323',
#   'id': '820-E-Brinker-Dr,-Avondale,-AZ-85323',
#   'latitude': 33.440699,
#   'longitude': -112.340231,
#   'lotSize': 6600,
#   'propertyType': 'Duplex-Triplex',
#   'squareFootage': 2400,
#   'state': 'AZ',
#   'yearBuilt': 1966,
#   'zipCode': '85323'},
#  {'addressLine1': '2850 75th St W',
#   'addressLine2': 'Apt 6',
#   'city': 'Bradenton',
#   'county': 'Manatee',
#   'features': {},
#   'formattedAddress': '2850 75th St W, Apt 6, Bradenton, FL 34209',
#   'id': '2850-75th-St-W,-Apt-6,-Bradenton,-FL-34209',
#   'latitude': 27.474641,
#   'longitude': -82.637979,
#   'state': 'FL',
#   'zipCode': '34209'},
#  {'addressLine1': '818 S Michigan St',
#   'addressLine2': 'Apt 4',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'Alton',
#   'county': 'Hidalgo',
#   'formattedAddress': '818 S Michigan St, Apt 4, Alton, TX 78573',
#   'id': '818-S-Michigan-St,-Apt-4,-Alton,-TX-78573',
#   'latitude': 26.280657,
#   'longitude': -98.327179,
#   'propertyType': 'Apartment',
#   'state': 'TX',
#   'zipCode': '78573'},
#  {'addressLine1': '1006 Terrace Acres Cir',
#   'assessorID': '09-09-32-1-000-076-000',
#   'bathrooms': 2,
#   'city': 'Auburn',
#   'county': 'Lee',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Brick',
#                'fireplace': True,
#                'floorCount': 1,
#                'foundationType': 'Slab / Mat / Raft',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 7,
#                'unitCount': 100},
#   'formattedAddress': '1006 Terrace Acres Cir, Auburn, AL 36830',
#   'id': '1006-Terrace-Acres-Cir,-Auburn,-AL-36830',
#   'lastSaleDate': '2012-09-28T00:00:00.000Z',
#   'lastSalePrice': 184000,
#   'latitude': 32.591959,
#   'legalDescription': 'LOT 15 TERRACE ACRES SD PB 5/34A AUBURN',
#   'longitude': -85.460394,
#   'owner': {'mailingAddress': {'addressLine1': '1006 Terrace Acres Cir',
#                                'city': 'Auburn',
#                                'formattedAddress': '1006 Terrace Acres Cir, '
#                                                    'Auburn, AL 36830',
#                                'id': '1006-Terrace-Acres-Cir,-Auburn,-AL-36830',
#                                'state': 'AL',
#                                'zipCode': '36830'},
#             'names': ['John R Goodin', 'Charlotte R Hendrix']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 1174}, '2023': {'total': 1526}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2061,
#   'state': 'AL',
#   'subdivision': 'TERRACE ACRES SD',
#   'taxAssessment': {'2018': {'value': 22720},
#                     '2023': {'improvements': 18346,
#                              'land': 10900,
#                              'value': 29246}},
#   'yearBuilt': 1961,
#   'zipCode': '36830'},
#  {'addressLine1': '39 Poplar Ln',
#   'bathrooms': 3,
#   'bedrooms': 5,
#   'city': 'Red Banks',
#   'county': 'Marshall',
#   'formattedAddress': '39 Poplar Ln, Red Banks, MS 38661',
#   'id': '39-Poplar-Ln,-Red-Banks,-MS-38661',
#   'latitude': 34.810594,
#   'longitude': -89.567084,
#   'lotSize': 70132,
#   'propertyType': 'Single Family',
#   'squareFootage': 3870,
#   'state': 'MS',
#   'yearBuilt': 2022,
#   'zipCode': '38661'},
#  {'addressLine1': '1090 Philadelphia Rd',
#   'assessorID': '030C-007',
#   'bathrooms': 3.5,
#   'city': 'Jasper',
#   'county': 'Pickens',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Composition',
#                'fireplace': True,
#                'floorCount': 2,
#                'foundationType': 'Masonry',
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'pool': True,
#                'roofType': 'Metal',
#                'roomCount': 5,
#                'unitCount': 1},
#   'formattedAddress': '1090 Philadelphia Rd, Jasper, GA 30143',
#   'id': '1090-Philadelphia-Rd,-Jasper,-GA-30143',
#   'lastSaleDate': '2015-05-22T00:00:00.000Z',
#   'lastSalePrice': 187000,
#   'latitude': 34.48043,
#   'legalDescription': 'DIST12 LL200,201 19.48AC HOUSE',
#   'longitude': -84.473579,
#   'lotSize': 848549,
#   'owner': {'mailingAddress': {'addressLine1': '1090 Philadelphia Rd',
#                                'city': 'Jasper',
#                                'formattedAddress': '1090 Philadelphia Rd, '
#                                                    'Jasper, GA 30143',
#                                'id': '1090-Philadelphia-Rd,-Jasper,-GA-30143',
#                                'state': 'GA',
#                                'zipCode': '30143'},
#             'names': ['Ryan T Kaul', 'Julie A Kaul'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 7494}, '2023': {'total': 6894}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2000,
#   'state': 'GA',
#   'subdivision': 'HAROLD W JOHNSON',
#   'taxAssessment': {'2021': {'improvements': 296099,
#                              'land': 47849,
#                              'value': 343948},
#                     '2023': {'improvements': 296099,
#                              'land': 47849,
#                              'value': 343948}},
#   'yearBuilt': 2016,
#   'zipCode': '30143',
#   'zoning': 'AG'},
#  {'addressLine1': '16423 Truxton St',
#   'assessorID': '0851640000018',
#   'bathrooms': 1,
#   'bedrooms': 3,
#   'city': 'Humble',
#   'county': 'Harris',
#   'features': {'architectureType': 'Traditional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Concrete Block',
#                'floorCount': 1,
#                'foundationType': 'Raised',
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Mixed',
#                'heating': True,
#                'heatingType': 'Central',
#                'roomCount': 5,
#                'unitCount': 1},
#   'formattedAddress': '16423 Truxton St, Humble, TX 77396',
#   'id': '16423-Truxton-St,-Humble,-TX-77396',
#   'lastSaleDate': '2010-06-15T00:00:00.000Z',
#   'latitude': 29.959585,
#   'legalDescription': 'LT 18 BLK 1 GLEN LEE PLACE SEC 1',
#   'longitude': -95.305287,
#   'lotSize': 7200,
#   'owner': {'mailingAddress': {'addressLine1': '2013 65th St',
#                                'city': 'Galveston',
#                                'formattedAddress': '2013 65th St, Galveston, '
#                                                    'TX 77551',
#                                'id': '2013-65th-St,-Galveston,-TX-77551',
#                                'state': 'TX',
#                                'zipCode': '77551'},
#             'names': ['Soto Maria Idolina', 'FLORES JOSE NERY']},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2019': {'total': 1901},
#                     '2020': {'total': 1069},
#                     '2022': {'total': 2633}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1368,
#   'state': 'TX',
#   'subdivision': 'GLEN LEE PLACE',
#   'taxAssessment': {'2020': {'improvements': 66288,
#                              'land': 17640,
#                              'value': 83928},
#                     '2022': {'improvements': 73777,
#                              'land': 36000,
#                              'value': 109777},
#                     '2023': {'improvements': 82250,
#                              'land': 44640,
#                              'value': 126890}},
#   'yearBuilt': 1955,
#   'zipCode': '77396'},
#  {'addressLine1': '149 Se 58th Ct',
#   'assessorID': '1S203BA-00600',
#   'bathrooms': 3,
#   'bedrooms': 4,
#   'city': 'Hillsboro',
#   'county': 'Washington',
#   'features': {'cooling': True,
#                'coolingType': 'Wall',
#                'exteriorType': 'Wood',
#                'fireplace': True,
#                'fireplaceType': 'Prefab',
#                'foundationType': 'Footing',
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'roofType': 'Wood Shingle',
#                'unitCount': 1},
#   'formattedAddress': '149 Se 58th Ct, Hillsboro, OR 97123',
#   'id': '149-Se-58th-Ct,-Hillsboro,-OR-97123',
#   'lastSaleDate': '2006-10-31T00:00:00.000Z',
#   'lastSalePrice': 367500,
#   'latitude': 45.519503,
#   'legalDescription': 'PRESTON MEADOWS, LOT 2, ACRES 0.14',
#   'longitude': -122.922061,
#   'lotSize': 6098,
#   'owner': {'mailingAddress': {'addressLine1': '149 Se 58th Ct',
#                                'city': 'Hillsboro',
#                                'formattedAddress': '149 Se 58th Ct, Hillsboro, '
#                                                    'OR 97123',
#                                'id': '149-Se-58th-Ct,-Hillsboro,-OR-97123',
#                                'state': 'OR',
#                                'zipCode': '97123'},
#             'names': ['Hung Chung', 'Hanh Vo'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 5506}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2040,
#   'state': 'OR',
#   'subdivision': 'PRESTON MEADOWS',
#   'taxAssessment': {'2023': {'value': 326840}},
#   'yearBuilt': 1995,
#   'zipCode': '97123',
#   'zoning': 'SFR-7'},
#  {'addressLine1': '5400 W Parmer Ln',
#   'addressLine2': 'Apt 523',
#   'city': 'Austin',
#   'county': 'Travis',
#   'features': {},
#   'formattedAddress': '5400 W Parmer Ln, Apt 523, Austin, TX 78727',
#   'id': '5400-W-Parmer-Ln,-Apt-523,-Austin,-TX-78727',
#   'latitude': 30.436525,
#   'longitude': -97.733233,
#   'state': 'TX',
#   'zipCode': '78727'}]

# %%
data = response.json()

file_name = 'real_estate.json'

with open(file_name, 'w') as file:
    json.dump(data, file, indent=4)


#real_estate_df = pd.DataFrame([data])

real_estate_df = pd.read_json('real_estate.json')
real_estate_df.head()
# Out:
#           addressLine1       city state  zipCode  \
# 0      3157 Rosebay Ln   Bartlett    TN    38134
# 1  410 Silver Pine Trl    Roswell    GA    30076
# 2    9803 Peddlers Way    Orlando    FL    32817
# 3     2140 Hammerle St  West Linn    OR    97068
# 4     2124 Landside Dr    Valrico    FL    33594
#
#                          formattedAddress  bedrooms  squareFootage  yearBuilt  \
# 0     3157 Rosebay Ln, Bartlett, TN 38134       3.0         1761.0     1973.0
# 1  410 Silver Pine Trl, Roswell, GA 30076       4.0         2664.0     1979.0
# 2    9803 Peddlers Way, Orlando, FL 32817       3.0         1440.0     1986.0
# 3   2140 Hammerle St, West Linn, OR 97068       2.0         2526.0        NaN
# 4     2124 Landside Dr, Valrico, FL 33594       3.0         2104.0     2014.0
#
#                                             features        county  ...  \
# 0  {'architectureType': 'Conventional', 'cooling'...        Shelby  ...
# 1  {'architectureType': 'Colonial', 'cooling': Tr...        Fulton  ...
# 2  {'cooling': True, 'coolingType': 'Central', 'e...        Orange  ...
# 3                                                 {}     Clackamas  ...
# 4  {'architectureType': 'Contemporary', 'cooling'...  Hillsborough  ...
#
#                                        taxAssessment  \
# 0  {'2023': {'value': 42150, 'land': 7675, 'impro...
# 1  {'2022': {'value': 154960, 'land': 29040, 'imp...
# 2  {'2021': {'value': 102525}, '2022': {'value': ...
# 3                                                NaN
# 4  {'2021': {'value': 212818}, '2022': {'value': ...
#
#                                        propertyTaxes  \
# 0                          {'2022': {'total': 1429}}
# 1  {'2022': {'total': 4374}, '2023': {'total': 48...
# 2  {'2022': {'total': 1406}, '2023': {'total': 14...
# 3                                                NaN
# 4  {'2022': {'total': 3823}, '2023': {'total': 40...
#
#                                                owner  \
# 0  {'names': ['BRANNICK DAISY L TRUST ONE A'], 'm...
# 1  {'names': ['GERKER FAMILY TRUST', 'GERKER JANE...
# 2  {'names': ['RICHARD A SEFICK', 'BERENICE W SEF...
# 3                                                NaN
# 4  {'names': ['Giovanni S Solorzano', 'Claudia So...
#
#                                        id   longitude   latitude  \
# 0     3157-Rosebay-Ln,-Bartlett,-TN-38134  -89.866508  35.211840
# 1  410-Silver-Pine-Trl,-Roswell,-GA-30076  -84.301676  34.004500
# 2    9803-Peddlers-Way,-Orlando,-FL-32817  -81.249395  28.591534
# 3   2140-Hammerle-St,-West-Linn,-OR-97068 -122.625382  45.370764
# 4     2124-Landside-Dr,-Valrico,-FL-33594  -82.250749  27.962256
#
#   ownerOccupied lastSalePrice              lastSaleDate addressLine2
# 0           NaN           NaN                       NaN          NaN
# 1           1.0           NaN                       NaN          NaN
# 2           1.0       84500.0  1986-10-01T00:00:00.000Z          NaN
# 3           NaN           NaN                       NaN          NaN
# 4           1.0      244900.0  2014-05-07T00:00:00.000Z          NaN
#
# [5 rows x 27 columns]

# %%
real_estate_df.columns
# Out:
# Index(['addressLine1', 'city', 'state', 'zipCode', 'formattedAddress',
#        'bedrooms', 'squareFootage', 'yearBuilt', 'features', 'county',
#        'assessorID', 'legalDescription', 'subdivision', 'zoning', 'bathrooms',
#        'lotSize', 'propertyType', 'taxAssessment', 'propertyTaxes', 'owner',
#        'id', 'longitude', 'latitude', 'ownerOccupied', 'lastSalePrice',
#        'lastSaleDate', 'addressLine2'],
#       dtype='object')

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   addressLine1      500 non-null    object
#  1   city              500 non-null    object
#  2   state             500 non-null    object
#  3   zipCode           500 non-null    int64
#  4   formattedAddress  500 non-null    object
#  5   bedrooms          322 non-null    float64
#  6   squareFootage     380 non-null    float64
#  7   yearBuilt         363 non-null    float64
#  8   features          451 non-null    object
#  9   county            500 non-null    object
#  10  assessorID        343 non-null    object
#  11  legalDescription  335 non-null    object
#  12  subdivision       293 non-null    object
#  13  zoning            180 non-null    object
#  14  bathrooms         364 non-null    float64
#  15  lotSize           341 non-null    float64
#  16  propertyType      401 non-null    object
#  17  taxAssessment     335 non-null    object
#  18  propertyTaxes     319 non-null    object
#  19  owner             335 non-null    object
#  20  id                500 non-null    object
#  21  longitude         500 non-null    float64
#  22  latitude          500 non-null    float64
#  23  ownerOccupied     305 non-null    float64
#  24  lastSalePrice     244 non-null    float64
#  25  lastSaleDate      301 non-null    object
#  26  addressLine2      112 non-null    object
# dtypes: float64(9), int64(1), object(17)
# memory usage: 105.6+ KB

# %% [markdown]
# ### Transformation layer

# %%
real_estate_df.fillna({
    'bathrooms' : 0.0,
    'bedrooms' : 0.0,
    'squareFootage' : 0.0,
    'county' : 'Unknown',
    'propertyType' : 'Unknown',
    'yearBuilt' : 0.0,
    'features' : 'Unknown',
    'assessorID' : 'Unknown',
    'legalDescription' : 'Unknown',
    'subdivision' : 'Unknown',
    'zoning' : 'Unknown',
    'ownerOccupied' : 0.0,
    'lotSize' : 0.0,
    'taxAssessment' : 'Unknown',
    'lastSaleDate' : 'Unknown',
    'propertyTaxes' : 'Unknown',
    'lastSalePrice' : 0.0,
    'addressLine2' : 'Unknown',
    'owner' : 'Unknown'
    }, inplace = True)

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   addressLine1      500 non-null    object
#  1   city              500 non-null    object
#  2   state             500 non-null    object
#  3   zipCode           500 non-null    int64
#  4   formattedAddress  500 non-null    object
#  5   bedrooms          500 non-null    float64
#  6   squareFootage     500 non-null    float64
#  7   yearBuilt         500 non-null    float64
#  8   features          500 non-null    object
#  9   county            500 non-null    object
#  10  assessorID        500 non-null    object
#  11  legalDescription  500 non-null    object
#  12  subdivision       500 non-null    object
#  13  zoning            500 non-null    object
#  14  bathrooms         500 non-null    float64
#  15  lotSize           500 non-null    float64
#  16  propertyType      500 non-null    object
#  17  taxAssessment     500 non-null    object
#  18  propertyTaxes     500 non-null    object
#  19  owner             500 non-null    object
#  20  id                500 non-null    object
#  21  longitude         500 non-null    float64
#  22  latitude          500 non-null    float64
#  23  ownerOccupied     500 non-null    float64
#  24  lastSalePrice     500 non-null    float64
#  25  lastSaleDate      500 non-null    object
#  26  addressLine2      500 non-null    object
# dtypes: float64(9), int64(1), object(17)
# memory usage: 105.6+ KB

# %%
# Address Table 
Address_Table = real_estate_df[['addressLine1', 'city', 'state', 'zipCode', 'formattedAddress', 'county', 'longitude', 'latitude', 'addressLine2']].copy().reset_index(drop = True)


# Address_Table.index.name = 'address_id'
# Address_Table = Address_Table.reset_index()


# Assign a unique primary key for tax_id using a dedicated numbering system
Address_Table['address_id'] = range(29, len(Address_Table) + 29)  # Sequential numbering starting at 1

Address_Table = Address_Table[['address_id', 'addressLine1', 'city', 'state', 'zipCode', 'formattedAddress', 'county', 'longitude', 'latitude', 'addressLine2']]


Address_Table.head()
# Out:
#    address_id         addressLine1       city state  zipCode  \
# 0          29      3157 Rosebay Ln   Bartlett    TN    38134
# 1          30  410 Silver Pine Trl    Roswell    GA    30076
# 2          31    9803 Peddlers Way    Orlando    FL    32817
# 3          32     2140 Hammerle St  West Linn    OR    97068
# 4          33     2124 Landside Dr    Valrico    FL    33594
#
#                          formattedAddress        county   longitude  \
# 0     3157 Rosebay Ln, Bartlett, TN 38134        Shelby  -89.866508
# 1  410 Silver Pine Trl, Roswell, GA 30076        Fulton  -84.301676
# 2    9803 Peddlers Way, Orlando, FL 32817        Orange  -81.249395
# 3   2140 Hammerle St, West Linn, OR 97068     Clackamas -122.625382
# 4     2124 Landside Dr, Valrico, FL 33594  Hillsborough  -82.250749
#
#     latitude addressLine2
# 0  35.211840      Unknown
# 1  34.004500      Unknown
# 2  28.591534      Unknown
# 3  45.370764      Unknown
# 4  27.962256      Unknown

# %%
# Property_info Table 


# Ensure Address_Table and real_estate_df have a common column to merge on, like 'addressLine1'
Property_info_Table = real_estate_df.merge(
    Address_Table[['address_id', 'addressLine1', 'city', 'state', 'zipCode']],
    on=['addressLine1', 'city', 'state', 'zipCode'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Property_info_Table
Property_info_Table = Property_info_Table[['address_id', 'assessorID', 'yearBuilt', 'legalDescription',
                                           'ownerOccupied', 'propertyType', 'owner', 'id', 'subdivision', 'zoning']].copy()

# # Reset the index and assign a new name for the index
# Property_info_Table.index.name = 'property_id'
# Property_info_Table = Property_info_Table.reset_index()


# Assign a unique primary key for tax_id using a dedicated numbering system
Property_info_Table['property_id'] = range(13, len(Property_info_Table) + 13)  # Sequential numbering starting at 1

Property_info_Table = Property_info_Table[['property_id', 'address_id', 'assessorID', 'yearBuilt', 'legalDescription',
                                           'ownerOccupied', 'propertyType', 'owner', 'id', 'subdivision', 'zoning']]





# Display the first few rows
Property_info_Table.head()
# Out:
#    property_id  address_id              assessorID  yearBuilt  \
# 0           13          29       B01-56J- -G-00106     1973.0
# 1           14          30         12 267106760531     1979.0
# 2           15          31    07-22-31-3800-02-520     1986.0
# 3           16          32                 Unknown        0.0
# 4           17          33  U1829219S5000001000070     2014.0
#
#                      legalDescription  ownerOccupied   propertyType  \
# 0                     WS ROSEBAY LANE            0.0  Single Family
# 1   ANNEXATION KITCHEN RENOVATION NVC            1.0  Single Family
# 2  HUNTERS TRACE UNIT 3 14/78 LOT 252            1.0  Single Family
# 3                             Unknown            0.0  Single Family
# 4               BONVIDA LOT 7 BLOCK 1            1.0  Single Family
#
#                                                owner  \
# 0  {'names': ['BRANNICK DAISY L TRUST ONE A'], 'm...
# 1  {'names': ['GERKER FAMILY TRUST', 'GERKER JANE...
# 2  {'names': ['RICHARD A SEFICK', 'BERENICE W SEF...
# 3                                            Unknown
# 4  {'names': ['Giovanni S Solorzano', 'Claudia So...
#
#                                        id                   subdivision  \
# 0     3157-Rosebay-Ln,-Bartlett,-TN-38134      WILDWOOD MANOR REV SEC A
# 1  410-Silver-Pine-Trl,-Roswell,-GA-30076  WOODFIELD AT MARTINS LANDING
# 2    9803-Peddlers-Way,-Orlando,-FL-32817            HUNTERS TRACE UT 3
# 3   2140-Hammerle-St,-West-Linn,-OR-97068                       Unknown
# 4     2124-Landside-Dr,-Valrico,-FL-33594                       BONVIDA
#
#     zoning
# 0    RS-10
# 1       R1
# 2     R-1A
# 3  Unknown
# 4       PD

# %%
# Remove the dictionary text format style in the owner column
Property_info_Table['owner'] = Property_info_Table['owner'].astype(str)



# Display the first few rows
Property_info_Table.head()
# Out:
#    property_id  address_id              assessorID  yearBuilt  \
# 0           13          29       B01-56J- -G-00106     1973.0
# 1           14          30         12 267106760531     1979.0
# 2           15          31    07-22-31-3800-02-520     1986.0
# 3           16          32                 Unknown        0.0
# 4           17          33  U1829219S5000001000070     2014.0
#
#                      legalDescription  ownerOccupied   propertyType  \
# 0                     WS ROSEBAY LANE            0.0  Single Family
# 1   ANNEXATION KITCHEN RENOVATION NVC            1.0  Single Family
# 2  HUNTERS TRACE UNIT 3 14/78 LOT 252            1.0  Single Family
# 3                             Unknown            0.0  Single Family
# 4               BONVIDA LOT 7 BLOCK 1            1.0  Single Family
#
#                                                owner  \
# 0  {'names': ['BRANNICK DAISY L TRUST ONE A'], 'm...
# 1  {'names': ['GERKER FAMILY TRUST', 'GERKER JANE...
# 2  {'names': ['RICHARD A SEFICK', 'BERENICE W SEF...
# 3                                            Unknown
# 4  {'names': ['Giovanni S Solorzano', 'Claudia So...
#
#                                        id                   subdivision  \
# 0     3157-Rosebay-Ln,-Bartlett,-TN-38134      WILDWOOD MANOR REV SEC A
# 1  410-Silver-Pine-Trl,-Roswell,-GA-30076  WOODFIELD AT MARTINS LANDING
# 2    9803-Peddlers-Way,-Orlando,-FL-32817            HUNTERS TRACE UT 3
# 3   2140-Hammerle-St,-West-Linn,-OR-97068                       Unknown
# 4     2124-Landside-Dr,-Valrico,-FL-33594                       BONVIDA
#
#     zoning
# 0    RS-10
# 1       R1
# 2     R-1A
# 3  Unknown
# 4       PD

# %%
display(Property_info_Table.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   property_id       500 non-null    int64
#  1   address_id        500 non-null    int64
#  2   assessorID        500 non-null    object
#  3   yearBuilt         500 non-null    float64
#  4   legalDescription  500 non-null    object
#  5   ownerOccupied     500 non-null    float64
#  6   propertyType      500 non-null    object
#  7   owner             500 non-null    object
#  8   id                500 non-null    object
#  9   subdivision       500 non-null    object
#  10  zoning            500 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 43.1+ KB
# None

# %%
# Tax Table

# Ensure Property_info_Table and real_estate_df have a common column to merge on.
Tax_Table = real_estate_df.merge(
    Property_info_Table[['property_id', 'yearBuilt', 'propertyType', 'id']],
    on=['yearBuilt', 'propertyType', 'id'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Tax_Table
Tax_Table = Tax_Table[['property_id', 'taxAssessment', 'propertyTaxes']].copy()

# # Reset the index and assign a new name for the index
# Tax_Table.index.name = 'tax_id'
# Tax_Table = Tax_Table.reset_index()


# Assign a unique primary key for tax_id using a dedicated numbering system
Tax_Table['tax_id'] = range(5, len(Tax_Table) + 5)  # Sequential numbering starting at 1

Tax_Table = Tax_Table[['tax_id', 'property_id', 'taxAssessment', 'propertyTaxes']]


# Display the first few rows
Tax_Table.head()
# Out:
#    tax_id  property_id                                      taxAssessment  \
# 0       5           13  {'2023': {'value': 42150, 'land': 7675, 'impro...
# 1       6           14  {'2022': {'value': 154960, 'land': 29040, 'imp...
# 2       7           15  {'2021': {'value': 102525}, '2022': {'value': ...
# 3       8           16                                            Unknown
# 4       9           17  {'2021': {'value': 212818}, '2022': {'value': ...
#
#                                        propertyTaxes
# 0                          {'2022': {'total': 1429}}
# 1  {'2022': {'total': 4374}, '2023': {'total': 48...
# 2  {'2022': {'total': 1406}, '2023': {'total': 14...
# 3                                            Unknown
# 4  {'2022': {'total': 3823}, '2023': {'total': 40...

# %%
# Remove the dictionary text format style in the owner column
Tax_Table['taxAssessment'] = Tax_Table['taxAssessment'].astype(str)
Tax_Table['propertyTaxes'] = Tax_Table['propertyTaxes'].astype(str)



# Display the first few rows
Tax_Table.head()
# Out:
#    tax_id  property_id                                      taxAssessment  \
# 0       5           13  {'2023': {'value': 42150, 'land': 7675, 'impro...
# 1       6           14  {'2022': {'value': 154960, 'land': 29040, 'imp...
# 2       7           15  {'2021': {'value': 102525}, '2022': {'value': ...
# 3       8           16                                            Unknown
# 4       9           17  {'2021': {'value': 212818}, '2022': {'value': ...
#
#                                        propertyTaxes
# 0                          {'2022': {'total': 1429}}
# 1  {'2022': {'total': 4374}, '2023': {'total': 48...
# 2  {'2022': {'total': 1406}, '2023': {'total': 14...
# 3                                            Unknown
# 4  {'2022': {'total': 3823}, '2023': {'total': 40...

# %%
# Sales Table

# Ensure Property_info_Table and real_estate_df have a common column to merge on.
Sales_Table = real_estate_df.merge(
    Property_info_Table[['property_id', 'yearBuilt', 'propertyType', 'id']],
    on=['yearBuilt', 'propertyType', 'id'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Sales_Table
Sales_Table = Sales_Table[['property_id', 'lastSalePrice', 'lastSaleDate']].copy()



# Assign a unique primary key for tax_id using a dedicated numbering system
Sales_Table['sales_id'] = range(55, len(Sales_Table) + 55)  # Sequential numbering starting at 1

Sales_Table = Sales_Table[['sales_id', 'property_id', 'lastSalePrice', 'lastSaleDate']].copy()


# Display the first few rows
Sales_Table.head()
# Out:
#    sales_id  property_id  lastSalePrice              lastSaleDate
# 0        55           13            0.0                   Unknown
# 1        56           14            0.0                   Unknown
# 2        57           15        84500.0  1986-10-01T00:00:00.000Z
# 3        58           16            0.0                   Unknown
# 4        59           17       244900.0  2014-05-07T00:00:00.000Z

# %%
# Features Table

# Ensure Property_info_Table and real_estate_df have a common column to merge on.
Features_Table = real_estate_df.merge(
    Property_info_Table[['property_id', 'yearBuilt', 'propertyType', 'id']],
    on=['yearBuilt', 'propertyType', 'id'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Features Table
Features_Table = Features_Table[['property_id', 'bedrooms', 'squareFootage', 'bathrooms', 'lotSize', 'features']].copy()



# Assign a unique primary key for tax_id using a dedicated numbering system
Features_Table['features_id'] = range(79, len(Sales_Table) + 79)  # Sequential numbering starting at 1

Features_Table = Features_Table[['features_id','property_id', 'bedrooms', 'squareFootage', 'bathrooms', 'lotSize', 'features']].copy()


# Display the first few rows
Features_Table.head()
# Out:
#    features_id  property_id  bedrooms  squareFootage  bathrooms  lotSize  \
# 0           79           13       3.0         1761.0        2.0   9975.0
# 1           80           14       4.0         2664.0        2.5  11587.0
# 2           81           15       3.0         1440.0        2.0   7506.0
# 3           82           16       2.0         2526.0        2.0      0.0
# 4           83           17       3.0         2104.0        2.0   8995.0
#
#                                             features
# 0  {'architectureType': 'Conventional', 'cooling'...
# 1  {'architectureType': 'Colonial', 'cooling': Tr...
# 2  {'cooling': True, 'coolingType': 'Central', 'e...
# 3                                                 {}
# 4  {'architectureType': 'Contemporary', 'cooling'...

# %%
# Remove the dictionary text format style in the owner column
Features_Table['features'] = Features_Table['features'].astype(str)



# Display the first few rows
Features_Table.head()
# Out:
#    features_id  property_id  bedrooms  squareFootage  bathrooms  lotSize  \
# 0           79           13       3.0         1761.0        2.0   9975.0
# 1           80           14       4.0         2664.0        2.5  11587.0
# 2           81           15       3.0         1440.0        2.0   7506.0
# 3           82           16       2.0         2526.0        2.0      0.0
# 4           83           17       3.0         2104.0        2.0   8995.0
#
#                                             features
# 0  {'architectureType': 'Conventional', 'cooling'...
# 1  {'architectureType': 'Colonial', 'cooling': Tr...
# 2  {'cooling': True, 'coolingType': 'Central', 'e...
# 3                                                 {}
# 4  {'architectureType': 'Contemporary', 'cooling'...

# %%
real_estate_df.columns
# Out:
# Index(['addressLine1', 'city', 'state', 'zipCode', 'formattedAddress',
#        'bedrooms', 'squareFootage', 'yearBuilt', 'features', 'county',
#        'assessorID', 'legalDescription', 'subdivision', 'zoning', 'bathrooms',
#        'lotSize', 'propertyType', 'taxAssessment', 'propertyTaxes', 'owner',
#        'id', 'longitude', 'latitude', 'ownerOccupied', 'lastSalePrice',
#        'lastSaleDate', 'addressLine2'],
#       dtype='object')

# %% [markdown]
# ### Loading Layer

# %%
# Load environment variables from the .env file
load_dotenv()


# Develop a function to get the Database connections
def get_db_connection():
    connection = psycopg2.connect(
        # Retrieve environment variables
        host = os.getenv('HOST'),
        database = os.getenv('DATABASE'),
        user = os.getenv('USER'),
        password = os.getenv('PASSWORD')
    )

    return connection

# Connect to the Database
conn = get_db_connection()

# %%
# Create a function that sets up the schema and tables
def create_tables():
    conn = get_db_connection()
    cursor = conn.cursor()
    create_table_query = '''
                            CREATE SCHEMA IF NOT EXISTS Zuma_Realtors;

                            DROP TABLE IF EXISTS Zuma_Realtors.Features_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Sales_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Property_info_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Tax_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Address_Table CASCADE;

                            CREATE TABLE Zuma_Realtors.Address_Table (
                                address_id INTEGER PRIMARY KEY,
                                addressLine1 VARCHAR(100000),
                                city VARCHAR(100000),
                                state VARCHAR(100000),
                                zipCode INTEGER,
                                formattedAddress VARCHAR(100000),
                                county VARCHAR(100000),
                                longitude FLOAT,
                                latitude FLOAT,
                                addressLine2 VARCHAR(100000)
                            );


                            CREATE TABLE Zuma_Realtors.Property_info_Table (
                                property_id INTEGER PRIMARY KEY,
                                address_id INTEGER,
                                assessorID VARCHAR(100000),
                                yearBuilt FLOAT,
                                legalDescription VARCHAR(100000),
                                ownerOccupied FLOAT,
                                propertyType VARCHAR(100000),
                                owner VARCHAR(100000),
                                id VARCHAR(100000),
                                subdivision VARCHAR(100000),
                                zoning VARCHAR(100000),
                                FOREIGN KEY (address_id) REFERENCES Zuma_Realtors.Address_Table(address_id)
                            );



                            CREATE TABLE Zuma_Realtors.Tax_Table (
                                tax_id INTEGER PRIMARY KEY,
                                property_id INTEGER,
                                taxAssessment VARCHAR(100000),
                                propertyTaxes VARCHAR(100000),
                                FOREIGN KEY (property_id) REFERENCES Zuma_Realtors.Property_info_Table(property_id)
                            );
 
                            

                             CREATE TABLE Zuma_Realtors.Sales_Table (
                                sales_id INTEGER PRIMARY KEY,
                                property_id INTEGER,
                                lastSalePrice FLOAT,
                                lastSaleDate VARCHAR(100000),
                                FOREIGN KEY (property_id) REFERENCES Zuma_Realtors.Property_info_Table(property_id)
                            );



                            CREATE TABLE Zuma_Realtors.Features_Table (
                                features_id INTEGER PRIMARY KEY,
                                property_id INTEGER,
                                bedrooms FLOAT,
                                squareFootage FLOAT,
                                bathrooms FLOAT,
                                lotSize FLOAT,
                                features VARCHAR(100000),
                                FOREIGN KEY (property_id) REFERENCES Zuma_Realtors.Property_info_Table(property_id)
                            );
                            '''
    cursor.execute(create_table_query)
    conn.commit()
    cursor.close()
    conn.close()

create_tables()

# %%
### Loading the Data into the db Tables
conn = get_db_connection()
cursor = conn.cursor()

# Insert the dataframe into SQL tables
for _,row in Address_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Address_Table (address_id, addressLine1, city, state, zipCode, formattedAddress, county, longitude, latitude, addressLine2)
            
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
        (row['address_id'], row['addressLine1'], row['city'], row['state'], row['zipCode'], row['formattedAddress'], row['county'], row['longitude'],  row['latitude'], row['addressLine2'])
    )


for _,row in Property_info_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Property_info_Table (property_id, address_id, assessorID, yearBuilt, legalDescription, ownerOccupied, propertyType, owner, id, subdivision, zoning)
            
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
        (row['property_id'], row['address_id'], row['assessorID'], row['yearBuilt'], row['legalDescription'], row['ownerOccupied'], row['propertyType'], row['owner'],  row['id'], row['subdivision'], row['zoning'])
    )


for _,row in Tax_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Tax_Table (tax_id, property_id, taxAssessment, propertyTaxes)
            
            VALUES (%s, %s, %s, %s)''',
        (row['tax_id'], row['property_id'], row['taxAssessment'], row['propertyTaxes'])
    )



for _,row in Sales_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Sales_Table (sales_id, property_id, lastSalePrice, lastSaleDate)
            
            VALUES (%s, %s, %s, %s)''',
        (row['sales_id'], row['property_id'], row['lastSalePrice'], row['lastSaleDate'])
    )




for _,row in Features_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Features_Table (features_id, property_id, bedrooms, squareFootage, bathrooms, lotSize, features)
            
            VALUES (%s, %s, %s, %s, %s, %s, %s)''',
        (row['features_id'], row['property_id'], row['bedrooms'], row['squareFootage'], row['bathrooms'], row['lotSize'], row['features'])
    )



# Commit Changes
conn.commit()

# Close Connection
cursor.close()
conn.close()

# %%
display(Property_info_Table.info())
display(Property_info_Table.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   property_id       500 non-null    int64
#  1   address_id        500 non-null    int64
#  2   assessorID        500 non-null    object
#  3   yearBuilt         500 non-null    float64
#  4   legalDescription  500 non-null    object
#  5   ownerOccupied     500 non-null    float64
#  6   propertyType      500 non-null    object
#  7   owner             500 non-null    object
#  8   id                500 non-null    object
#  9   subdivision       500 non-null    object
#  10  zoning            500 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 43.1+ KB
# None
# Index(['property_id', 'address_id', 'assessorID', 'yearBuilt',
#        'legalDescription', 'ownerOccupied', 'propertyType', 'owner', 'id',
#        'subdivision', 'zoning'],
#       dtype='object')

# %%
Features_Table.head()
# Out:
#    features_id  property_id  bedrooms  squareFootage  bathrooms  lotSize  \
# 0           79           13       3.0         1761.0        2.0   9975.0
# 1           80           14       4.0         2664.0        2.5  11587.0
# 2           81           15       3.0         1440.0        2.0   7506.0
# 3           82           16       2.0         2526.0        2.0      0.0
# 4           83           17       3.0         2104.0        2.0   8995.0
#
#                                             features
# 0  {'architectureType': 'Conventional', 'cooling'...
# 1  {'architectureType': 'Colonial', 'cooling': Tr...
# 2  {'cooling': True, 'coolingType': 'Central', 'e...
# 3                                                 {}
# 4  {'architectureType': 'Contemporary', 'cooling'...
