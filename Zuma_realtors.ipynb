# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from dotenv import load_dotenv
import os
import requests
from pprint import pprint
import psycopg2
import json

# %% [markdown]
# ### Data Extraction

# %%
# Load environment variables from the .env file
load_dotenv()

# Retrieve environment variables
rapidapi_key = os.getenv('RAPIDAPI_KEY')
rapidapi_host = os.getenv('RAPIDAPI_HOST')

# Define the headers using the variables
headers = {
    'x-rapidapi-key': rapidapi_key,
    'x-rapidapi-host': rapidapi_host,
}

# API request details
url = "https://realty-mole-property-api.p.rapidapi.com/randomProperties"
querystring = {"limit": "500"}

# Make the API request
response = requests.get(url, headers=headers, params=querystring)

# Print the response
pprint(response.json())
# Out:
# [{'addressLine1': '106 S Key St',
#   'addressLine2': 'Apt 38',
#   'city': 'Pilot Mountain',
#   'county': 'Surry',
#   'features': {},
#   'formattedAddress': '106 S Key St, Apt 38, Pilot Mountain, NC 27041',
#   'id': '106-S-Key-St,-Apt-38,-Pilot-Mountain,-NC-27041',
#   'latitude': 36.376987,
#   'longitude': -80.480906,
#   'state': 'NC',
#   'zipCode': '27041'},
#  {'addressLine1': '1314 Deer Trail Rd',
#   'assessorID': '39-00-29-4-000-004.048',
#   'bathrooms': 2.5,
#   'bedrooms': 3,
#   'city': 'Hoover',
#   'county': 'Jefferson',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Other',
#                'fireplace': True,
#                'fireplaceType': 'Prefab',
#                'floorCount': 1,
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Shingle',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '1314 Deer Trail Rd, Hoover, AL 35226',
#   'id': '1314-Deer-Trail-Rd,-Hoover,-AL-35226',
#   'lastSaleDate': '2005-01-26T00:00:00.000Z',
#   'lastSalePrice': 197000,
#   'latitude': 33.353804,
#   'legalDescription': 'LOT 4 BLK 1 DEER VALLEY II 29/20',
#   'longitude': -86.872279,
#   'owner': {'mailingAddress': {'addressLine1': '1314 Deer Trail Rd',
#                                'city': 'Hoover',
#                                'formattedAddress': '1314 Deer Trail Rd, '
#                                                    'Hoover, AL 35226',
#                                'id': '1314-Deer-Trail-Rd,-Hoover,-AL-35226',
#                                'state': 'AL',
#                                'zipCode': '35226'},
#             'names': ['Mohammad R Abdel Rohman'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 1903}},
#   'propertyType': 'Single Family',
#   'squareFootage': 978,
#   'state': 'AL',
#   'subdivision': 'DEER VALLEY II',
#   'taxAssessment': {'2022': {'improvements': 19940,
#                              'land': 7000,
#                              'value': 26940},
#                     '2023': {'improvements': 18280,
#                              'land': 12200,
#                              'value': 30480}},
#   'yearBuilt': 1995,
#   'zipCode': '35226',
#   'zoning': 'PRD'},
#  {'addressLine1': '91 Sw South River Dr',
#   'addressLine2': 'Apt 102',
#   'assessorID': '41-38-41-001-091-01020-0',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'Stuart',
#   'county': 'Martin',
#   'features': {'architectureType': 'Condo / Apartment',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Stucco',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Carport',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'OTHER',
#                'unitCount': 1},
#   'formattedAddress': '91 Sw South River Dr, Apt 102, Stuart, FL 34997',
#   'id': '91-Sw-South-River-Dr,-Apt-102,-Stuart,-FL-34997',
#   'lastSaleDate': '2020-08-20T00:00:00.000Z',
#   'lastSalePrice': 149500,
#   'latitude': 27.152562,
#   'legalDescription': 'SOUTH RIVER VILLAGE ONE CONDO UNIT 102 BLDG P.O. 91',
#   'longitude': -80.246179,
#   'owner': {'mailingAddress': {'addressLine1': '91 Sw South River Dr',
#                                'addressLine2': 'APT 102',
#                                'city': 'Stuart',
#                                'formattedAddress': '91 Sw South River Dr, APT '
#                                                    '102, Stuart, FL 34997',
#                                'id': '91-Sw-South-River-Dr,-APT-102,-Stuart,-FL-34997',
#                                'state': 'FL',
#                                'zipCode': '34997'},
#             'names': ['Kenneth Peter Lee', 'Charles Tortorici']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 1566}, '2023': {'total': 1635}},
#   'propertyType': 'Condo',
#   'squareFootage': 1107,
#   'state': 'FL',
#   'subdivision': 'SOUTH RIVER VILLAGE CONDO',
#   'taxAssessment': {'2022': {'value': 134930}, '2023': {'value': 138977}},
#   'yearBuilt': 1982,
#   'zipCode': '34997'},
#  {'addressLine1': '17 Crowninshield St',
#   'assessorID': 'PROV M:107 L:12',
#   'bathrooms': 2,
#   'bedrooms': 6,
#   'city': 'Providence',
#   'county': 'Providence',
#   'features': {'architectureType': 'Two Family',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 3,
#                'garage': True,
#                'garageSpaces': 6,
#                'garageType': 'Carport',
#                'heating': True,
#                'heatingType': 'Hot Water',
#                'roofType': 'Asphalt',
#                'roomCount': 10,
#                'unitCount': 2},
#   'formattedAddress': '17 Crowninshield St, Providence, RI 02909',
#   'id': '17-Crowninshield-St,-Providence,-RI-02909',
#   'lastSaleDate': '2011-09-27T00:00:00.000Z',
#   'lastSalePrice': 1,
#   'latitude': 41.817999,
#   'legalDescription': 'LOT:12 CITY/MUNI/TWP:PROVIDENCE',
#   'longitude': -71.458082,
#   'lotSize': 7172,
#   'owner': {'mailingAddress': {'addressLine1': '17 Crowninshield St',
#                                'city': 'Providence',
#                                'formattedAddress': '17 Crowninshield St, '
#                                                    'Providence, RI 02909',
#                                'id': '17-Crowninshield-St,-Providence,-RI-02909',
#                                'state': 'RI',
#                                'zipCode': '02909'},
#             'names': ['MARIA C VEGA'],
#             'type': None},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 3959},
#                     '2022': {'total': 4203},
#                     '2023': {'total': 7878}},
#   'propertyType': 'Duplex-Triplex',
#   'squareFootage': 3114,
#   'state': 'RI',
#   'taxAssessment': {'2019': {'improvements': 217500,
#                              'land': 51100,
#                              'value': 268600},
#                     '2022': {'improvements': 354400,
#                              'land': 74900,
#                              'value': 429300},
#                     '2023': {'improvements': 354400,
#                              'land': 74900,
#                              'value': 429300}},
#   'yearBuilt': 1950,
#   'zipCode': '02909',
#   'zoning': 'R-2'},
#  {'addressLine1': '220 Camford Stone Path',
#   'assessorID': '052321013',
#   'bathrooms': 3.5,
#   'bedrooms': 3,
#   'city': 'Fayetteville',
#   'county': 'Fayette',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Wood',
#                'fireplace': True,
#                'floorCount': 2,
#                'heating': True,
#                'heatingType': 'Central',
#                'unitCount': 1},
#   'formattedAddress': '220 Camford Stone Path, Fayetteville, GA 30214',
#   'id': '220-Camford-Stone-Path,-Fayetteville,-GA-30214',
#   'lastSaleDate': '2024-07-16T00:00:00.000Z',
#   'lastSalePrice': 359000,
#   'latitude': 33.450286,
#   'legalDescription': 'LOT 13 TOWNHOMES @ LAFAYETTE P',
#   'longitude': -84.461941,
#   'lotSize': 2178,
#   'owner': {'mailingAddress': {'addressLine1': '220 Camford Stone Path',
#                                'city': 'Fayetteville',
#                                'formattedAddress': '220 Camford Stone Path, '
#                                                    'Fayetteville, GA 30214',
#                                'id': '220-Camford-Stone-Path,-Fayetteville,-GA-30214',
#                                'state': 'GA',
#                                'zipCode': '30214'},
#             'names': ['Collette Camille Brown', 'Kristopher Jermaine Jolly'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 3953}, '2023': {'total': 4191}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1864,
#   'state': 'GA',
#   'subdivision': 'THE VILLAGES AT LAFAYETTE',
#   'taxAssessment': {'2022': {'improvements': 110080,
#                              'land': 20000,
#                              'value': 130080},
#                     '2023': {'improvements': 110480,
#                              'land': 27200,
#                              'value': 137680}},
#   'yearBuilt': 2003,
#   'zipCode': '30214'},
#  {'addressLine1': '1803 Cobblestone Ct',
#   'assessorID': '5740-02-006-0440-907',
#   'bathrooms': 3,
#   'bedrooms': 4,
#   'city': 'Richmond',
#   'county': 'Fort Bend',
#   'features': {'architectureType': 'Contemporary',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick Veneer',
#                'fireplace': True,
#                'fireplaceType': 'Single',
#                'floorCount': 2,
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'pool': True,
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '1803 Cobblestone Ct, Richmond, TX 77406',
#   'id': '1803-Cobblestone-Ct,-Richmond,-TX-77406',
#   'lastSaleDate': '2013-12-03T00:00:00.000Z',
#   'latitude': 29.62033,
#   'legalDescription': 'PECAN GROVE PLANTATION SEC 2, BLOCK 6, LOT 44',
#   'longitude': -95.730659,
#   'lotSize': 10960,
#   'owner': {'mailingAddress': {'addressLine1': '1803 Cobblestone Ct',
#                                'city': 'Richmond',
#                                'formattedAddress': '1803 Cobblestone Ct, '
#                                                    'Richmond, TX 77406',
#                                'id': '1803-Cobblestone-Ct,-Richmond,-TX-77406',
#                                'state': 'TX',
#                                'zipCode': '77406'},
#             'names': ['ROSE M MALDONADO', 'LARS MALDONADO'],
#             'type': None},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2018': {'total': 5413},
#                     '2019': {'total': 7106},
#                     '2021': {'total': 5222},
#                     '2023': {'total': 4709}},
#   'propertyType': 'Single Family',
#   'squareFootage': 3531,
#   'state': 'TX',
#   'subdivision': 'PECAN GROVE PLANTATION SEC 2',
#   'taxAssessment': {'2019': {'improvements': 289600,
#                              'land': 37000,
#                              'value': 326600},
#                     '2022': {'improvements': 347470,
#                              'land': 39000,
#                              'value': 386470},
#                     '2023': {'improvements': 466292,
#                              'land': 78000,
#                              'value': 425117}},
#   'yearBuilt': 1984,
#   'zipCode': '77406'},
#  {'addressLine1': '3122 Hampton Ave',
#   'assessorID': '601000-00100',
#   'bathrooms': 1,
#   'city': 'Saint Louis',
#   'county': 'Saint Louis City',
#   'features': {'cooling': True,
#                'coolingType': 'Window',
#                'exteriorType': 'Brick',
#                'floorCount': 2,
#                'heating': True,
#                'heatingType': 'Central',
#                'unitCount': 1},
#   'formattedAddress': '3122 Hampton Ave, Saint Louis, MO 63139',
#   'id': '3122-Hampton-Ave,-Saint-Louis,-MO-63139',
#   'lastSaleDate': '2007-11-28T00:00:00.000Z',
#   'latitude': 38.606012,
#   'legalDescription': 'C.B. 6010 HAMPTON 33.44 FT/70 FT 6 IN X 66.24 FT/77 FT '
#                       'ARSENAL WATSON PK ADDN LOT W-1',
#   'longitude': -90.289342,
#   'lotSize': 3400,
#   'owner': {'mailingAddress': {'addressLine1': '3122 Hampton Ave',
#                                'city': 'Saint Louis',
#                                'id': '3122-Hampton-Ave,-Saint-Louis,-MO-63139',
#                                'state': 'MO',
#                                'zipCode': '63139'},
#             'names': ['JOSEPH E LEICHT']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 1980}, '2022': {'total': 2121}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1296,
#   'state': 'MO',
#   'subdivision': 'SOUTHWEST GARDEN',
#   'taxAssessment': {'2020': {'improvements': 21210,
#                              'land': 2620,
#                              'value': 23830},
#                     '2022': {'improvements': 22700,
#                              'land': 2620,
#                              'value': 25320}},
#   'yearBuilt': 1928,
#   'zipCode': '63139',
#   'zoning': 'A'},
#  {'addressLine1': '7275 S Land Park Dr',
#   'assessorID': '031-0125-002-0000',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Sacramento',
#   'county': 'Sacramento',
#   'features': {'fireplace': True,
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Wood Shingle',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '7275 S Land Park Dr, Sacramento, CA 95831',
#   'id': '7275-S-Land-Park-Dr,-Sacramento,-CA-95831',
#   'lastSaleDate': '2007-04-20T00:00:00.000Z',
#   'lastSalePrice': 348000,
#   'latitude': 38.493307,
#   'legalDescription': 'SOUTH LAND PARK HILLS 27, LOT 62',
#   'longitude': -121.510947,
#   'lotSize': 8712,
#   'owner': {'mailingAddress': {'addressLine1': '2138 14th Ave',
#                                'city': 'San Francisco',
#                                'formattedAddress': '2138 14th Ave, San '
#                                                    'Francisco, CA 94116',
#                                'id': '2138-14th-Ave,-San-Francisco,-CA-94116',
#                                'state': 'CA',
#                                'zipCode': '94116'},
#             'names': ['William W Pau']},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2023': {'total': 5472}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1402,
#   'state': 'CA',
#   'subdivision': 'SOUTH LAND PARK HILLS 27',
#   'taxAssessment': {'2023': {'improvements': 221486,
#                              'land': 226639,
#                              'value': 448125}},
#   'yearBuilt': 1963,
#   'zipCode': '95831',
#   'zoning': 'R-1-EA-3'},
#  {'addressLine1': '16736 Stanford Place Dr',
#   'assessorID': '04J-6-3-018-3',
#   'bathrooms': 2.5,
#   'bedrooms': 4,
#   'city': 'Florissant',
#   'county': 'Saint Louis',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Other',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 8,
#                'unitCount': 1},
#   'formattedAddress': '16736 Stanford Place Dr, Florissant, MO 63034',
#   'id': '16736-Stanford-Place-Dr,-Florissant,-MO-63034',
#   'lastSaleDate': '2002-08-13T00:00:00.000Z',
#   'lastSalePrice': 225000,
#   'latitude': 38.852396,
#   'legalDescription': 'LEXINGTON FARM PLAT THREE 8 1 88',
#   'longitude': -90.314954,
#   'lotSize': 13939,
#   'owner': {'mailingAddress': {'addressLine1': '16736 Stanford Place Dr',
#                                'city': 'Florissant',
#                                'id': '16736-Stanford-Place-Dr,-Florissant,-MO-63034',
#                                'state': 'MO',
#                                'zipCode': '63034'},
#             'names': ['LLOYD R TINA A ABERNATHY']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 4976}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2862,
#   'state': 'MO',
#   'subdivision': 'LEXINGTON FARM PLAT THREE',
#   'taxAssessment': {'2022': {'improvements': 42620,
#                              'land': 6750,
#                              'value': 49370}},
#   'yearBuilt': 1991,
#   'zipCode': '63034',
#   'zoning': 'R2'},
#  {'addressLine1': '342 Tucker Ave',
#   'assessorID': '19  00903-0000-00017',
#   'city': 'Union',
#   'county': 'Union',
#   'features': {'architectureType': 'Cape Cod',
#                'exteriorType': 'Wood',
#                'floorCount': 2,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Garage',
#                'unitCount': 1},
#   'formattedAddress': '342 Tucker Ave, Union, NJ 07083',
#   'id': '342-Tucker-Ave,-Union,-NJ-07083',
#   'lastSaleDate': '2007-05-29T00:00:00.000Z',
#   'lastSalePrice': 425000,
#   'latitude': 40.675337,
#   'legalDescription': 'LOT:17 BLK:903 DIST:19 CITY/MUNI/TWP:UNION TWP',
#   'longitude': -74.268858,
#   'lotSize': 5001,
#   'owner': {'mailingAddress': {'addressLine1': '342 Tucker Ave',
#                                'city': 'Union',
#                                'formattedAddress': '342 Tucker Ave, Union, NJ '
#                                                    '07083',
#                                'id': '342-Tucker-Ave,-Union,-NJ-07083',
#                                'state': 'NJ',
#                                'zipCode': '07083'},
#             'names': ['Simon Nyabwari', 'Sabina Maobe']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 12257}},
#   'propertyType': 'Single Family',
#   'state': 'NJ',
#   'subdivision': 'WALTON PARK',
#   'taxAssessment': {'2023': {'improvements': 38600,
#                              'land': 20000,
#                              'value': 58600}},
#   'yearBuilt': 1965,
#   'zipCode': '07083'},
#  {'addressLine1': '11300 5th Ave NE',
#   'addressLine2': 'Apt 2',
#   'city': 'Seattle',
#   'county': 'King',
#   'features': {},
#   'formattedAddress': '11300 5th Ave NE, Apt 2, Seattle, WA 98125',
#   'id': '11300-5th-Ave-NE,-Apt-2,-Seattle,-WA-98125',
#   'latitude': 47.710908,
#   'longitude': -122.323015,
#   'state': 'WA',
#   'zipCode': '98125'},
#  {'addressLine1': '1144 Research Dr NE',
#   'assessorID': '16059000130',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Marietta',
#   'county': 'Cobb',
#   'features': {'architectureType': 'Ranch',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Wood',
#                'fireplace': True,
#                'fireplaceType': 'Prefab',
#                'floorCount': 1,
#                'heating': True,
#                'heatingType': 'Heat Pump',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '1144 Research Dr NE, Marietta, GA 30066',
#   'id': '1144-Research-Dr-NE,-Marietta,-GA-30066',
#   'lastSaleDate': '2004-10-08T00:00:00.000Z',
#   'lastSalePrice': 160000,
#   'latitude': 34.014015,
#   'legalDescription': 'DIST:9 CITY/MUNI/TWP:UNINCORPORATED SUBD:RAMBLEWOOD',
#   'longitude': -84.517645,
#   'lotSize': 10396,
#   'owner': {'mailingAddress': {'addressLine1': '1144 Research Dr NE',
#                                'city': 'Marietta',
#                                'formattedAddress': '1144 Research Dr NE, '
#                                                    'Marietta, GA 30066',
#                                'id': '1144-Research-Dr-NE,-Marietta,-GA-30066',
#                                'state': 'GA',
#                                'zipCode': '30066'},
#             'names': ['Walter Rogelio Reyes'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 3029},
#                     '2022': {'total': 3584},
#                     '2023': {'total': 4172}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2065,
#   'state': 'GA',
#   'subdivision': 'RAMBLEWOOD',
#   'taxAssessment': {'2021': {'improvements': 83016,
#                              'land': 16800,
#                              'value': 99816},
#                     '2022': {'improvements': 96084,
#                              'land': 22000,
#                              'value': 118084},
#                     '2023': {'improvements': 108364,
#                              'land': 30000,
#                              'value': 138364}},
#   'yearBuilt': 1972,
#   'zipCode': '30066'},
#  {'addressLine1': '1245 Sw 46th Ave',
#   'addressLine2': 'Apt 1215',
#   'assessorID': '49-42-06-CM-1670',
#   'bathrooms': 1,
#   'bedrooms': 1,
#   'city': 'Pompano Beach',
#   'county': 'Broward',
#   'features': {'architectureType': 'Condo / Apartment'},
#   'formattedAddress': '1245 Sw 46th Ave, Apt 1215, Pompano Beach, FL 33069',
#   'id': '1245-Sw-46th-Ave,-Apt-1215,-Pompano-Beach,-FL-33069',
#   'lastSaleDate': '2017-05-12T00:00:00.000Z',
#   'lastSalePrice': 107000,
#   'latitude': 26.214339,
#   'legalDescription': 'ROYAL POINCIANA CONDO UNIT 1215 BLDG 12 PER CDO BK/PG: '
#                       '41388/421',
#   'longitude': -80.189436,
#   'lotSize': 797,
#   'owner': {'names': ['Redgsl,girard D C Living Trust',
#                       'Redgsl,lambert S Living Trust']},
#   'propertyTaxes': {'2022': {'total': 2793}, '2023': {'total': 3261}},
#   'propertyType': 'Condo',
#   'squareFootage': 813,
#   'state': 'FL',
#   'subdivision': 'ROYAL POINCIANA CONDO',
#   'taxAssessment': {'2022': {'improvements': 120460,
#                              'land': 13380,
#                              'value': 133840},
#                     '2023': {'improvements': 142850,
#                              'land': 15870,
#                              'value': 158720}},
#   'yearBuilt': 1986,
#   'zipCode': '33069',
#   'zoning': 'RM-45'},
#  {'addressLine1': '1 Donnan Trce',
#   'assessorID': '072A      118B',
#   'bathrooms': 3,
#   'city': 'Newnan',
#   'county': 'Coweta',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick Veneer',
#                'fireplace': True,
#                'fireplaceType': 'Prefab',
#                'floorCount': 2,
#                'foundationType': 'Masonry',
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Shingle (Not Wood)',
#                'unitCount': 1},
#   'formattedAddress': '1 Donnan Trce, Newnan, GA 30263',
#   'id': '1-Donnan-Trce,-Newnan,-GA-30263',
#   'latitude': 33.423116,
#   'legalDescription': 'HSE/LOT 11 BLK C NEWNAN PINES',
#   'longitude': -84.783829,
#   'owner': {'mailingAddress': {'addressLine1': '1 Donnan Trce',
#                                'city': 'Newnan',
#                                'id': '1-Donnan-Trce,-Newnan,-GA-30263',
#                                'state': 'GA',
#                                'zipCode': '30263'},
#             'names': ['Jack Douglas Davis']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 1266}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2520,
#   'state': 'GA',
#   'subdivision': 'NEWNAN PINES',
#   'taxAssessment': {'2019': {'improvements': 71971,
#                              'land': 24000,
#                              'value': 95971}},
#   'yearBuilt': 1980,
#   'zipCode': '30263',
#   'zoning': 'RESIDENTIAL'},
#  {'addressLine1': '547 E Queen Ave',
#   'assessorID': '36323.0921',
#   'bathrooms': 1,
#   'bedrooms': 2,
#   'city': 'Spokane',
#   'county': 'Spokane',
#   'features': {'architectureType': 'Ranch / Rambler',
#                'exteriorType': 'Shingle (Not Wood)',
#                'floorCount': 1,
#                'foundationType': 'Concrete',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Detached Garage',
#                'heating': True,
#                'heatingType': 'Baseboard',
#                'roofType': 'Composition Shingle',
#                'roomCount': 4,
#                'unitCount': 1},
#   'formattedAddress': '547 E Queen Ave, Spokane, WA 99207',
#   'id': '547-E-Queen-Ave,-Spokane,-WA-99207',
#   'lastSaleDate': '1995-04-04T00:00:00.000Z',
#   'lastSalePrice': 70967,
#   'latitude': 47.704187,
#   'legalDescription': 'KENWOOD W L23 B9',
#   'longitude': -117.401214,
#   'lotSize': 6475,
#   'owner': {'mailingAddress': {'addressLine1': '547 E Queen Ave',
#                                'city': 'Spokane',
#                                'id': '547-E-Queen-Ave,-Spokane,-WA-99207',
#                                'state': 'WA',
#                                'zipCode': '99207'},
#             'names': ['JANET R PORTER']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 1295}},
#   'propertyType': 'Single Family',
#   'squareFootage': 790,
#   'state': 'WA',
#   'subdivision': 'WEST KENWOOD ADD',
#   'taxAssessment': {'2021': {'improvements': 89400,
#                              'land': 30000,
#                              'value': 119400}},
#   'yearBuilt': 1909,
#   'zipCode': '99207'},
#  {'addressLine1': '11401 Solar St',
#   'assessorID': '364058000006070',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Lorena',
#   'county': 'McLennan',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Other',
#                'foundationType': 'Slab / Mat / Raft',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle'},
#   'formattedAddress': '11401 Solar St, Lorena, TX 76655',
#   'id': '11401-Solar-St,-Lorena,-TX-76655',
#   'lastSaleDate': '2022-12-07T00:00:00.000Z',
#   'latitude': 31.451838,
#   'legalDescription': 'PARK MEADOWS SOUTH PH 1 LOT 7 BLOCK 6 ACRES .138',
#   'longitude': -97.223556,
#   'lotSize': 6011,
#   'owner': {'mailingAddress': {'addressLine1': '11401 Solar St',
#                                'city': 'Lorena',
#                                'formattedAddress': '11401 Solar St, Lorena, TX '
#                                                    '76655',
#                                'id': '11401-Solar-St,-Lorena,-TX-76655',
#                                'state': 'TX',
#                                'zipCode': '76655'},
#             'names': ['TROY TINNEY', 'Melissa K Tinney'],
#             'type': 'Organization'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 5316}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1878,
#   'state': 'TX',
#   'subdivision': 'PARK MEADOWS SOUTH PH 1',
#   'taxAssessment': {'2023': {'improvements': 284520,
#                              'land': 36670,
#                              'value': 321190}},
#   'yearBuilt': 2022,
#   'zipCode': '76655'},
#  {'addressLine1': '348 Philadelphia Ave',
#   'assessorID': '48-063-00-0078',
#   'bathrooms': 2,
#   'city': 'Massapequa Park',
#   'county': 'Nassau',
#   'features': {'architectureType': 'Cape Cod',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 2,
#                'foundationType': 'OTHER',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Shingle',
#                'roomCount': 7,
#                'unitCount': 1},
#   'formattedAddress': '348 Philadelphia Ave, Massapequa Park, NY 11762',
#   'id': '348-Philadelphia-Ave,-Massapequa-Park,-NY-11762',
#   'lastSaleDate': '2008-07-02T00:00:00.000Z',
#   'lastSalePrice': 455000,
#   'latitude': 40.693742,
#   'legalDescription': 'TOWN #3 SCH DIST 023',
#   'longitude': -73.439346,
#   'lotSize': 7140,
#   'owner': {'mailingAddress': {'addressLine1': '348 Philadelphia Ave',
#                                'city': 'Massapequa Park',
#                                'formattedAddress': '348 Philadelphia Ave, '
#                                                    'Massapequa Park, NY 11762',
#                                'id': '348-Philadelphia-Ave,-Massapequa-Park,-NY-11762',
#                                'state': 'NY',
#                                'zipCode': '11762'},
#             'names': ['Mark Taylor']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 11891}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1665,
#   'state': 'NY',
#   'taxAssessment': {'2023': {'improvements': 302, 'land': 212, 'value': 514}},
#   'yearBuilt': 1953,
#   'zipCode': '11762'},
#  {'addressLine1': '711 S Euclid St',
#   'addressLine2': 'Apt 42',
#   'city': 'Santa Ana',
#   'county': 'Orange',
#   'features': {},
#   'formattedAddress': '711 S Euclid St, Apt 42, Santa Ana, CA 92704',
#   'id': '711-S-Euclid-St,-Apt-42,-Santa-Ana,-CA-92704',
#   'latitude': 33.736997,
#   'longitude': -117.937143,
#   'state': 'CA',
#   'zipCode': '92704'},
#  {'addressLine1': '5716 Ledgestone Dr',
#   'assessorID': '82-06-02-002-686.009-019',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Evansville',
#   'county': 'Vanderburgh',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 3,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Asphalt',
#                'roomCount': 5},
#   'formattedAddress': '5716 Ledgestone Dr, Evansville, IN 47711',
#   'id': '5716-Ledgestone-Dr,-Evansville,-IN-47711',
#   'lastSaleDate': '1997-10-29T00:00:00.000Z',
#   'latitude': 38.029942,
#   'legalDescription': 'KEYSTONE SUB SECTION II LOT 47 CUT OUT OF CODE 2-150-24 '
#                       '8-6-96 PL BK P PG 67',
#   'longitude': -87.506488,
#   'lotSize': 10890,
#   'owner': {'mailingAddress': {'addressLine1': '5716 Ledgestone Dr',
#                                'city': 'Evansville',
#                                'formattedAddress': '5716 Ledgestone Dr, '
#                                                    'Evansville, IN 47711',
#                                'id': '5716-Ledgestone-Dr,-Evansville,-IN-47711',
#                                'state': 'IN',
#                                'zipCode': '47711'},
#             'names': ['James S Wagner', 'Mary Carolyn Wagner'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2019': {'total': 2467}, '2023': {'total': 3553}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1879,
#   'state': 'IN',
#   'subdivision': 'KEYSTONE SUB',
#   'taxAssessment': {'2019': {'improvements': 206100,
#                              'land': 25500,
#                              'value': 231600},
#                     '2023': {'improvements': 308300,
#                              'land': 25500,
#                              'value': 333800}},
#   'yearBuilt': 1996,
#   'zipCode': '47711'},
#  {'addressLine1': '10845 Bobcat Ter',
#   'assessorID': 'R0379401',
#   'bathrooms': 3,
#   'bedrooms': 3,
#   'city': 'Lone Tree',
#   'county': 'Douglas',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'roomCount': 4,
#                'unitCount': 1},
#   'formattedAddress': '10845 Bobcat Ter, Lone Tree, CO 80124',
#   'id': '10845-Bobcat-Ter,-Lone-Tree,-CO-80124',
#   'latitude': 39.51956,
#   'legalDescription': 'LOT 114 INTRAVEST 320 #1A .209 AM/L',
#   'longitude': -104.91838,
#   'lotSize': 9104,
#   'owner': {'mailingAddress': {'addressLine1': '10845 Bobcat Ter',
#                                'city': 'Littleton',
#                                'formattedAddress': '10845 Bobcat Ter, '
#                                                    'Littleton, CO 80124',
#                                'id': '10845-Bobcat-Ter,-Littleton,-CO-80124',
#                                'state': 'CO',
#                                'zipCode': '80124'},
#             'names': ['Janice M Cutaia', 'Janice M Chandler'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 5005}, '2023': {'total': 6664}},
#   'propertyType': 'Single Family',
#   'squareFootage': 3373,
#   'state': 'CO',
#   'subdivision': 'INTRAVEST 320',
#   'taxAssessment': {'2022': {'improvements': 40460,
#                              'land': 8900,
#                              'value': 49360},
#                     '2023': {'improvements': 54830,
#                              'land': 12260,
#                              'value': 67090}},
#   'yearBuilt': 1997,
#   'zipCode': '80124'},
#  {'addressLine1': '1400 Carpentier St',
#   'addressLine2': 'Apt 134',
#   'assessorID': '075 002114900',
#   'bathrooms': 2,
#   'bedrooms': 2,
#   'city': 'San Leandro',
#   'county': 'Alameda',
#   'features': {'floorCount': 4,
#                'garage': True,
#                'garageType': 'Garage',
#                'pool': True,
#                'roomCount': 4,
#                'unitCount': 164},
#   'formattedAddress': '1400 Carpentier St, Apt 134, San Leandro, CA 94577',
#   'id': '1400-Carpentier-St,-Apt-134,-San-Leandro,-CA-94577',
#   'latitude': 37.72234,
#   'legalDescription': 'TR 4298',
#   'longitude': -122.158206,
#   'lotSize': 89146,
#   'owner': {'mailingAddress': {'addressLine1': '1400 Carpentier St',
#                                'addressLine2': 'APT 134',
#                                'city': 'San Leandro',
#                                'id': '1400-Carpentier-St,-APT-134,-San-Leandro,-CA-94577',
#                                'state': 'CA',
#                                'zipCode': '94577'},
#             'names': ['']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2018': {'total': 3250}},
#   'propertyType': 'Condo',
#   'squareFootage': 1187,
#   'state': 'CA',
#   'subdivision': '4298',
#   'taxAssessment': {'2018': {'improvements': 158442,
#                              'land': 67903,
#                              'value': 226345}},
#   'yearBuilt': 1983,
#   'zipCode': '94577'},
#  {'addressLine1': '7032 16th St',
#   'assessorID': '3525210010127000030',
#   'bathrooms': 2,
#   'city': 'Zephyrhills',
#   'county': 'Pasco',
#   'features': {'exteriorType': 'Metal',
#                'floorCount': 1,
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Metal',
#                'unitCount': 1},
#   'formattedAddress': '7032 16th St, Zephyrhills, FL 33540',
#   'id': '7032-16th-St,-Zephyrhills,-FL-33540',
#   'latitude': 28.259933,
#   'legalDescription': 'ZEPHYRHILLS COLONY COMPANY LANDS PB 1 PG 55 PORTION OF '
#                       'TRACTS 114 & 127 IN SECTION 35 DESC AS SOUTH 60.00 FT '
#                       'OF TRACT 114 LESS EAST 432.32 FT & NORTH 140.00 FT OF '
#                       'TRACT 127 LESS EAST 432.32 FT RESERVING AN EASEMENT FOR '
#                       'INGRESS & EGRESS OVER AND ACROS',
#   'longitude': -82.175206,
#   'lotSize': 42900,
#   'owner': {'mailingAddress': {'addressLine1': '7032 16th St',
#                                'city': 'Zephyrhills',
#                                'id': '7032-16th-St,-Zephyrhills,-FL-33540',
#                                'state': 'FL',
#                                'zipCode': '33540'},
#             'names': ['']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 1269}},
#   'propertyType': 'Manufactured',
#   'squareFootage': 960,
#   'state': 'FL',
#   'subdivision': 'ZEPHYRHILLS COLONY CO',
#   'taxAssessment': {'2021': {'improvements': 19958,
#                              'land': 40755,
#                              'value': 60713}},
#   'yearBuilt': 1975,
#   'zipCode': '33540',
#   'zoning': 'R1MH'},
#  {'addressLine1': '1824 Monroe St',
#   'assessorID': '51-000-04-0381.00-00000',
#   'bathrooms': 1.5,
#   'bedrooms': 3,
#   'city': 'York',
#   'county': 'York',
#   'features': {'architectureType': 'Colonial',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Siding',
#                'floorCount': 2,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Detached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '1824 Monroe St, York, PA 17404',
#   'id': '1824-Monroe-St,-York,-PA-17404',
#   'lastSaleDate': '1979-09-05T00:00:00.000Z',
#   'lastSalePrice': 44500,
#   'latitude': 39.951226,
#   'legalDescription': 'DIST:51 CITY/MUNI/TWP:WEST MANCHESTER TOWNSHIP',
#   'longitude': -76.767455,
#   'lotSize': 17511,
#   'owner': {'mailingAddress': {'addressLine1': '1824 Monroe St',
#                                'city': 'York',
#                                'formattedAddress': '1824 Monroe St, York, PA '
#                                                    '17404',
#                                'id': '1824-Monroe-St,-York,-PA-17404',
#                                'state': 'PA',
#                                'zipCode': '17404'},
#             'names': ['Jeffrey L Ropp', 'LINDA G ROPP']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 3592},
#                     '2023': {'total': 3705},
#                     '2024': {'total': 3705}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1348,
#   'state': 'PA',
#   'subdivision': 'ALDINGER ADD',
#   'taxAssessment': {'2020': {'improvements': 82600,
#                              'land': 30100,
#                              'value': 112700},
#                     '2023': {'improvements': 82600,
#                              'land': 30100,
#                              'value': 112700},
#                     '2024': {'improvements': 82600,
#                              'land': 30100,
#                              'value': 112700}},
#   'yearBuilt': 1917,
#   'zipCode': '17404',
#   'zoning': 'RS'},
#  {'addressLine1': '10833 Green Harvest Dr',
#   'assessorID': 'U303020B6S000019000430',
#   'bathrooms': 4,
#   'bedrooms': 6,
#   'city': 'Riverview',
#   'county': 'Hillsborough',
#   'features': {'architectureType': 'Contemporary',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Stucco',
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '10833 Green Harvest Dr, Riverview, FL 33578',
#   'id': '10833-Green-Harvest-Dr,-Riverview,-FL-33578',
#   'lastSaleDate': '2019-12-13T00:00:00.000Z',
#   'lastSalePrice': 486000,
#   'latitude': 27.842323,
#   'legalDescription': 'VENTANA GROVES PHASE 2A LOT 43 BLOCK 19',
#   'longitude': -82.336736,
#   'lotSize': 7260,
#   'owner': {'mailingAddress': {'addressLine1': '10833 Green Harvest Dr',
#                                'city': 'Riverview',
#                                'formattedAddress': '10833 Green Harvest Dr, '
#                                                    'Riverview, FL 33578',
#                                'id': '10833-Green-Harvest-Dr,-Riverview,-FL-33578',
#                                'state': 'FL',
#                                'zipCode': '33578'},
#             'names': ['Dean Dagostino', 'CANUTE ELLIOTT', 'Lorie Elliott']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 7603}, '2023': {'total': 8538}},
#   'propertyType': 'Single Family',
#   'squareFootage': 4222,
#   'state': 'FL',
#   'subdivision': 'VENTANA GRVS PH 2A',
#   'taxAssessment': {'2022': {'value': 266186}, '2023': {'value': 274172}},
#   'yearBuilt': 2019,
#   'zipCode': '33578',
#   'zoning': 'PD'},
#  {'addressLine1': '3556 Franklin Park Dr',
#   'assessorID': '10-10-18-428-007',
#   'bathrooms': 1.5,
#   'city': 'Sterling Heights',
#   'county': 'Macomb',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'fireplace': True,
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'unitCount': 1},
#   'formattedAddress': '3556 Franklin Park Dr, Sterling Heights, MI 48310',
#   'id': '3556-Franklin-Park-Dr,-Sterling-Heights,-MI-48310',
#   'lastSaleDate': '2012-03-22T00:00:00.000Z',
#   'lastSalePrice': 108000,
#   'latitude': 42.585503,
#   'legalDescription': 'M 251 $WESTHAMPTON SUB. LOT 251',
#   'longitude': -83.073708,
#   'lotSize': 7187,
#   'owner': {'mailingAddress': {'addressLine1': '3556 Franklin Park Dr',
#                                'city': 'Sterling Heights',
#                                'id': '3556-Franklin-Park-Dr,-Sterling-Heights,-MI-48310',
#                                'state': 'MI',
#                                'zipCode': '48310'},
#             'names': ['WAEL ABO', 'GHAYDAA ABO']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 3012}, '2022': {'total': 3076}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1577,
#   'state': 'MI',
#   'subdivision': '$WESTHAMPTON SUB',
#   'taxAssessment': {'2022': {'value': 125900}, '2023': {'value': 138100}},
#   'yearBuilt': 1977,
#   'zipCode': '48310',
#   'zoning': 'R-60'},
#  {'addressLine1': '2714 N Jefferson St',
#   'assessorID': '26-015.40-040',
#   'bathrooms': 1.5,
#   'bedrooms': 3,
#   'city': 'Wilmington',
#   'county': 'New Castle',
#   'features': {'architectureType': 'Ranch',
#                'exteriorType': 'Brick',
#                'floorCount': 2,
#                'foundationType': 'Other',
#                'heating': True,
#                'heatingType': 'Hot Water',
#                'roofType': 'Wood',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '2714 N Jefferson St, Wilmington, DE 19802',
#   'id': '2714-N-Jefferson-St,-Wilmington,-DE-19802',
#   'lastSaleDate': '2021-07-30T00:00:00.000Z',
#   'lastSalePrice': 107000,
#   'latitude': 39.758636,
#   'legalDescription': 'LOT:34 BLK:1571 DIST:26 SUBD:WILMINGTON',
#   'longitude': -75.537083,
#   'lotSize': 1307,
#   'owner': {'mailingAddress': {'addressLine1': '1 Viscaya Dr',
#                                'city': 'Bear',
#                                'formattedAddress': '1 Viscaya Dr, Bear, DE '
#                                                    '19701',
#                                'id': '1-Viscaya-Dr,-Bear,-DE-19701',
#                                'state': 'DE',
#                                'zipCode': '19701'},
#             'names': ['Charles M Fax', 'Felecia Y Fax'],
#             'type': 'Individual'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2022': {'total': 1488}, '2023': {'total': 887}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1500,
#   'state': 'DE',
#   'subdivision': 'WILMINGTON',
#   'taxAssessment': {'2022': {'improvements': 28100,
#                              'land': 4600,
#                              'value': 32700},
#                     '2023': {'improvements': 28100,
#                              'land': 4600,
#                              'value': 32700}},
#   'yearBuilt': 1938,
#   'zipCode': '19802',
#   'zoning': '26R-3'},
#  {'addressLine1': '24 Willard Ave',
#   'assessorID': '48-225-00-0206',
#   'bathrooms': 1,
#   'city': 'Farmingdale',
#   'county': 'Nassau',
#   'features': {'architectureType': 'Bungalow',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 1,
#                'foundationType': 'Block',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Shingle',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '24 Willard Ave, Farmingdale, NY 11735',
#   'id': '24-Willard-Ave,-Farmingdale,-NY-11735',
#   'lastSaleDate': '2018-09-10T00:00:00.000Z',
#   'lastSalePrice': 465000,
#   'latitude': 40.719503,
#   'legalDescription': 'TOWN #3 SCH DIST 022',
#   'longitude': -73.44313,
#   'lotSize': 6000,
#   'owner': {'mailingAddress': {'addressLine1': '24 Willard Ave',
#                                'city': 'Farmingdale',
#                                'formattedAddress': '24 Willard Ave, '
#                                                    'Farmingdale, NY 11735',
#                                'id': '24-Willard-Ave,-Farmingdale,-NY-11735',
#                                'state': 'NY',
#                                'zipCode': '11735'},
#             'names': ['Joseph Ieraci', 'ROBERT MIJUCA']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 13196}, '2023': {'total': 10983}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1048,
#   'state': 'NY',
#   'subdivision': 'FARMINGGALE',
#   'taxAssessment': {'2020': {'improvements': 168, 'land': 524, 'value': 692},
#                     '2023': {'improvements': 179, 'land': 209, 'value': 388}},
#   'yearBuilt': 1943,
#   'zipCode': '11735'},
#  {'addressLine1': 'PO Box 2939',
#   'city': 'Weatherford',
#   'county': 'Parker',
#   'features': {},
#   'formattedAddress': 'PO Box 2939, Weatherford, TX 76086',
#   'id': 'PO-Box-2939,-Weatherford,-TX-76086',
#   'latitude': 32.754746,
#   'longitude': -97.77674,
#   'state': 'TX',
#   'zipCode': '76086'},
#  {'addressLine1': '711 Eagle Cliff Rd NE',
#   'assessorID': '4117-000-042-0101',
#   'bathrooms': 1.5,
#   'bedrooms': 4,
#   'city': 'Bainbridge Island',
#   'county': 'Kitsap',
#   'features': {'architectureType': 'Ranch',
#                'exteriorType': 'OTHER',
#                'fireplace': True,
#                'fireplaceType': 'Masonry',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '711 Eagle Cliff Rd NE, Bainbridge Island, WA 98110',
#   'id': '711-Eagle-Cliff-Rd-NE,-Bainbridge-Island,-WA-98110',
#   'latitude': 47.632402,
#   'legalDescription': 'LOT 42 AND THE EASTERLY HALF OF LOT 43, WING POINT '
#                       'NORTH, AS PER PLAT RECORDED IN VOLUME 12 OF PLATS, '
#                       'PAGES 64, 65 AND 66,',
#   'longitude': -122.512295,
#   'lotSize': 16117,
#   'owner': {'mailingAddress': {'addressLine1': '711 Eagle Cliff Rd NE',
#                                'city': 'Bainbridge Island',
#                                'formattedAddress': '711 Eagle Cliff Rd NE, '
#                                                    'Bainbridge Island, WA '
#                                                    '98110',
#                                'id': '711-Eagle-Cliff-Rd-NE,-Bainbridge-Island,-WA-98110',
#                                'state': 'WA',
#                                'zipCode': '98110'},
#             'names': ['Garrett W Kimzey', 'GARRETT KAREN A KIMZEY']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2024': {'total': 6048}},
#   'propertyType': 'Single Family',
#   'squareFootage': 988,
#   'state': 'WA',
#   'subdivision': 'WING POINT NORTH',
#   'taxAssessment': {'2024': {'improvements': 538500,
#                              'land': 265300,
#                              'value': 803800}},
#   'yearBuilt': 1968,
#   'zipCode': '98110',
#   'zoning': 'CITY'},
#  {'addressLine1': '3469 145th St',
#   'assessorID': '03-02217',
#   'bathrooms': 1,
#   'bedrooms': 3,
#   'city': 'Toledo',
#   'county': 'Lucas',
#   'features': {'architectureType': 'Conventional',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Aluminum / Vinyl Siding',
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Detached',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roomCount': 8,
#                'unitCount': 1},
#   'formattedAddress': '3469 145th St, Toledo, OH 43611',
#   'id': '3469-145th-St,-Toledo,-OH-43611',
#   'lastSaleDate': '2014-07-30T00:00:00.000Z',
#   'lastSalePrice': 92700,
#   'latitude': 41.728126,
#   'legalDescription': 'CARLAND ORCHARD LOTS 14 -16',
#   'longitude': -83.463284,
#   'lotSize': 16065,
#   'owner': {'mailingAddress': {'addressLine1': '3469 145th St',
#                                'city': 'Toledo',
#                                'formattedAddress': '3469 145th St, Toledo, OH '
#                                                    '43611',
#                                'id': '3469-145th-St,-Toledo,-OH-43611',
#                                'state': 'OH',
#                                'zipCode': '43611'},
#             'names': ['Lucas P Mikolayczyk'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 2436}, '2023': {'total': 2435}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1142,
#   'state': 'OH',
#   'subdivision': 'CARLAND ORCHARD',
# ...
#                                                    'Oklahoma City, OK 73170',
#                                'id': '11812-Cedar-Valley-Dr,-Oklahoma-City,-OK-73170',
#                                'state': 'OK',
#                                'zipCode': '73170'},
#             'names': ['Jeffrey R Dunzy', 'ANGELA A DUNZY']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 1859}, '2023': {'total': 1893}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1647,
#   'state': 'OK',
#   'subdivision': 'GREEN VALLEY 3',
#   'taxAssessment': {'2022': {'improvements': 12595,
#                              'land': 3414,
#                              'value': 16009},
#                     '2023': {'improvements': 13301,
#                              'land': 3189,
#                              'value': 16490}},
#   'yearBuilt': 1983,
#   'zipCode': '73170',
#   'zoning': 'R1'},
#  {'addressLine1': '47 Becker Ave',
#   'assessorID': '54  00011-0000-00009',
#   'bathrooms': 2,
#   'bedrooms': 4,
#   'city': 'Rochelle Park',
#   'county': 'Bergen',
#   'features': {'exteriorType': 'Wood',
#                'floorCount': 2,
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Garage',
#                'unitCount': 1},
#   'formattedAddress': '47 Becker Ave, Rochelle Park, NJ 07662',
#   'id': '47-Becker-Ave,-Rochelle-Park,-NJ-07662',
#   'lastSaleDate': '2022-07-29T00:00:00.000Z',
#   'lastSalePrice': 495000,
#   'latitude': 40.897299,
#   'legalDescription': 'ADDITIONAL LOTS: L 10',
#   'longitude': -74.077029,
#   'lotSize': 5001,
#   'owner': {'mailingAddress': {'addressLine1': '47 Becker Ave',
#                                'city': 'Rochelle Park',
#                                'formattedAddress': '47 Becker Ave, Rochelle '
#                                                    'Park, NJ 07662',
#                                'id': '47-Becker-Ave,-Rochelle-Park,-NJ-07662',
#                                'state': 'NJ',
#                                'zipCode': '07662'},
#             'names': ['Mojtaba Moslehi Eraghi', 'Quiroz Aparicio Abigaila']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 7242}, '2022': {'total': 8207}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1471,
#   'state': 'NJ',
#   'taxAssessment': {'2022': {'improvements': 117900,
#                              'land': 190200,
#                              'value': 308100},
#                     '2023': {'improvements': 117900,
#                              'land': 190200,
#                              'value': 308100}},
#   'yearBuilt': 1935,
#   'zipCode': '07662'},
#  {'addressLine1': '6130 Parsonage Cir',
#   'assessorID': '32-2N-28-1654-00A00-0420',
#   'bathrooms': 2,
#   'bedrooms': 4,
#   'city': 'Milton',
#   'county': 'Santa Rosa',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'Brick',
#                'floorCount': 1,
#                'foundationType': 'Masonry',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Shingle'},
#   'formattedAddress': '6130 Parsonage Cir, Milton, FL 32570',
#   'id': '6130-Parsonage-Cir,-Milton,-FL-32570',
#   'lastSaleDate': '2023-12-04T00:00:00.000Z',
#   'lastSalePrice': 360000,
#   'latitude': 30.640717,
#   'legalDescription': 'HAMPTON CHASE LOT 42 BLK A & AS DES IN OR 4292 PG 816',
#   'longitude': -87.076942,
#   'lotSize': 11326,
#   'owner': {'mailingAddress': {'addressLine1': '6130 Parsonage Cir',
#                                'city': 'Milton',
#                                'formattedAddress': '6130 Parsonage Cir, '
#                                                    'Milton, FL 32570',
#                                'id': '6130-Parsonage-Cir,-Milton,-FL-32570',
#                                'state': 'FL',
#                                'zipCode': '32570'},
#             'names': ['Ashley Marie Whiting'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 547}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2100,
#   'state': 'FL',
#   'subdivision': 'HAMPTON CHASE',
#   'taxAssessment': {'2023': {'land': 40000, 'value': 40000}},
#   'yearBuilt': 2023,
#   'zipCode': '32570'},
#  {'addressLine1': '1800 Parkvalley Dr',
#   'assessorID': '03-96-17-440-006.100-005',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Columbus',
#   'county': 'Bartholomew',
#   'features': {'cooling': True,
#                'coolingType': 'Central',
#                'fireplace': True,
#                'floorCount': 1,
#                'foundationType': 'Raised',
#                'garage': True,
#                'garageType': 'Attached',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Asphalt',
#                'roomCount': 7},
#   'formattedAddress': '1800 Parkvalley Dr, Columbus, IN 47203',
#   'id': '1800-Parkvalley-Dr,-Columbus,-IN-47203',
#   'lastSaleDate': '2022-03-04T00:00:00.000Z',
#   'latitude': 39.217654,
#   'legalDescription': 'LOT 58 - SANDY HOOK SECTION 3',
#   'longitude': -85.879478,
#   'lotSize': 12960,
#   'owner': {'mailingAddress': {'addressLine1': '1800 Parkvalley Dr',
#                                'city': 'Columbus',
#                                'formattedAddress': '1800 Parkvalley Dr, '
#                                                    'Columbus, IN 47203',
#                                'id': '1800-Parkvalley-Dr,-Columbus,-IN-47203',
#                                'state': 'IN',
#                                'zipCode': '47203'},
#             'names': ['Paul B Miller', 'John C Miller']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 2270}, '2022': {'total': 2414}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1875,
#   'state': 'IN',
#   'taxAssessment': {'2022': {'improvements': 163600,
#                              'land': 49100,
#                              'value': 212700},
#                     '2023': {'improvements': 152600,
#                              'land': 49100,
#                              'value': 201700}},
#   'yearBuilt': 1972,
#   'zipCode': '47203'},
#  {'addressLine1': '11415 Whispering Hollow Dr',
#   'assessorID': 'U21281707A000001000130',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Tampa',
#   'county': 'Hillsborough',
#   'features': {'architectureType': 'Contemporary',
#                'cooling': True,
#                'coolingType': 'Central',
#                'exteriorType': 'OTHER',
#                'fireplace': True,
#                'floorCount': 2,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '11415 Whispering Hollow Dr, Tampa, FL 33635',
#   'id': '11415-Whispering-Hollow-Dr,-Tampa,-FL-33635',
#   'lastSaleDate': '2018-03-08T00:00:00.000Z',
#   'lastSalePrice': 350000,
#   'latitude': 28.035092,
#   'legalDescription': 'COUNTRYWAY PARCEL B TRACT 17 LOT 13 BLOCK 1',
#   'longitude': -82.612761,
#   'lotSize': 5700,
#   'owner': {'mailingAddress': {'addressLine1': '11415 Whispering Hollow Dr',
#                                'city': 'Tampa',
#                                'formattedAddress': '11415 Whispering Hollow '
#                                                    'Dr, Tampa, FL 33635',
#                                'id': '11415-Whispering-Hollow-Dr,-Tampa,-FL-33635',
#                                'state': 'FL',
#                                'zipCode': '33635'},
#             'names': ['Frederick Drake', 'DE ALMEIDA LAISA']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2023': {'total': 4712}},
#   'propertyType': 'Single Family',
#   'squareFootage': 2302,
#   'state': 'FL',
#   'subdivision': 'COUNTRYWAY PARCEL B TRACT 17',
#   'taxAssessment': {'2023': {'value': 280847}},
#   'yearBuilt': 1993,
#   'zipCode': '33635',
#   'zoning': 'PD'},
#  {'addressLine1': '1312 Xaveria Dr',
#   'assessorID': '05-00318441',
#   'bathrooms': 3,
#   'city': 'Silver Spring',
#   'county': 'Montgomery',
#   'features': {'architectureType': 'Split Foyer',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Brick',
#                'fireplace': True,
#                'floorCount': 1,
#                'garage': True,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Composition Shingle',
#                'unitCount': 1},
#   'formattedAddress': '1312 Xaveria Dr, Silver Spring, MD 20903',
#   'id': '1312-Xaveria-Dr,-Silver-Spring,-MD-20903',
#   'lastSaleDate': '2020-10-01T00:00:00.000Z',
#   'lastSalePrice': 535000,
#   'latitude': 39.024189,
#   'legalDescription': 'HILLANDALE HGTS',
#   'longitude': -76.984978,
#   'lotSize': 12688,
#   'owner': {'mailingAddress': {'addressLine1': '1312 Xaveria Dr',
#                                'city': 'Silver Spring',
#                                'formattedAddress': '1312 Xaveria Dr, Silver '
#                                                    'Spring, MD 20903',
#                                'id': '1312-Xaveria-Dr,-Silver-Spring,-MD-20903',
#                                'state': 'MD',
#                                'zipCode': '20903'},
#             'names': ['Blanca D Calderon Ortiz', 'Jose R Veintimilla Yugsan'],
#             'type': 'Individual'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2022': {'total': 5072}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1660,
#   'state': 'MD',
#   'subdivision': 'HILLANDALE',
#   'taxAssessment': {'2023': {'improvements': 284300,
#                              'land': 223400,
#                              'value': 507700}},
#   'yearBuilt': 1960,
#   'zipCode': '20903',
#   'zoning': 'R90'},
#  {'addressLine1': '5000 Hartsfield Dr',
#   'assessorID': '1757.01-48-3799 0026389',
#   'bathrooms': 1,
#   'city': 'Wake Forest',
#   'county': 'Wake',
#   'features': {'architectureType': 'Conventional',
#                'exteriorType': 'Siding',
#                'floorCount': 1,
#                'foundationType': 'Raised',
#                'garage': True,
#                'garageSpaces': 1,
#                'garageType': 'Garage',
#                'heating': True,
#                'heatingType': 'Central',
#                'roomCount': 6,
#                'unitCount': 1},
#   'formattedAddress': '5000 Hartsfield Dr, Wake Forest, NC 27587',
#   'id': '5000-Hartsfield-Dr,-Wake-Forest,-NC-27587',
#   'latitude': 35.888702,
#   'legalDescription': 'LOA HARTSFIELD SUB',
#   'longitude': -78.478754,
#   'lotSize': 16117,
#   'owner': {'mailingAddress': {'addressLine1': '6415 Hawthorne St',
#                                'city': 'Hyattsville',
#                                'formattedAddress': '6415 Hawthorne St, '
#                                                    'Hyattsville, MD 20785',
#                                'id': '6415-Hawthorne-St,-Hyattsville,-MD-20785',
#                                'state': 'MD',
#                                'zipCode': '20785'},
#             'names': ['Joe L Greene'],
#             'type': 'Individual'},
#   'ownerOccupied': False,
#   'propertyTaxes': {'2022': {'total': 648},
#                     '2023': {'total': 698},
#                     '2024': {'total': 1043}},
#   'propertyType': 'Single Family',
#   'squareFootage': 916,
#   'state': 'NC',
#   'subdivision': 'LOA HARTSFIELD SUB',
#   'taxAssessment': {'2022': {'improvements': 55001,
#                              'land': 32000,
#                              'value': 87001},
#                     '2023': {'improvements': 55001,
#                              'land': 32000,
#                              'value': 87001},
#                     '2024': {'improvements': 89660,
#                              'land': 75000,
#                              'value': 164660}},
#   'yearBuilt': 1969,
#   'zipCode': '27587',
#   'zoning': 'R-30'},
#  {'addressLine1': '300 Luman Rd',
#   'addressLine2': 'Unit 163',
#   'bathrooms': 2,
#   'bedrooms': 4,
#   'city': 'Phoenix',
#   'county': 'Jackson',
#   'formattedAddress': '300 Luman Rd, Unit 163, Phoenix, OR 97535',
#   'id': '300-Luman-Rd,-Unit-163,-Phoenix,-OR-97535',
#   'latitude': 42.275293,
#   'longitude': -122.811567,
#   'propertyType': 'Manufactured',
#   'squareFootage': 1620,
#   'state': 'OR',
#   'yearBuilt': 2023,
#   'zipCode': '97535'},
#  {'addressLine1': '8908 36th Ave N',
#   'assessorID': '18-118-21-34-0044',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Minneapolis',
#   'county': 'Hennepin',
#   'features': {'architectureType': 'Split Level',
#                'cooling': True,
#                'coolingType': 'Commercial',
#                'exteriorType': 'Other',
#                'floorCount': 2,
#                'foundationType': 'Concrete Block',
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Detached Garage',
#                'heating': True,
#                'heatingType': 'Forced Air',
#                'roofType': 'Asphalt',
#                'roomCount': 7,
#                'unitCount': 1},
#   'formattedAddress': '8908 36th Ave N, Minneapolis, MN 55427',
#   'id': '8908-36th-Ave-N,-Minneapolis,-MN-55427',
#   'lastSaleDate': '2005-12-21T00:00:00.000Z',
#   'lastSalePrice': 250000,
#   'latitude': 45.022213,
#   'legalDescription': '010 003 NORTHWOOD TERRACE 1ST ADDN 90 X 115',
#   'longitude': -93.394027,
#   'lotSize': 10454,
#   'owner': {'mailingAddress': {'addressLine1': '8908 36th Ave N',
#                                'city': 'Minneapolis',
#                                'id': '8908-36th-Ave-N,-Minneapolis,-MN-55427',
#                                'state': 'MN',
#                                'zipCode': '55427'},
#             'names': ['JACK BARNETT']},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2021': {'total': 3775}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1104,
#   'state': 'MN',
#   'subdivision': 'NORTHWOOD TERRACE 1ST ADDN',
#   'taxAssessment': {'2019': {'improvements': 158000,
#                              'land': 75000,
#                              'value': 233000},
#                     '2020': {'improvements': 170000,
#                              'land': 78000,
#                              'value': 248000}},
#   'yearBuilt': 1961,
#   'zipCode': '55427'},
#  {'addressLine1': '428 Anson Ave',
#   'assessorID': '143-141-012-000',
#   'bathrooms': 2,
#   'bedrooms': 3,
#   'city': 'Rohnert Park',
#   'county': 'Sonoma',
#   'features': {'cooling': True,
#                'coolingType': 'Commercial',
#                'fireplace': True,
#                'floorCount': 1,
#                'garage': True,
#                'garageSpaces': 2,
#                'garageType': 'Attached',
#                'roomCount': 5,
#                'unitCount': 1},
#   'formattedAddress': '428 Anson Ave, Rohnert Park, CA 94928',
#   'id': '428-Anson-Ave,-Rohnert-Park,-CA-94928',
#   'lastSaleDate': '2009-05-29T00:00:00.000Z',
#   'lastSalePrice': 221000,
#   'latitude': 38.338201,
#   'legalDescription': 'ROHNERT PARK SUB #5 UNIT A LOT 12 BLK 1',
#   'longitude': -122.704047,
#   'lotSize': 6098,
#   'owner': {'mailingAddress': {'addressLine1': '428 Anson Ave',
#                                'city': 'Rohnert Park',
#                                'formattedAddress': '428 Anson Ave, Rohnert '
#                                                    'Park, CA 94928',
#                                'id': '428-Anson-Ave,-Rohnert-Park,-CA-94928',
#                                'state': 'CA',
#                                'zipCode': '94928'},
#             'names': ['ANACLETO FAMILY TRUST'],
#             'type': 'Organization'},
#   'ownerOccupied': True,
#   'propertyTaxes': {'2020': {'total': 3272}, '2023': {'total': 3308}},
#   'propertyType': 'Single Family',
#   'squareFootage': 1200,
#   'state': 'CA',
#   'subdivision': 'ROHNERT PARK SUBDIVISION #5 UNIT A',
#   'taxAssessment': {'2020': {'improvements': 142472,
#                              'land': 117744,
#                              'value': 260216},
#                     '2023': {'improvements': 149762,
#                              'land': 123768,
#                              'value': 273530}},
#   'yearBuilt': 1960,
#   'zipCode': '94928'}]

# %%
data = response.json()

file_name = 'real_estate.json'

with open(file_name, 'w') as file:
    json.dump(data, file, indent=4)


#real_estate_df = pd.DataFrame([data])

real_estate_df = pd.read_json('real_estate.json')
real_estate_df.head()
# Out:
#              addressLine1            city state  zipCode  \
# 0            106 S Key St  Pilot Mountain    NC    27041
# 1      1314 Deer Trail Rd          Hoover    AL    35226
# 2    91 Sw South River Dr          Stuart    FL    34997
# 3     17 Crowninshield St      Providence    RI     2909
# 4  220 Camford Stone Path    Fayetteville    GA    30214
#
#                                   formattedAddress addressLine2  \
# 0   106 S Key St, Apt 38, Pilot Mountain, NC 27041       Apt 38
# 1             1314 Deer Trail Rd, Hoover, AL 35226          NaN
# 2  91 Sw South River Dr, Apt 102, Stuart, FL 34997      Apt 102
# 3        17 Crowninshield St, Providence, RI 02909          NaN
# 4   220 Camford Stone Path, Fayetteville, GA 30214          NaN
#
#                                             features      county  \
# 0                                                 {}       Surry
# 1  {'cooling': True, 'coolingType': 'Commercial',...   Jefferson
# 2  {'architectureType': 'Condo / Apartment', 'coo...      Martin
# 3  {'architectureType': 'Two Family', 'exteriorTy...  Providence
# 4  {'cooling': True, 'coolingType': 'Central', 'e...     Fayette
#
#                                                 id  longitude  ...  zoning  \
# 0   106-S-Key-St,-Apt-38,-Pilot-Mountain,-NC-27041 -80.480906  ...     NaN
# 1             1314-Deer-Trail-Rd,-Hoover,-AL-35226 -86.872279  ...     PRD
# 2  91-Sw-South-River-Dr,-Apt-102,-Stuart,-FL-34997 -80.246179  ...     NaN
# 3        17-Crowninshield-St,-Providence,-RI-02909 -71.458082  ...     R-2
# 4   220-Camford-Stone-Path,-Fayetteville,-GA-30214 -84.461941  ...     NaN
#
#    ownerOccupied  bathrooms    propertyType lastSalePrice  \
# 0            NaN        NaN             NaN           NaN
# 1            1.0        2.5   Single Family      197000.0
# 2            1.0        2.0           Condo      149500.0
# 3            1.0        2.0  Duplex-Triplex           1.0
# 4            1.0        3.5   Single Family      359000.0
#
#                lastSaleDate  \
# 0                       NaN
# 1  2005-01-26T00:00:00.000Z
# 2  2020-08-20T00:00:00.000Z
# 3  2011-09-27T00:00:00.000Z
# 4  2024-07-16T00:00:00.000Z
#
#                                        taxAssessment  \
# 0                                                NaN
# 1  {'2022': {'value': 26940, 'land': 7000, 'impro...
# 2  {'2022': {'value': 134930}, '2023': {'value': ...
# 3  {'2019': {'value': 268600, 'land': 51100, 'imp...
# 4  {'2022': {'value': 130080, 'land': 20000, 'imp...
#
#                                        propertyTaxes  \
# 0                                                NaN
# 1                          {'2022': {'total': 1903}}
# 2  {'2022': {'total': 1566}, '2023': {'total': 16...
# 3  {'2019': {'total': 3959}, '2022': {'total': 42...
# 4  {'2022': {'total': 3953}, '2023': {'total': 41...
#
#                                                owner  lotSize
# 0                                                NaN      NaN
# 1  {'names': ['Mohammad R Abdel Rohman'], 'mailin...      NaN
# 2  {'names': ['Kenneth Peter Lee', 'Charles Torto...      NaN
# 3  {'names': ['MARIA C VEGA'], 'mailingAddress': ...   7172.0
# 4  {'names': ['Collette Camille Brown', 'Kristoph...   2178.0
#
# [5 rows x 27 columns]

# %%
real_estate_df.columns
# Out:
# Index(['addressLine1', 'city', 'state', 'zipCode', 'formattedAddress',
#        'addressLine2', 'features', 'county', 'id', 'longitude', 'latitude',
#        'bedrooms', 'squareFootage', 'yearBuilt', 'assessorID',
#        'legalDescription', 'subdivision', 'zoning', 'ownerOccupied',
#        'bathrooms', 'propertyType', 'lastSalePrice', 'lastSaleDate',
#        'taxAssessment', 'propertyTaxes', 'owner', 'lotSize'],
#       dtype='object')

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   addressLine1      500 non-null    object
#  1   city              500 non-null    object
#  2   state             500 non-null    object
#  3   zipCode           500 non-null    int64
#  4   formattedAddress  500 non-null    object
#  5   addressLine2      88 non-null     object
#  6   features          467 non-null    object
#  7   county            499 non-null    object
#  8   id                500 non-null    object
#  9   longitude         500 non-null    float64
#  10  latitude          500 non-null    float64
#  11  bedrooms          325 non-null    float64
#  12  squareFootage     383 non-null    float64
#  13  yearBuilt         374 non-null    float64
#  14  assessorID        373 non-null    object
#  15  legalDescription  369 non-null    object
#  16  subdivision       311 non-null    object
#  17  zoning            194 non-null    object
#  18  ownerOccupied     344 non-null    float64
#  19  bathrooms         375 non-null    float64
#  20  propertyType      415 non-null    object
#  21  lastSalePrice     268 non-null    float64
#  22  lastSaleDate      324 non-null    object
#  23  taxAssessment     369 non-null    object
#  24  propertyTaxes     358 non-null    object
#  25  owner             371 non-null    object
#  26  lotSize           367 non-null    float64
# dtypes: float64(9), int64(1), object(17)
# memory usage: 105.6+ KB

# %% [markdown]
# ### Transformation layer

# %%
real_estate_df.fillna({
    'bathrooms' : 0.0,
    'bedrooms' : 0.0,
    'squareFootage' : 0.0,
    'county' : 'Unknown',
    'propertyType' : 'Unknown',
    'yearBuilt' : 0.0,
    'features' : 'Unknown',
    'assessorID' : 'Unknown',
    'legalDescription' : 'Unknown',
    'subdivision' : 'Unknown',
    'zoning' : 'Unknown',
    'ownerOccupied' : 0.0,
    'lotSize' : 0.0,
    'taxAssessment' : 'Unknown',
    'lastSaleDate' : 'Unknown',
    'propertyTaxes' : 'Unknown',
    'lastSalePrice' : 0.0,
    'addressLine2' : 'Unknown',
    'owner' : 'Unknown'
    }, inplace = True)

# %%
real_estate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   addressLine1      500 non-null    object
#  1   city              500 non-null    object
#  2   state             500 non-null    object
#  3   zipCode           500 non-null    int64
#  4   formattedAddress  500 non-null    object
#  5   addressLine2      500 non-null    object
#  6   features          500 non-null    object
#  7   county            500 non-null    object
#  8   id                500 non-null    object
#  9   longitude         500 non-null    float64
#  10  latitude          500 non-null    float64
#  11  bedrooms          500 non-null    float64
#  12  squareFootage     500 non-null    float64
#  13  yearBuilt         500 non-null    float64
#  14  assessorID        500 non-null    object
#  15  legalDescription  500 non-null    object
#  16  subdivision       500 non-null    object
#  17  zoning            500 non-null    object
#  18  ownerOccupied     500 non-null    float64
#  19  bathrooms         500 non-null    float64
#  20  propertyType      500 non-null    object
#  21  lastSalePrice     500 non-null    float64
#  22  lastSaleDate      500 non-null    object
#  23  taxAssessment     500 non-null    object
#  24  propertyTaxes     500 non-null    object
#  25  owner             500 non-null    object
#  26  lotSize           500 non-null    float64
# dtypes: float64(9), int64(1), object(17)
# memory usage: 105.6+ KB

# %%
# Address Table 
Address_Table = real_estate_df[['addressLine1', 'city', 'state', 'zipCode', 'formattedAddress', 'county', 'longitude', 'latitude', 'addressLine2']].copy().reset_index(drop = True)


# Assign a unique primary key for tax_id using a dedicated numbering system
Address_Table['address_id'] = range(29, len(Address_Table) + 29)  # Sequential numbering starting at 29

Address_Table = Address_Table[['address_id', 'addressLine1', 'city', 'state', 'zipCode', 'formattedAddress', 'county', 'longitude', 'latitude', 'addressLine2']]


Address_Table.head()
# Out:
#    address_id            addressLine1            city state  zipCode  \
# 0          29            106 S Key St  Pilot Mountain    NC    27041
# 1          30      1314 Deer Trail Rd          Hoover    AL    35226
# 2          31    91 Sw South River Dr          Stuart    FL    34997
# 3          32     17 Crowninshield St      Providence    RI     2909
# 4          33  220 Camford Stone Path    Fayetteville    GA    30214
#
#                                   formattedAddress      county  longitude  \
# 0   106 S Key St, Apt 38, Pilot Mountain, NC 27041       Surry -80.480906
# 1             1314 Deer Trail Rd, Hoover, AL 35226   Jefferson -86.872279
# 2  91 Sw South River Dr, Apt 102, Stuart, FL 34997      Martin -80.246179
# 3        17 Crowninshield St, Providence, RI 02909  Providence -71.458082
# 4   220 Camford Stone Path, Fayetteville, GA 30214     Fayette -84.461941
#
#     latitude addressLine2
# 0  36.376987       Apt 38
# 1  33.353804      Unknown
# 2  27.152562      Apt 102
# 3  41.817999      Unknown
# 4  33.450286      Unknown

# %%
# Property_info Table 


# Ensure Address_Table and real_estate_df have a common column to merge on, like 'addressLine1'
Property_info_Table = real_estate_df.merge(
    Address_Table[['address_id', 'addressLine1', 'city', 'state', 'zipCode']],
    on=['addressLine1', 'city', 'state', 'zipCode'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Property_info_Table
Property_info_Table = Property_info_Table[['address_id', 'assessorID', 'yearBuilt', 'legalDescription',
                                           'ownerOccupied', 'propertyType', 'owner', 'id', 'subdivision', 'zoning']].copy()


# Assign a unique primary key for tax_id using a dedicated numbering system
Property_info_Table['property_id'] = range(13, len(Property_info_Table) + 13)  # Sequential numbering starting at 13

Property_info_Table = Property_info_Table[['property_id', 'address_id', 'assessorID', 'yearBuilt', 'legalDescription',
                                           'ownerOccupied', 'propertyType', 'owner', 'id', 'subdivision', 'zoning']]


# Display the first few rows
Property_info_Table.head()
# Out:
#    property_id  address_id                assessorID  yearBuilt  \
# 0           13          29                   Unknown        0.0
# 1           14          30    39-00-29-4-000-004.048     1995.0
# 2           15          31  41-38-41-001-091-01020-0     1982.0
# 3           16          32           PROV M:107 L:12     1950.0
# 4           17          33                 052321013     2003.0
#
#                                     legalDescription  ownerOccupied  \
# 0                                            Unknown            0.0
# 1                   LOT 4 BLK 1 DEER VALLEY II 29/20            1.0
# 2  SOUTH RIVER VILLAGE ONE CONDO UNIT 102 BLDG P....            1.0
# 3                    LOT:12 CITY/MUNI/TWP:PROVIDENCE            1.0
# 4                     LOT 13 TOWNHOMES @ LAFAYETTE P            1.0
#
#      propertyType                                              owner  \
# 0         Unknown                                            Unknown
# 1   Single Family  {'names': ['Mohammad R Abdel Rohman'], 'mailin...
# 2           Condo  {'names': ['Kenneth Peter Lee', 'Charles Torto...
# 3  Duplex-Triplex  {'names': ['MARIA C VEGA'], 'mailingAddress': ...
# 4   Single Family  {'names': ['Collette Camille Brown', 'Kristoph...
#
#                                                 id                subdivision  \
# 0   106-S-Key-St,-Apt-38,-Pilot-Mountain,-NC-27041                    Unknown
# 1             1314-Deer-Trail-Rd,-Hoover,-AL-35226             DEER VALLEY II
# 2  91-Sw-South-River-Dr,-Apt-102,-Stuart,-FL-34997  SOUTH RIVER VILLAGE CONDO
# 3        17-Crowninshield-St,-Providence,-RI-02909                    Unknown
# 4   220-Camford-Stone-Path,-Fayetteville,-GA-30214  THE VILLAGES AT LAFAYETTE
#
#     zoning
# 0  Unknown
# 1      PRD
# 2  Unknown
# 3      R-2
# 4  Unknown

# %%
# Remove the dictionary text format style in the "owner" column
Property_info_Table['owner'] = Property_info_Table['owner'].astype(str)



# Display the first few rows
Property_info_Table.head()
# Out:
#    property_id  address_id                assessorID  yearBuilt  \
# 0           13          29                   Unknown        0.0
# 1           14          30    39-00-29-4-000-004.048     1995.0
# 2           15          31  41-38-41-001-091-01020-0     1982.0
# 3           16          32           PROV M:107 L:12     1950.0
# 4           17          33                 052321013     2003.0
#
#                                     legalDescription  ownerOccupied  \
# 0                                            Unknown            0.0
# 1                   LOT 4 BLK 1 DEER VALLEY II 29/20            1.0
# 2  SOUTH RIVER VILLAGE ONE CONDO UNIT 102 BLDG P....            1.0
# 3                    LOT:12 CITY/MUNI/TWP:PROVIDENCE            1.0
# 4                     LOT 13 TOWNHOMES @ LAFAYETTE P            1.0
#
#      propertyType                                              owner  \
# 0         Unknown                                            Unknown
# 1   Single Family  {'names': ['Mohammad R Abdel Rohman'], 'mailin...
# 2           Condo  {'names': ['Kenneth Peter Lee', 'Charles Torto...
# 3  Duplex-Triplex  {'names': ['MARIA C VEGA'], 'mailingAddress': ...
# 4   Single Family  {'names': ['Collette Camille Brown', 'Kristoph...
#
#                                                 id                subdivision  \
# 0   106-S-Key-St,-Apt-38,-Pilot-Mountain,-NC-27041                    Unknown
# 1             1314-Deer-Trail-Rd,-Hoover,-AL-35226             DEER VALLEY II
# 2  91-Sw-South-River-Dr,-Apt-102,-Stuart,-FL-34997  SOUTH RIVER VILLAGE CONDO
# 3        17-Crowninshield-St,-Providence,-RI-02909                    Unknown
# 4   220-Camford-Stone-Path,-Fayetteville,-GA-30214  THE VILLAGES AT LAFAYETTE
#
#     zoning
# 0  Unknown
# 1      PRD
# 2  Unknown
# 3      R-2
# 4  Unknown

# %%
display(Property_info_Table.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   property_id       500 non-null    int64
#  1   address_id        500 non-null    int64
#  2   assessorID        500 non-null    object
#  3   yearBuilt         500 non-null    float64
#  4   legalDescription  500 non-null    object
#  5   ownerOccupied     500 non-null    float64
#  6   propertyType      500 non-null    object
#  7   owner             500 non-null    object
#  8   id                500 non-null    object
#  9   subdivision       500 non-null    object
#  10  zoning            500 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 43.1+ KB
# None

# %%
# Tax Table

# Ensure Property_info_Table and real_estate_df have a common column to merge on.
Tax_Table = real_estate_df.merge(
    Property_info_Table[['property_id', 'yearBuilt', 'propertyType', 'id']],
    on=['yearBuilt', 'propertyType', 'id'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Tax_Table
Tax_Table = Tax_Table[['property_id', 'taxAssessment', 'propertyTaxes']].copy()


# Assign a unique primary key for tax_id using a dedicated numbering system
Tax_Table['tax_id'] = range(5, len(Tax_Table) + 5)  # Sequential numbering starting at 5

Tax_Table = Tax_Table[['tax_id', 'property_id', 'taxAssessment', 'propertyTaxes']]


# Display the first few rows
Tax_Table.head()
# Out:
#    tax_id  property_id                                      taxAssessment  \
# 0       5           13                                            Unknown
# 1       6           14  {'2022': {'value': 26940, 'land': 7000, 'impro...
# 2       7           15  {'2022': {'value': 134930}, '2023': {'value': ...
# 3       8           16  {'2019': {'value': 268600, 'land': 51100, 'imp...
# 4       9           17  {'2022': {'value': 130080, 'land': 20000, 'imp...
#
#                                        propertyTaxes
# 0                                            Unknown
# 1                          {'2022': {'total': 1903}}
# 2  {'2022': {'total': 1566}, '2023': {'total': 16...
# 3  {'2019': {'total': 3959}, '2022': {'total': 42...
# 4  {'2022': {'total': 3953}, '2023': {'total': 41...

# %%
# Remove the dictionary text format style in the 'taxAssessment'and 'propertyTaxes' column
Tax_Table['taxAssessment'] = Tax_Table['taxAssessment'].astype(str)
Tax_Table['propertyTaxes'] = Tax_Table['propertyTaxes'].astype(str)



# Display the first few rows
Tax_Table.head()
# Out:
#    tax_id  property_id                                      taxAssessment  \
# 0       5           13                                            Unknown
# 1       6           14  {'2022': {'value': 26940, 'land': 7000, 'impro...
# 2       7           15  {'2022': {'value': 134930}, '2023': {'value': ...
# 3       8           16  {'2019': {'value': 268600, 'land': 51100, 'imp...
# 4       9           17  {'2022': {'value': 130080, 'land': 20000, 'imp...
#
#                                        propertyTaxes
# 0                                            Unknown
# 1                          {'2022': {'total': 1903}}
# 2  {'2022': {'total': 1566}, '2023': {'total': 16...
# 3  {'2019': {'total': 3959}, '2022': {'total': 42...
# 4  {'2022': {'total': 3953}, '2023': {'total': 41...

# %%
# Sales Table

# Ensure Property_info_Table and real_estate_df have a common column to merge on.
Sales_Table = real_estate_df.merge(
    Property_info_Table[['property_id', 'yearBuilt', 'propertyType', 'id']],
    on=['yearBuilt', 'propertyType', 'id'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Sales_Table
Sales_Table = Sales_Table[['property_id', 'lastSalePrice', 'lastSaleDate']].copy()


# Assign a unique primary key for tax_id using a dedicated numbering system
Sales_Table['sales_id'] = range(55, len(Sales_Table) + 55)  # Sequential numbering starting at 55

Sales_Table = Sales_Table[['sales_id', 'property_id', 'lastSalePrice', 'lastSaleDate']].copy()


# Display the first few rows
Sales_Table.head()
# Out:
#    sales_id  property_id  lastSalePrice              lastSaleDate
# 0        55           13            0.0                   Unknown
# 1        56           14       197000.0  2005-01-26T00:00:00.000Z
# 2        57           15       149500.0  2020-08-20T00:00:00.000Z
# 3        58           16            1.0  2011-09-27T00:00:00.000Z
# 4        59           17       359000.0  2024-07-16T00:00:00.000Z

# %%
# Features Table

# Ensure Property_info_Table and real_estate_df have a common column to merge on.
Features_Table = real_estate_df.merge(
    Property_info_Table[['property_id', 'yearBuilt', 'propertyType', 'id']],
    on=['yearBuilt', 'propertyType', 'id'],  # Join on these common columns
    how='left'  # Keep all rows from real_estate_df
)

# Select the required columns for the Features Table
Features_Table = Features_Table[['property_id', 'bedrooms', 'squareFootage', 'bathrooms', 'lotSize', 'features']].copy()


# Assign a unique primary key for tax_id using a dedicated numbering system
Features_Table['features_id'] = range(79, len(Sales_Table) + 79)  # Sequential numbering starting at 79

Features_Table = Features_Table[['features_id','property_id', 'bedrooms', 'squareFootage', 'bathrooms', 'lotSize', 'features']].copy()


# Display the first few rows
Features_Table.head()
# Out:
#    features_id  property_id  bedrooms  squareFootage  bathrooms  lotSize  \
# 0           79           13       0.0            0.0        0.0      0.0
# 1           80           14       3.0          978.0        2.5      0.0
# 2           81           15       2.0         1107.0        2.0      0.0
# 3           82           16       6.0         3114.0        2.0   7172.0
# 4           83           17       3.0         1864.0        3.5   2178.0
#
#                                             features
# 0                                                 {}
# 1  {'cooling': True, 'coolingType': 'Commercial',...
# 2  {'architectureType': 'Condo / Apartment', 'coo...
# 3  {'architectureType': 'Two Family', 'exteriorTy...
# 4  {'cooling': True, 'coolingType': 'Central', 'e...

# %%
# Remove the dictionary text format style in the 'features' column
Features_Table['features'] = Features_Table['features'].astype(str)


# Display the first few rows
Features_Table.head()
# Out:
#    features_id  property_id  bedrooms  squareFootage  bathrooms  lotSize  \
# 0           79           13       0.0            0.0        0.0      0.0
# 1           80           14       3.0          978.0        2.5      0.0
# 2           81           15       2.0         1107.0        2.0      0.0
# 3           82           16       6.0         3114.0        2.0   7172.0
# 4           83           17       3.0         1864.0        3.5   2178.0
#
#                                             features
# 0                                                 {}
# 1  {'cooling': True, 'coolingType': 'Commercial',...
# 2  {'architectureType': 'Condo / Apartment', 'coo...
# 3  {'architectureType': 'Two Family', 'exteriorTy...
# 4  {'cooling': True, 'coolingType': 'Central', 'e...

# %%
real_estate_df.columns
# Out:
# Index(['addressLine1', 'city', 'state', 'zipCode', 'formattedAddress',
#        'addressLine2', 'features', 'county', 'id', 'longitude', 'latitude',
#        'bedrooms', 'squareFootage', 'yearBuilt', 'assessorID',
#        'legalDescription', 'subdivision', 'zoning', 'ownerOccupied',
#        'bathrooms', 'propertyType', 'lastSalePrice', 'lastSaleDate',
#        'taxAssessment', 'propertyTaxes', 'owner', 'lotSize'],
#       dtype='object')

# %% [markdown]
# ### Loading Layer

# %%
# Load environment variables from the .env file
load_dotenv()


# Develop a function to get the Database connections
def get_db_connection():
    connection = psycopg2.connect(
        # Retrieve environment variables
        host = os.getenv('HOST'),
        database = os.getenv('DATABASE'),
        user = os.getenv('USER'),
        password = os.getenv('PASSWORD')
    )

    return connection

# Connect to the Database
conn = get_db_connection()

# %%
# Create a function that sets up the schema and tables
def create_tables():
    conn = get_db_connection()
    cursor = conn.cursor()
    create_table_query = '''
                            CREATE SCHEMA IF NOT EXISTS Zuma_Realtors;

                            DROP TABLE IF EXISTS Zuma_Realtors.Features_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Sales_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Property_info_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Tax_Table CASCADE;
                            DROP TABLE IF EXISTS Zuma_Realtors.Address_Table CASCADE;

                            CREATE TABLE Zuma_Realtors.Address_Table (
                                address_id INTEGER PRIMARY KEY,
                                addressLine1 VARCHAR(100000),
                                city VARCHAR(100000),
                                state VARCHAR(100000),
                                zipCode INTEGER,
                                formattedAddress VARCHAR(100000),
                                county VARCHAR(100000),
                                longitude FLOAT,
                                latitude FLOAT,
                                addressLine2 VARCHAR(100000)
                            );


                            CREATE TABLE Zuma_Realtors.Property_info_Table (
                                property_id INTEGER PRIMARY KEY,
                                address_id INTEGER,
                                assessorID VARCHAR(100000),
                                yearBuilt FLOAT,
                                legalDescription VARCHAR(100000),
                                ownerOccupied FLOAT,
                                propertyType VARCHAR(100000),
                                owner VARCHAR(100000),
                                id VARCHAR(100000),
                                subdivision VARCHAR(100000),
                                zoning VARCHAR(100000),
                                FOREIGN KEY (address_id) REFERENCES Zuma_Realtors.Address_Table(address_id)
                            );



                            CREATE TABLE Zuma_Realtors.Tax_Table (
                                tax_id INTEGER PRIMARY KEY,
                                property_id INTEGER,
                                taxAssessment VARCHAR(100000),
                                propertyTaxes VARCHAR(100000),
                                FOREIGN KEY (property_id) REFERENCES Zuma_Realtors.Property_info_Table(property_id)
                            );
 
                            

                             CREATE TABLE Zuma_Realtors.Sales_Table (
                                sales_id INTEGER PRIMARY KEY,
                                property_id INTEGER,
                                lastSalePrice FLOAT,
                                lastSaleDate VARCHAR(100000),
                                FOREIGN KEY (property_id) REFERENCES Zuma_Realtors.Property_info_Table(property_id)
                            );



                            CREATE TABLE Zuma_Realtors.Features_Table (
                                features_id INTEGER PRIMARY KEY,
                                property_id INTEGER,
                                bedrooms FLOAT,
                                squareFootage FLOAT,
                                bathrooms FLOAT,
                                lotSize FLOAT,
                                features VARCHAR(100000),
                                FOREIGN KEY (property_id) REFERENCES Zuma_Realtors.Property_info_Table(property_id)
                            );
                            '''
   
   
    cursor.execute(create_table_query)
    conn.commit()
    cursor.close()
    conn.close()

create_tables()

# %%
### Loading the Data into the db Tables
conn = get_db_connection()
cursor = conn.cursor()

# Insert the dataframe into SQL tables
for _,row in Address_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Address_Table (address_id, addressLine1, city, state, zipCode, formattedAddress, county, longitude, latitude, addressLine2)
            
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
        (row['address_id'], row['addressLine1'], row['city'], row['state'], row['zipCode'], row['formattedAddress'], row['county'], row['longitude'],  row['latitude'], row['addressLine2'])
    )


for _,row in Property_info_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Property_info_Table (property_id, address_id, assessorID, yearBuilt, legalDescription, ownerOccupied, propertyType, owner, id, subdivision, zoning)
            
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)''',
        (row['property_id'], row['address_id'], row['assessorID'], row['yearBuilt'], row['legalDescription'], row['ownerOccupied'], row['propertyType'], row['owner'],  row['id'], row['subdivision'], row['zoning'])
    )


for _,row in Tax_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Tax_Table (tax_id, property_id, taxAssessment, propertyTaxes)
            
            VALUES (%s, %s, %s, %s)''',
        (row['tax_id'], row['property_id'], row['taxAssessment'], row['propertyTaxes'])
    )



for _,row in Sales_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Sales_Table (sales_id, property_id, lastSalePrice, lastSaleDate)
            
            VALUES (%s, %s, %s, %s)''',
        (row['sales_id'], row['property_id'], row['lastSalePrice'], row['lastSaleDate'])
    )




for _,row in Features_Table.iterrows():
    cursor.execute(
        '''INSERT INTO Zuma_Realtors.Features_Table (features_id, property_id, bedrooms, squareFootage, bathrooms, lotSize, features)
            
            VALUES (%s, %s, %s, %s, %s, %s, %s)''',
        (row['features_id'], row['property_id'], row['bedrooms'], row['squareFootage'], row['bathrooms'], row['lotSize'], row['features'])
    )



# Commit Changes
conn.commit()

# Close Connection
cursor.close()
conn.close()

# %%
display(Property_info_Table.info())
display(Property_info_Table.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   property_id       500 non-null    int64
#  1   address_id        500 non-null    int64
#  2   assessorID        500 non-null    object
#  3   yearBuilt         500 non-null    float64
#  4   legalDescription  500 non-null    object
#  5   ownerOccupied     500 non-null    float64
#  6   propertyType      500 non-null    object
#  7   owner             500 non-null    object
#  8   id                500 non-null    object
#  9   subdivision       500 non-null    object
#  10  zoning            500 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 43.1+ KB
# None
# Index(['property_id', 'address_id', 'assessorID', 'yearBuilt',
#        'legalDescription', 'ownerOccupied', 'propertyType', 'owner', 'id',
#        'subdivision', 'zoning'],
#       dtype='object')

# %%
Features_Table.head()
# Out:
#    features_id  property_id  bedrooms  squareFootage  bathrooms  lotSize  \
# 0           79           13       0.0            0.0        0.0      0.0
# 1           80           14       3.0          978.0        2.5      0.0
# 2           81           15       2.0         1107.0        2.0      0.0
# 3           82           16       6.0         3114.0        2.0   7172.0
# 4           83           17       3.0         1864.0        3.5   2178.0
#
#                                             features
# 0                                                 {}
# 1  {'cooling': True, 'coolingType': 'Commercial',...
# 2  {'architectureType': 'Condo / Apartment', 'coo...
# 3  {'architectureType': 'Two Family', 'exteriorTy...
# 4  {'cooling': True, 'coolingType': 'Central', 'e...
